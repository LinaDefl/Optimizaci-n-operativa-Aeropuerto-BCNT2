# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("vuelos_bcn_sindup.csv") 
df.head(10)
# Out:
#    Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 0         0.0  16/11/2025 23-03-05                   Ryanair     FR3166
# 1         1.0  16/11/2025 23-03-05  Norwegian Air Sweden AOC     D81741
# 2         2.0  16/11/2025 23-03-05                Aer Lingus      EI563
# 3         3.0  16/11/2025 23-03-05            easyJet Europe     EC7139
# 4         4.0  16/11/2025 23-03-05                Icelandair      FI597
# 5         5.0  16/11/2025 23-03-05              Lauda Europe     LW2889
# 6         6.0  16/11/2025 23-03-05                   Ryanair     FR3129
# 7         7.0  16/11/2025 23-03-05                   Ryanair     FR3976
# 8         8.0  16/11/2025 23-03-05                   Ryanair     FR1527
# 9         9.0  16/11/2025 23-03-05                   Ryanair     FR2402
#
#                  Name_Destiny Time_flight          flight_state  \
# 0               Palermo (PMO)       11:00             Ha salido
# ...

# %%
df.shape
# Out:
# (2143, 10)

# %%
# Dividir en diccionario por fecha
df_por_fecha = {fecha: df_fecha.copy() for fecha, df_fecha in df.groupby('fecha_scrapeo')}
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_16 = df_por_fecha['16/11/2025 23-03-05'].copy()
df_16
# Out:
#      Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 0           0.0  16/11/2025 23-03-05                   Ryanair     FR3166
# 1           1.0  16/11/2025 23-03-05  Norwegian Air Sweden AOC     D81741
# 2           2.0  16/11/2025 23-03-05                Aer Lingus      EI563
# 3           3.0  16/11/2025 23-03-05            easyJet Europe     EC7139
# 4           4.0  16/11/2025 23-03-05                Icelandair      FI597
# ..          ...                  ...                       ...        ...
# 111       113.0  16/11/2025 23-03-05                  Wizz Air     W64116
# 112       114.0  16/11/2025 23-03-05            Wizz Air Malta     W45154
# 113       115.0  16/11/2025 23-03-05                   Ryanair     FR5220
# 114       116.0  16/11/2025 23-03-05                  Wizz Air     W61706
# 115       117.0  16/11/2025 23-03-05                   Ryanair     FR9406
#
#                    Name_Destiny Time_flight          flight_state  \
# ...

# %%
df_16[(df_16['Gate'].isna())].shape
# Out:
# (107, 10)

# %%
df_16[(df_16['Gate'].isna())].head(20)
# Out:
#     Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 0          0.0  16/11/2025 23-03-05                   Ryanair     FR3166
# 1          1.0  16/11/2025 23-03-05  Norwegian Air Sweden AOC     D81741
# 2          2.0  16/11/2025 23-03-05                Aer Lingus      EI563
# 3          3.0  16/11/2025 23-03-05            easyJet Europe     EC7139
# 4          4.0  16/11/2025 23-03-05                Icelandair      FI597
# 6          6.0  16/11/2025 23-03-05                   Ryanair     FR3129
# 7          7.0  16/11/2025 23-03-05                   Ryanair     FR3976
# 8          8.0  16/11/2025 23-03-05                   Ryanair     FR1527
# 9          9.0  16/11/2025 23-03-05                   Ryanair     FR2402
# 10        10.0  16/11/2025 23-03-05                   Volotea     V72167
# 12        12.0  16/11/2025 23-03-05          Pegasus Airlines     PC1092
# 13        13.0  16/11/2025 23-03-05                   Ryanair     FR2511
# ...

# %%
df_16.loc[df_16['Num_flight'] == 'FR6394', 'Gate'] = 'W'
df_16.loc[df_16['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_16.loc[df_16['Num_flight'] == 'FR6394', 'flight_capacity'] = 197
 
df_16.loc[df_16['Num_flight'] == 'V73700', 'Gate'] = 'S'
df_16.loc[df_16['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_16.loc[df_16['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_16.loc[df_16['Num_flight'] == 'RR5252', 'Gate'] = 'U'
df_16.loc[df_16['Num_flight'] == 'RR5252', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'RR5252', 'flight_capacity'] = 189

df_16.loc[df_16['Num_flight'] == 'FR2250', 'Gate'] = 'W'
df_16.loc[df_16['Num_flight'] == 'RR5252', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'RR5252', 'flight_capacity'] = 189

df_16.loc[df_16['Num_flight'] == 'FR2922', 'Gate'] = 'U'
df_16.loc[df_16['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737 MAX 8'
df_16.loc[df_16['Num_flight'] == 'FR2922', 'flight_capacity'] = 197

df_16.loc[df_16['Num_flight'] == 'W46728', 'Gate'] = 'S'
df_16.loc[df_16['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_16.loc[df_16['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_16.loc[df_16['Num_flight'] == 'FR4585', 'Gate'] = 'S'
df_16.loc[df_16['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_16.loc[df_16['Num_flight'] == 'FR3121', 'Gate'] = 'U'
df_16.loc[df_16['Num_flight'] == 'RR5252', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'RR5252', 'flight_capacity'] = 189

df_16.loc[df_16['Num_flight'] == 'FR3129', 'Gate'] = 'U'
df_16.loc[df_16['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_16.loc[df_16['Num_flight'] == 'EI563', 'Gate'] = 'Y'
df_16.loc[df_16['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_16.loc[df_16['Num_flight'] == 'EI563', 'flight_capacity'] = 180

df_16.loc[df_16['Num_flight'] == 'PC1092', 'Gate'] = 'W'
df_16.loc[df_16['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_16.loc[df_16['Num_flight'] == 'PC1092', 'flight_capacity'] = 180

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
    df_16.loc[df_16['Num_flight'] == 'TO4759', 'flight_capacity'] = 186
    df_16.loc[df_16['Num_flight'] == 'TO4759', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A320neo'
    df_16.loc[df_16['Num_flight'] == 'HV5134', 'flight_capacity'] = 186
    df_16.loc[df_16['Num_flight'] == 'HV5134', 'Gate'] = 'U'
        
    df_16.loc[df_16['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'EI565', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'EI565', 'Gate'] = 'Y'
            
    df_16.loc[df_16['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR3792', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR3792', 'Gate'] = 'W'
            
    df_16.loc[df_16['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'W43406', 'flight_capacity'] = 180
    
    df_16.loc[df_16['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'FR5752', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR5752', 'Gate'] = 'R'

    df_16.loc[df_16['Num_flight'] == 'U28060', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'U28060', 'flight_capacity'] = 156
                    
    df_16.loc[df_16['Num_flight'] == 'W45154', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'W45154', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'W45154', 'Gate'] = 'W'
                        
    df_16.loc[df_16['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W46020', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W46020', 'Gate'] = 'S'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR5718', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR5718', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR12', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR12', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'V73573', 'flight_capacity'] = 156
    df_16.loc[df_16['Num_flight'] == 'V73573', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR1681', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR1681', 'Gate'] = 'U'
        
    df_16.loc[df_16['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR777', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR777', 'Gate'] = 'R'
    
    df_16.loc[df_16['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR6305', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR6305', 'Gate'] = 'U'
        
    df_16.loc[df_16['Num_flight'] == 'EC7109', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'EC7109', 'flight_capacity'] = 156
      
    df_16.loc[df_16['Num_flight'] == 'FR2406', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR2406', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR2406', 'Gate'] = 'U'
          
    df_16.loc[df_16['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'W43686', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'W43686', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'LS804', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'LS804', 'Gate'] = 'W'
    
    df_16.loc[df_16['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR8631', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR8631', 'Gate'] = 'W'
       
    df_16.loc[df_16['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'W61176', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'W61176', 'Gate'] = 'S'
           
    df_16.loc[df_16['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321'
    df_16.loc[df_16['Num_flight'] == 'W61478', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'W61478', 'Gate'] = 'S'
               
    df_16.loc[df_16['Num_flight'] == 'EC7159', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'EC7159', 'flight_capacity'] = 156
    
    df_16.loc[df_16['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321'
    df_16.loc[df_16['Num_flight'] == 'W64406', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'W64406', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'EC3750', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'EC3750', 'flight_capacity'] = 180
        
    df_16.loc[df_16['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR9015', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR9015', 'Gate'] = 'Y'
            
    df_16.loc[df_16['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'U28058', 'flight_capacity'] = 156
        
    df_16.loc[df_16['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'EC4212', 'flight_capacity'] = 180
         
    df_16.loc[df_16['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W67022', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W67022', 'Gate'] = 'S'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'BZ251', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'BZ251', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'BZ251', 'Gate'] = 'W'
    
    df_16.loc[df_16['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR3320', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR3320', 'Gate'] = 'U'
        
    df_16.loc[df_16['Num_flight'] == 'EC7694', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'EC7694', 'flight_capacity'] = 180
    
    df_16.loc[df_16['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'FR6973', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR6973', 'Gate'] = 'S'
        
    df_16.loc[df_16['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == '3O378', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == '3O378', 'Gate'] = 'W'
    
    df_16.loc[df_16['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR133', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR133', 'Gate'] = 'R'
    
    df_16.loc[df_16['Num_flight'] == 'FR9814', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR9814', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR9814', 'Gate'] = 'R'

    df_16.loc[df_16['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR8669', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR8669', 'Gate'] = 'W'

    df_16.loc[df_16['Num_flight'] == '3O374', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == '3O374', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == '3O374', 'Gate'] = 'Y'

    df_16.loc[df_16['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'RR8394', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'RR8394', 'Gate'] = 'S'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR3166', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR3166', 'Gate'] = 'S'

    df_16.loc[df_16['Num_flight'] == 'EC7139', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'EC7139', 'flight_capacity'] = 156
    
    df_16.loc[df_16['Num_flight'] == 'LW2889', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'LW2889', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'LW2889', 'Gate'] = 'U'

    df_16.loc[df_16['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'FR3976', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR3976', 'Gate'] = 'W'

    df_16.loc[df_16['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR1527', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR1527', 'Gate'] = 'S'

    df_16.loc[df_16['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR6300', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR6300', 'Gate'] = 'U'

    df_16.loc[df_16['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'EC1380', 'flight_capacity'] = 180
    
    df_16.loc[df_16['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR1342', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR1342', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'HV5132', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'HV5132', 'Gate'] = 'U'

    df_16.loc[df_16['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'FI597', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FI597', 'Gate'] = 'R'

# %%
df_16.loc[df_16['Name_company'] == 'easyJet Europe', 'Gate'] = 'R'
df_16.loc[df_16['Name_company'] == 'EasyJet', 'Gate'] = 'M' # Airbus A319
df_16.loc[df_16['Name_company'] == 'Easyjet', 'Gate'] = 'M'
df_16.loc[df_16['Name_company'] == 'EasyJet Europe', 'Gate'] = 'R'
df_16.loc[df_16['Name_company'] == 'easyJet', 'Gate'] = 'M'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR2402', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR2402', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'FR2402', 'Name_Destiny'] = 'Sevilla (SVQ)'
    
    df_16.loc[df_16['Num_flight'] == 'V72167', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'V72167', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'V72167', 'Aircraft'] = 'Airbus A320'
    
    df_16.loc[df_16['Num_flight'] == 'FR2511', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'FR2511', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR2511', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'FR8598', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'FR8598', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR8598', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'V71445', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'V71445', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'V71445', 'Aircraft'] = 'Airbus A320'
    
    df_16.loc[df_16['Num_flight'] == 'W46330', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'W46330', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
    
    df_16.loc[df_16['Num_flight'] == 'W46330', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'W46330', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'W46330', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'FR9811', 'Gate'] = 'Y'
    df_16.loc[df_16['Num_flight'] == 'FR9811', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737 MAX 8'
    
    df_16.loc[df_16['Num_flight'] == 'FR483', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'FR483', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR483', 'Name_Destiny'] = 'Malaga (AGP)'
    
    df_16.loc[df_16['Num_flight'] == 'BT684', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'BT684', 'flight_capacity'] = 148
    df_16.loc[df_16['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
    
    df_16.loc[df_16['Num_flight'] == 'FR6920', 'Gate'] = 'W'
    df_16.loc[df_16['Num_flight'] == 'FR6920', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737 MAX 8'
    
    df_16.loc[df_16['Num_flight'] == 'PC7184', 'Gate'] = 'W'
    df_16.loc[df_16['Num_flight'] == 'PC7184', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'PC7184', 'Aircraft'] = 'Boeing 737 MAX 8'
    
    df_16.loc[df_16['Num_flight'] == 'XQ895', 'Gate'] = 'Y'
    df_16.loc[df_16['Num_flight'] == 'XQ895', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'XQ895', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'D85502', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'D85502', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'FR269', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'FR269', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'QS1059', 'Gate'] = 'S'
    df_16.loc[df_16['Num_flight'] == 'QS1059', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'FR774', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'FR774', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'RR3072', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'RR3072', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'RR3072', 'Aircraft'] = 'Boeing 737-800'
    
    df_16.loc[df_16['Num_flight'] == 'TO4755', 'Gate'] = 'U'
    df_16.loc[df_16['Num_flight'] == 'TO4755', 'flight_capacity'] = 186
    df_16.loc[df_16['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'HV6066', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'HV6066', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'HV6066', 'Gate'] = 'U'

    df_16.loc[df_16['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
    df_16.loc[df_16['Num_flight'] == 'U25716', 'flight_capacity'] = 186
    df_16.loc[df_16['Num_flight'] == 'U25716', 'Gate'] = 'M'
    
    df_16.loc[df_16['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
    df_16.loc[df_16['Num_flight'] == 'W43180', 'flight_capacity'] = 230
    df_16.loc[df_16['Num_flight'] == 'W43180', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'FR3160', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR3160', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR3160', 'Gate'] = 'Y'
    
    df_16.loc[df_16['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
    df_16.loc[df_16['Num_flight'] == 'V72165', 'flight_capacity'] = 156
    df_16.loc[df_16['Num_flight'] == 'V72165', 'Gate'] = 'R'
    
    df_16.loc[df_16['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR2233', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR2233', 'Gate'] = 'W'
    
    df_16.loc[df_16['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR5710', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR5710', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'LS1338', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'LS1338', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'LS1338', 'Gate'] = 'Y'
    
    df_16.loc[df_16['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W64666', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W64666', 'Gate'] = 'Y'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'FR8136', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR8136', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR8136', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W62096', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W62096', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'HV6788', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'HV6788', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'FR6985', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR6985', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'JU585', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'JU585', 'Gate'] = 'W'
    
    df_16.loc[df_16['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'D83659', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'D83659', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'EW2521', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'EW2521', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR4587', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR4587', 'Gate'] = 'R'

# %%
if (df_16['fecha_scrapeo'] == "16/11/2025 23-03-05").any():
    df_16.loc[df_16['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'D81741', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'D81741', 'Gate'] = 'U'
    
    df_16.loc[df_16['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR9406', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR9406', 'Gate'] = 'Y'
    
    df_16.loc[df_16['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W61706', 'flight_capacity'] = 239 
    df_16.loc[df_16['Num_flight'] == 'W61706', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR5220', 'flight_capacity'] = 189 
    df_16.loc[df_16['Num_flight'] == 'FR5220', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W64116', 'flight_capacity'] = 239 
    df_16.loc[df_16['Num_flight'] == 'W64116', 'Gate'] = 'Y'
    
    df_16.loc[df_16['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
    df_16.loc[df_16['Num_flight'] == 'V71415', 'flight_capacity'] = 180
    df_16.loc[df_16['Num_flight'] == 'V71415', 'Gate'] = 'S'
    
    df_16.loc[df_16['Num_flight'] == 'U22706', 'Aircraft'] = 'Airbus A320neo'
    df_16.loc[df_16['Num_flight'] == 'U22706', 'flight_capacity'] = 186
    df_16.loc[df_16['Num_flight'] == 'U22706', 'Gate'] = 'M'
    
    df_16.loc[df_16['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
    df_16.loc[df_16['Num_flight'] == 'W43178', 'flight_capacity'] = 230
    df_16.loc[df_16['Num_flight'] == 'W43178', 'Gate'] = 'S' 
    
    df_16.loc[df_16['Num_flight'] == 'FR2896', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'FR2896', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'FR2896', 'Gate'] = "R"
    df_16.loc[df_16['Num_flight'] == 'FR2896', 'Name_Destiny'] = "Palma de Mallorca (PMI)"
    
    df_16.loc[df_16['Num_flight'] == 'RR8615', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'RR8615', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'RR8615', 'Gate'] = "R"
    
    df_16.loc[df_16['Num_flight'] == 'W64738', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W64738', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W64738', 'Gate'] = "W"
    
    df_16.loc[df_16['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
    df_16.loc[df_16['Num_flight'] == 'U22326', 'flight_capacity'] = 186
    df_16.loc[df_16['Num_flight'] == 'U22326', 'Gate'] = "M"
    
    df_16.loc[df_16['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'RR6944', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'RR6944', 'Gate'] = "R"
    
    df_16.loc[df_16['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_16.loc[df_16['Num_flight'] == 'FR6275', 'flight_capacity'] = 197
    df_16.loc[df_16['Num_flight'] == 'FR6275', 'Gate'] = "Y"
    
    df_16.loc[df_16['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
    df_16.loc[df_16['Num_flight'] == 'W62378', 'flight_capacity'] = 239
    df_16.loc[df_16['Num_flight'] == 'W62378', 'Gate'] = "U"
    
    df_16.loc[df_16['Num_flight'] == 'LG3596', 'Aircraft'] = 'Boeing 737-800'
    df_16.loc[df_16['Num_flight'] == 'LG3596', 'flight_capacity'] = 189
    df_16.loc[df_16['Num_flight'] == 'LG3596', 'Gate'] = "R"

# %%
df_16.isna().sum()
# Out:
# Unnamed: 0         0
# fecha_scrapeo      0
# Name_company       0
# Num_flight         0
# Name_Destiny       0
# Time_flight        0
# flight_state       0
# flight_capacity    0
# Aircraft           0
# Gate               1
# dtype: int64

# %%
df_16['Aircraft'].unique()
# Out:
# array(['Boeing 737-800', 'Airbus A320', 'Airbus A319', 'Boeing 737 MAX 8',
#        'Airbus A321', 'Boeing 737-8AS', 'Airbus A220-300',
#        'Boeing 737 MAX 8-200', 'Airbus A321neo', 'Airbus A320neo'],
#       dtype=object)

# %%
df_16[(df_16['Aircraft'] == 'Boeing 737-800')].head(10)
# Out:
#     Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 0          0.0  16/11/2025 23-03-05                   Ryanair     FR3166
# 1          1.0  16/11/2025 23-03-05  Norwegian Air Sweden AOC     D81741
# 6          6.0  16/11/2025 23-03-05                   Ryanair     FR3129
# 8          8.0  16/11/2025 23-03-05                   Ryanair     FR1527
# 9          9.0  16/11/2025 23-03-05                   Ryanair     FR2402
# 11        11.0  16/11/2025 23-03-05                   Ryanair     FR6300
# 13        13.0  16/11/2025 23-03-05                   Ryanair     FR2511
# 14        14.0  16/11/2025 23-03-05                   Ryanair     FR8598
# 16        16.0  16/11/2025 23-03-05            Wizz Air Malta     W46330
# 21        21.0  16/11/2025 23-03-05                   Ryanair      FR483
#
#              Name_Destiny Time_flight          flight_state  flight_capacity  \
# 0           Palermo (PMO)       11:00             Ha salido            189.0
# ...

# %%
df_16.loc[df_16['Num_flight'] == 'W64406', 'flight_capacity'] = 230
df_16.loc[df_16['Num_flight'] == 'W61478', 'flight_capacity'] = 230
df_16.loc[df_16['Num_flight'] == 'PC1092', 'flight_capacity'] = 230

# %%
df_16[(df_16['Aircraft'] == 'Boeing 737 MAX 8-200')].head(10)
# Out:
#     Unnamed: 0        fecha_scrapeo    Name_company Num_flight Name_Destiny  \
# 23        23.0  16/11/2025 23-03-05  easyJet Europe     EC7153  Milan (MXP)
#
#    Time_flight          flight_state  flight_capacity              Aircraft  \
# 23       14:05  Retrasado, Ha salido            197.0  Boeing 737 MAX 8-200
#
#    Gate
# 23    R

# %%
df_16.loc[df_16['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_16.loc[df_16['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

# %%
df_16[(df_16['Aircraft'] == 'Boeing 737-8AS')].head(10)
# Out:
#     Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 17        17.0  16/11/2025 23-03-05         Ryanair     FR3121
# 18        18.0  16/11/2025 23-03-05         Easyjet     U28056
# 30        30.0  16/11/2025 23-03-05  easyJet Europe     EC7107
# 45        45.0  16/11/2025 23-03-05  easyJet Europe     EC7173
# 49        49.0  16/11/2025 23-03-05         Ryanair     FR2250
# 63        63.0  16/11/2025 23-03-05  easyJet Europe     EC7103
#
#                          Name_Destiny Time_flight flight_state  \
# 17                     Beauvais (BVA)       13:20    Ha salido
# 18                       London (LGW)       13:25    Ha salido
# 30                       Geneva (GVA)       14:25    Ha salido
# 45                       Berlin (BER)       16:30    Ha salido
# 49                    Marrakech (RAK)       17:00    Ha salido
# 63  Basel, Switzerland/Mulhouse (BSL)       18:45    Ha salido
#
#     flight_capacity        Aircraft Gate
# ...

# %%
df_16.loc[df_16['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_16.loc[df_16['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_16.loc[df_16['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_16.loc[df_16['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_16.loc[df_16['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_16.loc[df_16['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

df_16.loc[df_16['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_16.loc[df_16['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_16.loc[df_16['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_16.loc[df_16['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'

# %%
df_16.shape
# Out:
# (116, 10)

# %%
#df_por_fecha['16/11/2025 23-03-05'] = df_16

# %%
#df_por_fecha

# %%
df_17 = df_por_fecha['17/11/2025 14-06-56'].copy()
df_17
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 116       118.0  17/11/2025 14-06-56         Ryanair     FR3180
# 117       119.0  17/11/2025 14-06-56         Ryanair      FR846
# 118       120.0  17/11/2025 14-06-56  easyJet Europe     EC7105
# 119       121.0  17/11/2025 14-06-56         Ryanair     FR2233
# 120       122.0  17/11/2025 14-06-56         Ryanair     FR8384
# ..          ...                  ...             ...        ...
# 281       283.0  17/11/2025 14-06-56         Ryanair     FR2250
# 282       284.0  17/11/2025 14-06-56         Easyjet     U22706
# 283       285.0  17/11/2025 14-06-56        Wizz Air     W64116
# 284       286.0  17/11/2025 14-06-56         Ryanair     FR8574
# 285       287.0  17/11/2025 14-06-56  Wizz Air Malta     W45154
#
#         Name_Destiny Time_flight          flight_state  flight_capacity  \
# 116       Rome (FCO)       06:00             Ha salido              NaN
# ...

# %%
df_17[(df_17['Aircraft'].isna())].head(20)
# Out:
#      Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 116       118.0  17/11/2025 14-06-56                   Ryanair     FR3180
# 117       119.0  17/11/2025 14-06-56                   Ryanair      FR846
# 118       120.0  17/11/2025 14-06-56            easyJet Europe     EC7105
# 119       121.0  17/11/2025 14-06-56                   Ryanair     FR2233
# 120       122.0  17/11/2025 14-06-56                   Ryanair     FR8384
# 121       123.0  17/11/2025 14-06-56                   Ryanair     FR3078
# 122       124.0  17/11/2025 14-06-56            easyJet Europe     EC8062
# 123       125.0  17/11/2025 14-06-56                   Ryanair     FR3035
# 124       126.0  17/11/2025 14-06-56                   Ryanair     FR8215
# 125       127.0  17/11/2025 14-06-56            easyJet Europe     EC7141
# 126       128.0  17/11/2025 14-06-56            easyJet Europe     EC7151
# 127       129.0  17/11/2025 14-06-56                   Ryanair     FR3028
# ...

# %%
df_17.loc[df_17['Num_flight'] == 'W45154', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'W45154', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'W64116', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'W64116', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'FR8574', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR8574', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR8574', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'U22706', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'U22706', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR1527', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR1527', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR2250', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR2250', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR4587', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR4587', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR3168', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR3168', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3168', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W46020', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W46020', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'RR4084', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'RR4084', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2402', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR2402', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W43406', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W43406', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'W43178', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'EC1380', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR6920', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR6920', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR6275', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR6275', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'

# %%
df_17.loc[df_17['Num_flight'] == 'EI565', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'EI565', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR878', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR878', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'V72165', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'V72165', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR3928', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR3928', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2098', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR2098', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W62378', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'W62378', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'W62378', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'TO4759', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'TO4759', 'flight_capacity'] = 186
df_17.loc[df_17['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'

df_17.loc[df_17['Num_flight'] == 'RR8394', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'RR8394', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR5710', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR5710', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'JU585', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'JU585', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'V72135', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'V72135', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'V72135', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'TW408', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'TW408', 'flight_capacity'] = 246
df_17.loc[df_17['Num_flight'] == 'TW408', 'Aircraft'] = 'Airbus A330-200'

df_17.loc[df_17['Num_flight'] == 'EC1010', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC1010', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'W42940', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W42940', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'EC1956', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR6597', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR6597', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR6341', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR6341', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3807', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR3807', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3185', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR3185', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'

# %%
df_17.loc[df_17['Num_flight'] == '3O378', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == '3O378', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR3080', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR3080', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3080', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W64666', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'W64666', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'V71415', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'V71415', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'U28058', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'LW7351', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'LW7351', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR133', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR133', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'W61706', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W61706', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'LW2896', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'LW2896', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'LW2896', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'EW7521', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'EW7521', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR8231', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR8231', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR9307', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR9307', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR9307', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W61478', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W61478', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'FR3174', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR3174', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC7205', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7205', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR269', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR269', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'RR333', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'RR333', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'HV5134', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'HV5134', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'

# %%
df_17.loc[df_17['Num_flight'] == 'W43686', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'W43686', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR3320', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR3320', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR3320', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR3320', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'EC7199', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7199', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'EC3737', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR2922', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR2922', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR1786', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR1786', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR1786', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W67920', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'W67920', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'V73700', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'V73700', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'EC7173', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'RR6300', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'RR6300', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR5270', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR5270', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'U23372', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'U23372', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'RR6874', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'RR6874', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'RR6874', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR6305', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR6305', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR5718', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR5718', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2507', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR2507', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'

# %%
df_17.loc[df_17['Num_flight'] == 'V73735', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'V73735', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'V73735', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'V73735', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'W43564', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W43564', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'W43564', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR9811', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR9811', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR867', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR867', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'PC1094', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'PC1094', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'W46728', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W46728', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'FR1681', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3146', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR3146', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3146', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == '3O376', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'QS1059', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'QS1059', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC4212', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'W64406', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W64406', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'V71443', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'V71443', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'V71443', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'EC7107', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'BZ251', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'BZ251', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'D85502', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'D85502', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2889', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR2889', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2889', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'BT684', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'BT684', 'flight_capacity'] = 148
df_17.loc[df_17['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'

df_17.loc[df_17['Num_flight'] == 'FR3792', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR3792', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'LS804', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'LS804', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'

# %%
df_17.loc[df_17['Num_flight'] == 'FR3189', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR3189', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'TK608', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'TK608', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR4585', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR4585', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC7153', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'LG3592', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'LG3592', 'flight_capacity'] = 76
df_17.loc[df_17['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'

df_17.loc[df_17['Num_flight'] == 'PC1528', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'PC1528', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'EW521', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'EW521', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'D81741', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'D81741', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'H4264', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'H4264', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR8631', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR8631', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W46330', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'W46330', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'FR3108', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3108', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'W67022', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W67022', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'EC7137', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7137', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'D83657', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'D83657', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'PC1092', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'PC1092', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR774', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR774', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR6973', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR6973', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR8217', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR8217', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR777', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR777', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'

# %%
df_17.loc[df_17['Num_flight'] == 'FR3129', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR3129', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'LS232', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'LS232', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'LS232', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3129', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR3129', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC7197', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7197', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR1279', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR1279', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'TO4755', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'TO4755', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR7539', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR7539', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EI563', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'EI563', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == '3F232', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == '3F232', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == '3F232', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'U22002', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR9045', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR9045', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3039', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3039', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3976', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR3976', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR3121', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3121', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2239', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR2239', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'U28056', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'EC7131', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR7808', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR7808', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'U22324', 'flight_capacity'] = 186
df_17.loc[df_17['Num_flight'] == 'U22324', 'Aircraft'] = 'Airbus A320neo'

# %%
df_17.loc[df_17['Num_flight'] == 'FR3143', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3143', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W61476', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W61476', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'FR6559', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR6559', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR6559', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'W46018', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'W46018', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'TO4751', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'TO4751', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'HV5132', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'HV5132', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'HV5132', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC7656', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'JU581', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'JU581', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR4545', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR4545', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2495', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR2495', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2495', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EW9441', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'EW9441', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EW9441', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'HV6062', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'HV6062', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'HV6062', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR2834', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR2834', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC1030', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EC1030', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'V73573', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'V73573', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'W62376', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'W62376', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'W45088', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'W45088', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'W43176', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'W43176', 'flight_capacity'] = 230
df_17.loc[df_17['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'

df_17.loc[df_17['Num_flight'] == 'EW2521', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'EW2521', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == '3O398', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == '3O398', 'Aircraft'] = 'Airbus A320'

# %%
df_17.loc[df_17['Num_flight'] == 'V72327', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'V72327', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'W62048', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'W62048', 'flight_capacity'] = 239
df_17.loc[df_17['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'

df_17.loc[df_17['Num_flight'] == 'FR6078', 'Gate'] = 'W'
df_17.loc[df_17['Num_flight'] == 'FR6078', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR6078', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'LW12', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'LW12', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'EC1376', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR575', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR575', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR58', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR58', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'D85510', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'D85510', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR1165', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR1165', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'LW1342', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'LW1342', 'flight_capacity'] = 180
df_17.loc[df_17['Num_flight'] == 'LW1342', 'Aircraft'] = 'Airbus A320'

df_17.loc[df_17['Num_flight'] == 'FR3028', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3028', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC7151', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'EC7141', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7141', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR8215', 'Gate'] = 'Y'
df_17.loc[df_17['Num_flight'] == 'FR8215', 'flight_capacity'] = 197
df_17.loc[df_17['Num_flight'] == 'FR8215', 'Aircraft'] = 'Boeing 737 MAX 8'

df_17.loc[df_17['Num_flight'] == 'FR3035', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR3035', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC8062', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR3078', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3078', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR8384', 'Gate'] = 'R'
df_17.loc[df_17['Num_flight'] == 'FR8384', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR8384', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'EC7105', 'flight_capacity'] = 156
df_17.loc[df_17['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'

df_17.loc[df_17['Num_flight'] == 'FR2233', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'

# %%
df_17.loc[df_17['Name_company'] == 'easyJet Europe', 'Gate'] = 'R'
df_17.loc[df_17['Name_company'] == 'EasyJet', 'Gate'] = 'M' # Airbus A319
df_17.loc[df_17['Name_company'] == 'Easyjet', 'Gate'] = 'M'
df_17.loc[df_17['Name_company'] == 'EasyJet Europe', 'Gate'] = 'R'
df_17.loc[df_17['Name_company'] == 'easyJet', 'Gate'] = 'M'

# %%
df_17.loc[df_17['Num_flight'] == 'FR3180', 'Gate'] = 'U'
df_17.loc[df_17['Num_flight'] == 'FR3180', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'

df_17.loc[df_17['Num_flight'] == 'FR846', 'Gate'] = 'S'
df_17.loc[df_17['Num_flight'] == 'FR846', 'flight_capacity'] = 189
df_17.loc[df_17['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'

# %%
df_17.shape
# Out:
# (170, 10)

# %%
df_17.isna().sum()
# Out:
# Unnamed: 0         0
# fecha_scrapeo      0
# Name_company       0
# Num_flight         0
# Name_Destiny       0
# Time_flight        0
# flight_state       0
# flight_capacity    1
# Aircraft           1
# Gate               8
# dtype: int64

# %%
df_17['flight_capacity'].unique()
# Out:
# array([189., 156., 197., 180., 239., 230., 186.,  76., 148.,  nan, 246.])

# %%
df_17['Aircraft'].unique()
# Out:
# array(['Boeing 737-800', 'Airbus A319', 'Boeing 737 MAX 8', 'Airbus A320',
#        'Airbus A321neo', 'Airbus A321', 'Airbus A320neo',
#        'de Havilland Dash 8-400', 'Airbus A220-300', nan,
#        'Airbus A330-200'], dtype=object)

# %%
df_17[(df_17['Aircraft'] == 'Boeing 737-800')]
# Out:
#      Unnamed: 0        fecha_scrapeo Name_company Num_flight     Name_Destiny  \
# 116       118.0  17/11/2025 14-06-56      Ryanair     FR3180       Rome (FCO)
# 117       119.0  17/11/2025 14-06-56      Ryanair      FR846      Milan (BGY)
# 119       121.0  17/11/2025 14-06-56      Ryanair     FR2233  Al Aaroui (NDR)
# 120       122.0  17/11/2025 14-06-56      Ryanair     FR8384   Budapest (BUD)
# 121       123.0  17/11/2025 14-06-56      Ryanair     FR3078     Lisbon (LIS)
# ..          ...                  ...          ...        ...              ...
# 271       273.0  17/11/2025 14-06-56      Ryanair     FR6920     Dublin (DUB)
# 275       277.0  17/11/2025 14-06-56      Ryanair     FR2402    Sevilla (SVQ)
# 276       278.0  17/11/2025 14-06-56         BUZZ     RR4084     Warsaw (WMI)
# 278       280.0  17/11/2025 14-06-56      Ryanair     FR3168  Newcastle (NCL)
# 284       286.0  17/11/2025 14-06-56      Ryanair     FR8574       Rome (FCO)
#
# ...

# %%
# AL ACABAR DE MODIFICAR GUARDARLO EN EL DICCIONARIO 
df_por_fecha['17/11/2025 14-06-56'] = df_17

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_18 = df_por_fecha['18/11/2025 14-12-47'].copy()
df_18
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 286       288.0  18/11/2025 14-12-47  easyJet Europe     EC7105
# 287       289.0  18/11/2025 14-12-47         Ryanair     FR3189
# 288       290.0  18/11/2025 14-12-47         Ryanair     FR2507
# 289       291.0  18/11/2025 14-12-47         Ryanair     FR4545
# 290       292.0  18/11/2025 14-12-47  easyJet Europe     EC8062
# ..          ...                  ...             ...        ...
# 349       351.0  18/11/2025 14-12-47       Transavia     TO4759
# 350       352.0  18/11/2025 14-12-47  easyJet Europe     EC1380
# 351       353.0  18/11/2025 14-12-47         Ryanair     FR6394
# 352       354.0  18/11/2025 14-12-47  Wizz Air Malta     W46020
# 353       355.0  18/11/2025 14-12-47         Ryanair     FR4585
#
#            Name_Destiny Time_flight flight_state  flight_capacity Aircraft  \
# 286        Geneva (GVA)       06:00    Ha salido              NaN      NaN
# ...

# %%
df_18[(df_18['Aircraft'].isna())]
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 286       288.0  18/11/2025 14-12-47  easyJet Europe     EC7105
# 287       289.0  18/11/2025 14-12-47         Ryanair     FR3189
# 288       290.0  18/11/2025 14-12-47         Ryanair     FR2507
# 289       291.0  18/11/2025 14-12-47         Ryanair     FR4545
# 290       292.0  18/11/2025 14-12-47  easyJet Europe     EC8062
# ..          ...                  ...             ...        ...
# 349       351.0  18/11/2025 14-12-47       Transavia     TO4759
# 350       352.0  18/11/2025 14-12-47  easyJet Europe     EC1380
# 351       353.0  18/11/2025 14-12-47         Ryanair     FR6394
# 352       354.0  18/11/2025 14-12-47  Wizz Air Malta     W46020
# 353       355.0  18/11/2025 14-12-47         Ryanair     FR4585
#
#            Name_Destiny Time_flight flight_state  flight_capacity Aircraft  \
# 286        Geneva (GVA)       06:00    Ha salido              NaN      NaN
# ...

# %%
df_18.loc[df_18['Num_flight'] == 'EC7151', 'flight_capacity'] = 156
df_18.loc[df_18['Num_flight'] == 'EC7151', 'Aircraft'] = "Airbus A319"

df_18.loc[df_18['Num_flight'] == 'EC7103', 'flight_capacity'] = 156
df_18.loc[df_18['Num_flight'] == 'EC7103', 'Aircraft'] = "Airbus A319"

df_18.loc[df_18['Num_flight'] == 'EC1956', 'flight_capacity'] = 180
df_18.loc[df_18['Num_flight'] == 'EC1956', 'Aircraft'] = "Airbus A320"

df_18.loc[df_18['Num_flight'] == 'EC1380', 'flight_capacity'] = 180
df_18.loc[df_18['Num_flight'] == 'EC1380', 'Aircraft'] = "Airbus A320"

# %%
df_18.loc[df_18['Num_flight'] == 'FR2507', 'flight_capacity'] = 197
df_18.loc[df_18['Num_flight'] == 'FR3193', 'flight_capacity'] = 189

# %%
df_18.loc[df_18['Name_company'] == 'easyJet Europe', 'Gate'] = 'R'
df_18.loc[df_18['Name_company'] == 'EasyJet', 'Gate'] = 'M' # Airbus A319
df_18.loc[df_18['Name_company'] == 'Easyjet', 'Gate'] = 'M'
df_18.loc[df_18['Name_company'] == 'EasyJet Europe', 'Gate'] = 'R'
df_18.loc[df_18['Name_company'] == 'easyJet', 'Gate'] = 'M'

# %%
if (df_18['fecha_scrapeo'] == "18/11/2025 14-12-47").any():
    
    df_18.loc[df_18['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == '3O642', 'flight_capacity'] = 180
    df_18.loc[df_18['Num_flight'] == '3O642', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'RR4084', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'RR4084', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
    df_18.loc[df_18['Num_flight'] == 'TO4759', 'flight_capacity'] = 186
    df_18.loc[df_18['Num_flight'] == 'TO4759', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR6394', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR6394', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W46020', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'W46020', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR4585', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR4585', 'Gate'] = 'U'

# %%
if (df_18['fecha_scrapeo'] == "18/11/2025 14-12-47").any():
    
    df_18.loc[df_18['Num_flight'] == 'W43176', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'W43176', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3076', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR3076', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-800'
    df_18.loc[df_18['Num_flight'] == 'KU136', 'flight_capacity'] = 235
    df_18.loc[df_18['Num_flight'] == 'KU136', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'BZ251', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'BZ251', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR3792', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR3792', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR3792', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR3792', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR846', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR846', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR1165', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR1165', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR575', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR575', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'HV5134', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'HV5134', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3180', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR3180', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'RR6300', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'RR6300', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR777', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR777', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR2834', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR2834', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W61176', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'W61176', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W61478', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'W61478', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR9015', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR9015', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == 'EW9443', 'flight_capacity'] = 180
    df_18.loc[df_18['Num_flight'] == 'EW9443', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321'
    df_18.loc[df_18['Num_flight'] == 'W64406', 'flight_capacity'] = 230
    df_18.loc[df_18['Num_flight'] == 'W64406', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
    df_18.loc[df_18['Num_flight'] == 'U28058', 'flight_capacity'] = 156
    df_18.loc[df_18['Num_flight'] == 'U28058', 'Gate'] = 'M'
    
    df_18.loc[df_18['Num_flight'] == 'HV6790', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'HV6790', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'HV6790', 'Gate'] = 'U'

# %%
if (df_18['fecha_scrapeo'] == "18/11/2025 14-12-47").any():
    
    df_18.loc[df_18['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W43176', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'W43176', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'EW9441', 'Aircraft'] = 'Airbus A319'
    df_18.loc[df_18['Num_flight'] == 'EW9441', 'flight_capacity'] = 156
    df_18.loc[df_18['Num_flight'] == 'EW9441', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
    df_18.loc[df_18['Num_flight'] == 'JU581', 'flight_capacity'] = 156
    df_18.loc[df_18['Num_flight'] == 'JU581', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == 'LW12', 'flight_capacity'] = 180
    df_18.loc[df_18['Num_flight'] == 'LW12', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W61476', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'W61476', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR1279', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR1279', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR5270', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR5270', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320neo'
    df_18.loc[df_18['Num_flight'] == 'J246', 'flight_capacity'] = 186
    df_18.loc[df_18['Num_flight'] == 'J246', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == 'EI563', 'flight_capacity'] = 180
    df_18.loc[df_18['Num_flight'] == 'EI563', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR58', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR58', 'Gate'] = 'S'
    
    df_18.loc[df_18['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FI597', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FI597', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3108', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR3108', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'D83657', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'D83657', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR8384', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR8384', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'PC1092', 'flight_capacity'] = 239
    df_18.loc[df_18['Num_flight'] == 'PC1092', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR6267', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'FR6267', 'Gate'] = 'Y'
    
    df_18.loc[df_18['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'DY1741', 'flight_capacity'] = 197
    df_18.loc[df_18['Num_flight'] == 'DY1741', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == '5F5512', 'Aircraft'] = 'Airbus A321'
    df_18.loc[df_18['Num_flight'] == '5F5512', 'flight_capacity'] = 230
    df_18.loc[df_18['Num_flight'] == '5F5512', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'LG3592', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'LG3592', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'LG3592', 'Gate'] = 'U'
    
    df_18.loc[df_18['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR2239', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR2239', 'Gate'] = 'W'

# %%
if (df_18['fecha_scrapeo'] == "18/11/2025 14-12-47").any():
    
    df_18.loc[df_18['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'# Airbus A319
    df_18.loc[df_18['Num_flight'] == 'EC7105', 'flight_capacity'] = 156 # FR3189 	
    
    df_18.loc[df_18['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3189', 'flight_capacity'] = 189
    df_18.loc[df_18['Num_flight'] == 'FR3189', 'Gate'] = 'W'
    
    df_18.loc[df_18['Num_flight'] == 'FR2507', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR2507', 'flight_capacity'] = 197
    
    df_18.loc[df_18['Num_flight'] == 'FR4545', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_18.loc[df_18['Num_flight'] == 'FR4545', 'flight_capacity'] = 197
    
    df_18.loc[df_18['Num_flight'] == 'EC8062', 'flight_capacity'] = 156
    df_18.loc[df_18['Num_flight'] == 'EC8062', 'Aircraft'] =  'Airbus A319' # FR3166
    
    df_18.loc[df_18['Num_flight'] == 'FR3166', 'Gate'] = 'S'
    df_18.loc[df_18['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3166', 'flight_capacity'] = 189 # FR5718
    
    df_18.loc[df_18['Num_flight'] == 'FR5718', 'Gate'] = 'U' 
    df_18.loc[df_18['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR5718', 'flight_capacity'] = 189 # FR3193
    
    df_18.loc[df_18['Num_flight'] == 'FR3193', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'FR3193', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR5718', 'flight_capacity'] = 189
    
    df_18.loc[df_18['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == 'EC3737', 'flight_capacity'] = 180
    
    df_18.loc[df_18['Num_flight'] == 'FR133', 'Gate'] = 'S'
    df_18.loc[df_18['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR133', 'flight_capacity'] = 189
    
    df_18.loc[df_18['Num_flight'] == 'W43938', 'Gate'] = 'W'
    df_18.loc[df_18['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == 'W43938', 'flight_capacity'] = 180
    
    df_18.loc[df_18['Num_flight'] == 'W62048', 'Gate'] = 'S'
    df_18.loc[df_18['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W62048', 'flight_capacity'] = 239
    
    df_18.loc[df_18['Num_flight'] == 'FR3035', 'Gate'] = 'R'
    df_18.loc[df_18['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3035', 'flight_capacity'] = 189
    
    df_18.loc[df_18['Num_flight'] == 'FR3807', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737-800'
    df_18.loc[df_18['Num_flight'] == 'FR3807', 'flight_capacity'] = 189
    
    df_18.loc[df_18['Num_flight'] == 'W61914', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W61914', 'flight_capacity'] = 239
    
    df_18.loc[df_18['Num_flight'] == 'W62376', 'Gate'] = 'S'
    df_18.loc[df_18['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W62376', 'flight_capacity'] = 239
    
    df_18.loc[df_18['Num_flight'] == 'TO4751', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'TO4751', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'TO4751', 'flight_capacity'] = 239 #TO4751
    
    df_18.loc[df_18['Num_flight'] == 'W42938', 'Gate'] = 'U'
    df_18.loc[df_18['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
    df_18.loc[df_18['Num_flight'] == 'W42938', 'flight_capacity'] = 239 #3O378
    
    df_18.loc[df_18['Num_flight'] == '3O378', 'Gate'] = 'Y'
    df_18.loc[df_18['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
    df_18.loc[df_18['Num_flight'] == '3O378', 'flight_capacity'] = 180

# %%
df_18.isna().sum()
# Out:
# Unnamed: 0         0
# fecha_scrapeo      0
# Name_company       0
# Num_flight         0
# Name_Destiny       0
# Time_flight        0
# flight_state       0
# flight_capacity    0
# Aircraft           0
# Gate               0
# dtype: int64

# %%
#df_18.tail(60)

# %%
df_18
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 286       288.0  18/11/2025 14-12-47  easyJet Europe     EC7105
# 287       289.0  18/11/2025 14-12-47         Ryanair     FR3189
# 288       290.0  18/11/2025 14-12-47         Ryanair     FR2507
# 289       291.0  18/11/2025 14-12-47         Ryanair     FR4545
# 290       292.0  18/11/2025 14-12-47  easyJet Europe     EC8062
# ..          ...                  ...             ...        ...
# 349       351.0  18/11/2025 14-12-47       Transavia     TO4759
# 350       352.0  18/11/2025 14-12-47  easyJet Europe     EC1380
# 351       353.0  18/11/2025 14-12-47         Ryanair     FR6394
# 352       354.0  18/11/2025 14-12-47  Wizz Air Malta     W46020
# 353       355.0  18/11/2025 14-12-47         Ryanair     FR4585
#
#            Name_Destiny Time_flight flight_state  flight_capacity  \
# 286        Geneva (GVA)       06:00    Ha salido            156.0
# ...

# %%
df_por_fecha['18/11/2025 14-12-47'] = df_18.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_19 = df_por_fecha['19/11/2025 14-33-06'].copy()
df_19
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 354       356.0  19/11/2025 14-33-06         Ryanair     FR2918
# 355       357.0  19/11/2025 14-33-06         Ryanair     FR3185
# 356       358.0  19/11/2025 14-33-06         Ryanair     FR9406
# 357       359.0  19/11/2025 14-33-06  easyJet Europe     EC7105
# 358       360.0  19/11/2025 14-33-06         Ryanair      FR483
# ..          ...                  ...             ...        ...
# 433       435.0  19/11/2025 14-33-06         Easyjet     U22326
# 434       436.0  19/11/2025 14-33-06  easyJet Europe     EC1380
# 435       437.0  19/11/2025 14-33-06  Wizz Air Malta     W43406
# 436       438.0  19/11/2025 14-33-06  Wizz Air Malta     W46020
# 437       439.0  19/11/2025 14-33-06         Ryanair     FR6394
#
#           Name_Destiny Time_flight          flight_state  flight_capacity  \
# 354     Brussels (BRU)       06:05             Ha salido              NaN
# ...

# %%
df_19.loc[df_19['Name_company'] == 'easyJet Europe', 'Gate'] = 'R'
df_19.loc[df_19['Name_company'] == 'EasyJet', 'Gate'] = 'M' # Airbus A319
df_19.loc[df_19['Name_company'] == 'Easyjet', 'Gate'] = 'M'
df_19.loc[df_19['Name_company'] == 'EasyJet Europe', 'Gate'] = 'R'
df_19.loc[df_19['Name_company'] == 'easyJet', 'Gate'] = 'M'

# %%
df_19.isna().sum()
# Out:
# Unnamed: 0          0
# fecha_scrapeo       0
# Name_company        0
# Num_flight          0
# Name_Destiny        0
# Time_flight         0
# flight_state        0
# flight_capacity    84
# Aircraft           84
# Gate               72
# dtype: int64

# %%
df_19[(df_19['Gate'].isna())].tail(20)
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 414       416.0  19/11/2025 14-33-06           Ryanair     FR8231
# 415       417.0  19/11/2025 14-33-06          Wizz Air     W61478
# 416       418.0  19/11/2025 14-33-06           Ryanair     FR1165
# 417       419.0  19/11/2025 14-33-06           Ryanair     FR9334
# 418       420.0  19/11/2025 14-33-06           Ryanair     FR1342
# 419       421.0  19/11/2025 14-33-06         Eurowings     EW9443
# 420       422.0  19/11/2025 14-33-06           Ryanair      FR133
# 421       423.0  19/11/2025 14-33-06         Transavia     HV6064
# 423       425.0  19/11/2025 14-33-06          Wizz Air     W61706
# 424       426.0  19/11/2025 14-33-06           Ryanair     FR3143
# 425       427.0  19/11/2025 14-33-06           Ryanair       FR58
# 426       428.0  19/11/2025 14-33-06              BUZZ     RR5246
# 428       430.0  19/11/2025 14-33-06  Air Arabia Maroc      3O378
# ...

# %%
df_19.loc[df_19['Num_flight'] == 'FR2918', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'FR3185', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3185', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR9406', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'FR483', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR483', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'EC7193', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EC7193', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'FR2239', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'FR3028', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'FR3108', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR3108', 'flight_capacity'] = 197

# %%
df_19.loc[df_19['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EC8062', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'EC3737', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'EC7161', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EC7161', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'W43176', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_19.loc[df_19['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_19.loc[df_19['Num_flight'] == 'W62376', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'RR8384', 'Gate'] = 'R'
df_19.loc[df_19['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == '3O376', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'W42940', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W42940', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'EW9441', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'EW9441', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EW9441', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'FR2834', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR2834', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'FR4545', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'RR3049', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'RR3049', 'flight_capacity'] = 197

# %%
df_19.loc[df_19['Num_flight'] == '3O642', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == '3O642', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'HV5132', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'HV5132', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'FR3078', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'W61476', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321'
df_19.loc[df_19['Num_flight'] == 'W61476', 'flight_capacity'] = 230

df_19.loc[df_19['Num_flight'] == 'FR3039', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3039', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'BT878', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'BT878', 'Aircraft'] = 'Airbus A220-300'
df_19.loc[df_19['Num_flight'] == 'BT878', 'flight_capacity'] = 148

df_19.loc[df_19['Num_flight'] == 'FR6267', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR6267', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'U5406', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'U5406', 'Aircraft'] = 'Boeing 737-700'
df_19.loc[df_19['Num_flight'] == 'U5406', 'flight_capacity'] = 149

df_19.loc[df_19['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320neo'
df_19.loc[df_19['Num_flight'] == 'U22704', 'flight_capacity'] = 186

df_19.loc[df_19['Num_flight'] == 'FR2507', 'Gate'] = 'R'
df_19.loc[df_19['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR2507', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'EI563', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'EI563', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'FR575', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR575', 'flight_capacity'] = 189

# %%
df_19.loc[df_19['Num_flight'] == 'FR9925', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR9925', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR9925', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'PC1092', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'PC1092', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'FR6597', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR6597', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'FR3792', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'H4264', 'Gate'] = 'R'
df_19.loc[df_19['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'H4264', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'DY1741', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'EW521', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A321'
df_19.loc[df_19['Num_flight'] == 'EW521', 'flight_capacity'] = 230

df_19.loc[df_19['Num_flight'] == 'LG3592', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'
df_19.loc[df_19['Num_flight'] == 'LG3592', 'flight_capacity'] = 76

df_19.loc[df_19['Num_flight'] == 'TK608', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'TK608', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'BZ251', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'BZ251', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'BZ251', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'D83659', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'D83659', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'EW2521', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EW2521', 'flight_capacity'] = 156

# %%
df_19.loc[df_19['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR777', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'FR12', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR12', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'PC1094', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321'
df_19.loc[df_19['Num_flight'] == 'PC1094', 'flight_capacity'] = 230

df_19.loc[df_19['Num_flight'] == 'V71415', 'Gate'] = 'R'
df_19.loc[df_19['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'FR3035', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR3035', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_19.loc[df_19['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_19.loc[df_19['Num_flight'] == 'FR3928', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'FR5718', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'W67920', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W67920', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'FR4585', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'E9803', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'E9803', 'Aircraft'] = 'Airbus A350-900'
df_19.loc[df_19['Num_flight'] == 'E9803', 'flight_capacity'] = 432

df_19.loc[df_19['Num_flight'] == 'FR3180', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'FR8231', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'W61478', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'FR1165', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR1165', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'FR9334', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'FR9334', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR9334', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

# %%
df_19.loc[df_19['Num_flight'] == 'FR1342', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'EW9443', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'EW9443', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'FR133', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR133', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'HV6064', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'HV6064', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'HV6064', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'U28058', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'W61706', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W61706', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'FR3143', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR3143', 'flight_capacity'] = 189

df_19.loc[df_19['Num_flight'] == 'FR58', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'FR58', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'RR5246', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'RR5246', 'Aircraft'] = 'Boeing 737 MAX 8'
df_19.loc[df_19['Num_flight'] == 'RR5246', 'flight_capacity'] = 197

df_19.loc[df_19['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == '3O378', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == '3O378', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'TW408', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'TW408', 'Aircraft'] = 'BOEING 777-300ER'
df_19.loc[df_19['Num_flight'] == 'TW408', 'flight_capacity'] = 294

df_19.loc[df_19['Num_flight'] == 'JU585', 'Gate'] = 'Y'
df_19.loc[df_19['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'JU585', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'TO4759', 'Gate'] = 'S'
df_19.loc[df_19['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_19.loc[df_19['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_19.loc[df_19['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A319'
df_19.loc[df_19['Num_flight'] == 'U22326', 'flight_capacity'] = 156

df_19.loc[df_19['Num_flight'] == 'W43406', 'Gate'] = 'U'
df_19.loc[df_19['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_19.loc[df_19['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_19.loc[df_19['Num_flight'] == 'W46020', 'Gate'] = 'R'
df_19.loc[df_19['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_19.loc[df_19['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_19.loc[df_19['Num_flight'] == 'FR6394', 'Gate'] = 'W'
df_19.loc[df_19['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737-800'
df_19.loc[df_19['Num_flight'] == 'FR6394', 'flight_capacity'] = 189

# %%
df_19['Aircraft'].unique()
# Out:
# array(['Boeing 737-800', 'Airbus A319', 'Boeing 737 MAX 8', 'Airbus A320',
#        'Airbus A321', 'Airbus A321neo', 'Airbus A220-300',
#        'Boeing 737-700', 'Airbus A320neo', 'de Havilland Dash 8-400',
#        'Airbus A350-900', 'BOEING 777-300ER'], dtype=object)

# %%
df_19['Gate'].unique()
# Out:
# array(['U', 'Y', nan, 'R', 'S', 'W', 'M'], dtype=object)

# %%
df_19['flight_capacity'].unique()
# Out:
# array([189., 156., 197., 180., 230., 239., 148., 149., 186.,  76., 432.,
#        294.])

# %%
df_19[(df_19['Gate'] == 'U')]
# Out:
#      Unnamed: 0        fecha_scrapeo           Name_company Num_flight  \
# 354       356.0  19/11/2025 14-33-06                Ryanair     FR2918
# 358       360.0  19/11/2025 14-33-06                Ryanair      FR483
# 361       363.0  19/11/2025 14-33-06                Ryanair     FR3028
# 362       364.0  19/11/2025 14-33-06                Ryanair     FR3108
# 366       368.0  19/11/2025 14-33-06         Wizz Air Malta     W43176
# 367       369.0  19/11/2025 14-33-06               Wizz Air     W62376
# 372       374.0  19/11/2025 14-33-06                Ryanair     FR2834
# 373       375.0  19/11/2025 14-33-06                Ryanair     FR4545
# 374       376.0  19/11/2025 14-33-06                   BUZZ     RR3049
# 376       378.0  19/11/2025 14-33-06              Transavia     HV5132
# 380       382.0  19/11/2025 14-33-06             Air Baltic      BT878
# 386       388.0  19/11/2025 14-33-06                Ryanair      FR575
# ...

# %%
df_19[(df_19['Aircraft'] == 'BOEING 777-300ER')]
# Out:
#      Unnamed: 0        fecha_scrapeo Name_company Num_flight  \
# 429       431.0  19/11/2025 14-33-06    T'Way Air      TW408
#
#             Name_Destiny Time_flight          flight_state  flight_capacity  \
# 429  Seoul/Incheon (ICN)       20:30  Retrasado, Ha salido            294.0
#
#              Aircraft Gate
# 429  BOEING 777-300ER    Y

# %%
df_por_fecha['19/11/2025 14-33-06'] = df_19.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_20 = df_por_fecha['20/11/2025 14-38-34'].copy()
df_20
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 438       440.0  20/11/2025 14-38-34         Ryanair     FR8215
# 439       441.0  20/11/2025 14-38-34         Ryanair     FR2918
# 440       442.0  20/11/2025 14-38-34  easyJet Europe     EC7105
# 441       443.0  20/11/2025 14-38-34         Ryanair     FR3976
# 442       444.0  20/11/2025 14-38-34  easyJet Europe     EC7191
# ..          ...                  ...             ...        ...
# 563       566.0  20/11/2025 14-38-34            BUZZ     RR3035
# 564       567.0  20/11/2025 14-38-34            BUZZ     RR4084
# 565       568.0  20/11/2025 14-38-34  Wizz Air Malta     W46020
# 566       569.0  20/11/2025 14-38-34        Wizz Air     W64116
# 567       570.0  20/11/2025 14-38-34  Wizz Air Malta     W45154
#
#        Name_Destiny Time_flight          flight_state  flight_capacity  \
# 438    London (STN)       06:00             Ha salido              NaN
# ...

# %%
df20 = pd.read_csv("vuelos_limpio20.csv") 
df20.head(10)
# Out:
#    Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 0           0  20/11/2025 14-38-34         Ryanair     FR8215
# 1           1  20/11/2025 14-38-34         Ryanair     FR2918
# 2           2  20/11/2025 14-38-34  easyJet Europe     EC7105
# 3           3  20/11/2025 14-38-34         Ryanair     FR3976
# 4           4  20/11/2025 14-38-34  easyJet Europe     EC7191
# 5           5  20/11/2025 14-38-34         Ryanair     FR3049
# 6           6  20/11/2025 14-38-34         Ryanair     FR3028
# 7           7  20/11/2025 14-38-34    Lauda Europe     LW2495
# 8           8  20/11/2025 14-38-34         Ryanair      FR133
# 9           9  20/11/2025 14-38-34  easyJet Europe     EC7101
#
#                         Name_Destiny Time_flight flight_state  \
# 0                       London (STN)       06:00    Ha salido
# 1                     Brussels (BRU)       06:05    Ha salido
# 2                       Geneva (GVA)       06:10    Ha salido
# ...

# %%
df20.loc[df20['Num_flight'] == 'W43406', 'flight_capacity'] = 186

# %%
df20.loc[df20['Num_flight'] == 'W62376', 'flight_capacity'] = 239

# %%
df20.loc[df20['Num_flight'] == 'V73735', 'flight_capacity'] = 156
df20.loc[df20['Num_flight'] == 'V73573', 'flight_capacity'] = 156
df20.loc[df20['Num_flight'] == 'V72165', 'flight_capacity'] = 156

# %%
df_20 = df20

# %%
df_20
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 0             0  20/11/2025 14-38-34         Ryanair     FR8215
# 1             1  20/11/2025 14-38-34         Ryanair     FR2918
# 2             2  20/11/2025 14-38-34  easyJet Europe     EC7105
# 3             3  20/11/2025 14-38-34         Ryanair     FR3976
# 4             4  20/11/2025 14-38-34  easyJet Europe     EC7191
# ..          ...                  ...             ...        ...
# 125         126  20/11/2025 14-38-34            BUZZ     RR3035
# 126         127  20/11/2025 14-38-34            BUZZ     RR4084
# 127         128  20/11/2025 14-38-34  Wizz Air Malta     W46020
# 128         129  20/11/2025 14-38-34        Wizz Air     W64116
# 129         130  20/11/2025 14-38-34  Wizz Air Malta     W45154
#
#        Name_Destiny Time_flight flight_state  flight_capacity  \
# 0      London (STN)       06:00    Ha salido            189.0
# 1    Brussels (BRU)       06:05    Ha salido            189.0
# ...

# %%
df_20 = df_20.rename(columns={'flight_Aircraft': 'Aircraft'})

# %%
df_por_fecha['20/11/2025 14-38-34'] = df_20.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_21 = df_por_fecha['21/11/2025 14-58-40'].copy()
df_21
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 568       571.0  21/11/2025 14-58-40  easyJet Europe     EC7105
# 569       572.0  21/11/2025 14-58-40         Ryanair     FR8183
# 570       573.0  21/11/2025 14-58-40         Ryanair     FR8231
# 571       574.0  21/11/2025 14-58-40         Ryanair      FR777
# 572       575.0  21/11/2025 14-58-40         Ryanair      FR846
# ..          ...                  ...             ...        ...
# 731       736.0  21/11/2025 14-58-40        Wizz Air     W64116
# 732       737.0  21/11/2025 14-58-40         Ryanair     FR3080
# 733       738.0  21/11/2025 14-58-40  Wizz Air Malta     W45154
# 734       739.0  21/11/2025 14-58-40        Wizz Air     W61706
# 735       740.0  21/11/2025 14-58-40         Ryanair     FR9814
#
#        Name_Destiny Time_flight          flight_state  flight_capacity  \
# 568    Geneva (GVA)       06:10             Ha salido              NaN
# ...

# %%
df_21.loc[df_21['Name_company'] == 'easyJet Europe', 'Gate'] = 'R'
df_21.loc[df_21['Name_company'] == 'EasyJet', 'Gate'] = 'M' # Airbus A319
df_21.loc[df_21['Name_company'] == 'Easyjet', 'Gate'] = 'M'
df_21.loc[df_21['Name_company'] == 'EasyJet Europe', 'Gate'] = 'R'
df_21.loc[df_21['Name_company'] == 'easyJet', 'Gate'] = 'M'

# %%
df_21[(df_21['Aircraft'].isna())].shape
# Out:
# (168, 10)

# %%
df_21[(df_21['Aircraft'].isna())].head(40)
# Out:
#      Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 568       571.0  21/11/2025 14-58-40            easyJet Europe     EC7105
# 569       572.0  21/11/2025 14-58-40                   Ryanair     FR8183
# 570       573.0  21/11/2025 14-58-40                   Ryanair     FR8231
# 571       574.0  21/11/2025 14-58-40                   Ryanair      FR777
# 572       575.0  21/11/2025 14-58-40                   Ryanair      FR846
# 573       576.0  21/11/2025 14-58-40                   Ryanair      FR133
# 574       577.0  21/11/2025 14-58-40                   Ryanair     FR4545
# 575       578.0  21/11/2025 14-58-40            easyJet Europe     EC7101
# 576       579.0  21/11/2025 14-58-40            easyJet Europe     EC7199
# 577       580.0  21/11/2025 14-58-40              Lauda Europe     LW2889
# 578       581.0  21/11/2025 14-58-40  Norwegian Air Sweden AOC     D85502
# 579       582.0  21/11/2025 14-58-40                   Ryanair     FR3976
# ...

# %%
df_21.loc[df_21['Num_flight'] == 'FR1342', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR5718', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'V73735', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'V73735', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'W46728', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W46728', 'flight_capacity'] = 239

# %%
df_21.loc[df_21['Num_flight'] == 'FR878', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR878', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR483', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR483', 'flight_capacity'] = 197

#df_21.loc[df_21['Num_flight'] == 'V73735', 'Gate'] = 'U'
#df_21.loc[df_21['Num_flight'] == 'V73735', 'Aircraft'] = 'Boeing 737 MAX 8'
#df_21.loc[df_21['Num_flight'] == 'V73735', 'flight_capacity'] = 197

# %%
df_21.loc[df_21['Num_flight'] == 'FR774', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR774', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'TO4755', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_21.loc[df_21['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_21.loc[df_21['Num_flight'] == 'FR8215', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR8215', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR8215', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'V71443', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'V71443', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'V71443', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'W64406', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'FR2507', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR867', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR867', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'QS1059', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'QS1059', 'flight_capacity'] = 189

# %%
df_21.loc[df_21['Num_flight'] == 'RR3049', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'RR3049', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'FI597', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FI597', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'LS232', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'LS232', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'LS232', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'EC8064', 'Gate'] = 'M'
df_21.loc[df_21['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'FR4585', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'D83657', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'D83657', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'FR575', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR58', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'PC1092', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_21.loc[df_21['Num_flight'] == 'PC1092', 'flight_capacity'] = 230

df_21.loc[df_21['Num_flight'] == 'FR6874', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR6874', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'W67022', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'W46330', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321'
df_21.loc[df_21['Num_flight'] == 'W46330', 'flight_capacity'] = 230

df_21.loc[df_21['Num_flight'] == 'DY1741', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'PC1528', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'PC1528', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'TK608', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'TK608', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR6078', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'FR6078', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR6078', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'LS804', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR3180', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'BT684', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_21.loc[df_21['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_21.loc[df_21['Num_flight'] == 'S4507', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'S4507', 'Aircraft'] = 'Airbus A320neo'
df_21.loc[df_21['Num_flight'] == 'S4507', 'flight_capacity'] = 186

df_21.loc[df_21['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'LW7351', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

# %%
df_21.loc[df_21['Num_flight'] == 'FR6920', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR6920', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'HV5132', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'HV5132', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'EW7521', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'EW7521', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'W61476', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'FR2239', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320neo'
df_21.loc[df_21['Num_flight'] == 'U22002', 'flight_capacity'] = 186

df_21.loc[df_21['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'FR6267', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'HV6064', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'HV6064', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'HV6064', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'U22704', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'FR5270', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR5270', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'RR8384', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR3166', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR269', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == '3F232', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == '3F232', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == '3F232', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'EI563', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'EI563', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'FR3121', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR3121', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'LW2896', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'LW2896', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'LW2896', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'EC7141', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7141', 'flight_capacity'] = 156

# %%
df_21.loc[df_21['Num_flight'] == 'FR5752', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'FR1165', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR1165', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'W62048', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'EC3737', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == '3O374', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == '3O374', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == '3O374', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'LW12', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'W43176', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_21.loc[df_21['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_21.loc[df_21['Num_flight'] == 'W45088', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321'
df_21.loc[df_21['Num_flight'] == 'W45088', 'flight_capacity'] = 230

df_21.loc[df_21['Num_flight'] == 'W62376', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'FR3028', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR3320', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'HV6788', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'U26654', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'U26654', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == '3O378', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == '3O378', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_21.loc[df_21['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_21.loc[df_21['Num_flight'] == 'JU581', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'JU581', 'flight_capacity'] = 157

df_21.loc[df_21['Num_flight'] == 'FR9015', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR9015', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'W46018', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_21.loc[df_21['Num_flight'] == 'W45088', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321'
df_21.loc[df_21['Num_flight'] == 'W45088', 'flight_capacity'] = 230

df_21.loc[df_21['Num_flight'] == 'W62376', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_21.loc[df_21['Num_flight'] == 'W62376', 'flight_capacity'] = 239

# %%
df_21.loc[df_21['Num_flight'] == 'EC7105', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'FR8183', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'FR8183', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR8183', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR8231', 'Gate'] = 'Y'
df_21.loc[df_21['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR777', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR846', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR133', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR4545', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'EC7199', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC7199', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'FR4545', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_21.loc[df_21['Num_flight'] == 'LW2889', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'LW2889', 'Aircraft'] = 'Airbus A320'
df_21.loc[df_21['Num_flight'] == 'LW2889', 'flight_capacity'] = 180

df_21.loc[df_21['Num_flight'] == 'D85502', 'Gate'] = 'U'
df_21.loc[df_21['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR3976', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR3976', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR3185', 'Gate'] = 'W'
df_21.loc[df_21['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR3185', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'FR6973', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737-800'
df_21.loc[df_21['Num_flight'] == 'FR6973', 'flight_capacity'] = 189

df_21.loc[df_21['Num_flight'] == 'EC1376', 'Gate'] = 'R'
df_21.loc[df_21['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_21.loc[df_21['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_21.loc[df_21['Num_flight'] == 'FR2834', 'Gate'] = 'S'
df_21.loc[df_21['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
df_21.loc[df_21['Num_flight'] == 'FR2834', 'flight_capacity'] = 197

# %%
if (df_21['fecha_scrapeo'] == "21/11/2025 14-58-40").any():
    df_21.loc[df_21['Num_flight'] == 'FR6353', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'FR6353', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR6353', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'FR6341', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR6341', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'HV5134', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'HV5134', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'V73573', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'V73573', 'flight_capacity'] = 156
        
    df_21.loc[df_21['Num_flight'] == 'FR3076', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR3076', 'flight_capacity'] = 197
        
    df_21.loc[df_21['Num_flight'] == 'W67920', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W67920', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'FR4587', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR4587', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'FR4587', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR4587', 'flight_capacity'] = 189

    df_21.loc[df_21['Num_flight'] == 'V73700', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'V73700', 'flight_capacity'] = 180

    df_21.loc[df_21['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

    df_21.loc[df_21['Num_flight'] == 'FR3129', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR3129', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'W43564', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'W43564', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'W43564', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == 'FR6985', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR6985', 'flight_capacity'] = 189

    df_21.loc[df_21['Num_flight'] == 'FR2925', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'FR2925', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR2925', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'D85510', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'D85510', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'FR9045', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

    df_21.loc[df_21['Num_flight'] == 'PC1094', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321'
    df_21.loc[df_21['Num_flight'] == 'PC1094', 'flight_capacity'] = 230

# %%
if (df_21['fecha_scrapeo'] == "21/11/2025 14-58-40").any():
    df_21.loc[df_21['Num_flight'] == 'V71415', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'V71415', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == 'EW2521', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A321'
    df_21.loc[df_21['Num_flight'] == 'EW2521', 'flight_capacity'] = 230
    
    df_21.loc[df_21['Num_flight'] == 'FR6374', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR6374', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR6374', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'U28058', 'flight_capacity'] = 156
        
    df_21.loc[df_21['Num_flight'] == 'LW7362', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'LW7362', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'LW7362', 'flight_capacity'] = 180
            
    df_21.loc[df_21['Num_flight'] == 'FR2330', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'FR2330', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR2330', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'EW9443', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'EW9443', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'V72165', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'V72165', 'flight_capacity'] = 156
    
    df_21.loc[df_21['Num_flight'] == 'RR6330', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'RR6330', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'RR6330', 'flight_capacity'] = 189
        
    df_21.loc[df_21['Num_flight'] == 'FR3078', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR3078', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'FR149', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR149', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

    df_21.loc[df_21['Num_flight'] == 'W61478', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W61478', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'FR3189', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

    df_21.loc[df_21['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

    df_21.loc[df_21['Num_flight'] == 'FR2098', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR2098', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'W43686', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'W43686', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == '5F5512', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == '5F5512', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == '5F5512', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == '3O398', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == '3O398', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == '3O398', 'flight_capacity'] = 180
        
    df_21.loc[df_21['Num_flight'] == 'EC7205', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'EC7205', 'flight_capacity'] = 156

# %%
if (df_21['fecha_scrapeo'] == "21/11/2025 14-58-40").any():
    
    df_21.loc[df_21['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'U22326', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == 'TO4759', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
    df_21.loc[df_21['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

    df_21.loc[df_21['Num_flight'] == 'FR5710', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR5710', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'W62378', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W62378', 'flight_capacity'] = 239

    df_21.loc[df_21['Num_flight'] == 'LG3592', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'LG3592', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'LG3592', 'flight_capacity'] = 189

    df_21.loc[df_21['Num_flight'] == 'RR1786', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'RR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'RR1786', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'JU585', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
    df_21.loc[df_21['Num_flight'] == 'JU585', 'flight_capacity'] = 157
    
    df_21.loc[df_21['Num_flight'] == 'FR8631', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR8631', 'flight_capacity'] = 189
        
    df_21.loc[df_21['Num_flight'] == 'FR7539', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR7539', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'V72135', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'V72135', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'V72135', 'flight_capacity'] = 180
        
    df_21.loc[df_21['Num_flight'] == 'TW408', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'TW408', 'Aircraft'] = 'Airbus A330-200'
    df_21.loc[df_21['Num_flight'] == 'TW408', 'flight_capacity'] = 246
    
    df_21.loc[df_21['Num_flight'] == 'FR3792', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR3792', 'flight_capacity'] = 189
        
    df_21.loc[df_21['Num_flight'] == 'W42940', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W42940', 'flight_capacity'] = 239

    df_21.loc[df_21['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

    df_21.loc[df_21['Num_flight'] == 'W62096', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W62096', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'FR6305', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR6305', 'flight_capacity'] = 189
        
    df_21.loc[df_21['Num_flight'] == 'FR6275', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR6275', 'flight_capacity'] = 197
            
    df_21.loc[df_21['Num_flight'] == 'FR2402', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR2402', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'FR1527', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR1527', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
    df_21.loc[df_21['Num_flight'] == 'EC7656', 'flight_capacity'] = 230
    
    df_21.loc[df_21['Num_flight'] == 'W64666', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
    df_21.loc[df_21['Num_flight'] == 'W64666', 'flight_capacity'] = 230

# %%
if (df_21['fecha_scrapeo'] == "21/11/2025 14-58-40").any():
    df_21.loc[df_21['Num_flight'] == 'FR9814', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'FR9814', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR9814', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'W61706', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W61706', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'W45154', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'
    df_21.loc[df_21['Num_flight'] == 'W45154', 'flight_capacity'] = 230
    
    df_21.loc[df_21['Num_flight'] == 'FR3080', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'FR3080', 'Aircraft'] = 'Boeing 737 MAX 8'
    df_21.loc[df_21['Num_flight'] == 'FR3080', 'flight_capacity'] = 197
    
    df_21.loc[df_21['Num_flight'] == 'W64116', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W64116', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'FR2250', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR2250', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'FR6597', 'Gate'] = 'W'
    df_21.loc[df_21['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR6597', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'FR2495', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'FR2495', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR2495', 'flight_capacity'] = 189
    df_21.loc[df_21['Num_flight'] == 'FR9811', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR9811', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'FR8669', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR8669', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'W46020', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
    df_21.loc[df_21['Num_flight'] == 'W46020', 'flight_capacity'] = 239
    
    df_21.loc[df_21['Num_flight'] == 'FR7808', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR7808', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'RR6944', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'RR6944', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'W43406', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320neo'
    df_21.loc[df_21['Num_flight'] == 'W43406', 'flight_capacity'] = 186
    
    df_21.loc[df_21['Num_flight'] == 'W43178', 'Gate'] = 'U'
    df_21.loc[df_21['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
    df_21.loc[df_21['Num_flight'] == 'W43178', 'flight_capacity'] = 230
    
    df_21.loc[df_21['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'EC1380', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == 'FR3174', 'Gate'] = 'R'
    df_21.loc[df_21['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'FR3174', 'flight_capacity'] = 189
    
    df_21.loc[df_21['Num_flight'] == 'U23374', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'U23374', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == 'EI565', 'Gate'] = 'Y'
    df_21.loc[df_21['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
    df_21.loc[df_21['Num_flight'] == 'EI565', 'flight_capacity'] = 180
    
    df_21.loc[df_21['Num_flight'] == 'RR8394', 'Gate'] = 'S'
    df_21.loc[df_21['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737-800'
    df_21.loc[df_21['Num_flight'] == 'RR8394', 'flight_capacity'] = 189

# %%
df_21.isna().sum()
# Out:
# Unnamed: 0         0
# fecha_scrapeo      0
# Name_company       0
# Num_flight         0
# Name_Destiny       0
# Time_flight        0
# flight_state       0
# flight_capacity    0
# Aircraft           0
# Gate               0
# dtype: int64

# %%
df_21['Aircraft'].unique()
# Out:
# array(['Airbus A319', 'Boeing 737-800', 'Boeing 737 MAX 8', 'Airbus A320',
#        'Airbus A321neo', 'Airbus A321', 'Airbus A320neo',
#        'Airbus A220-300', 'Airbus A330-200'], dtype=object)

# %%
df_21[(df_21['Gate'] == 'R')]
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 568       571.0  21/11/2025 14-58-40  easyJet Europe     EC7105
# 575       578.0  21/11/2025 14-58-40  easyJet Europe     EC7101
# 576       579.0  21/11/2025 14-58-40  easyJet Europe     EC7199
# 582       585.0  21/11/2025 14-58-40  easyJet Europe     EC1376
# 586       589.0  21/11/2025 14-58-40  easyJet Europe     EC3737
# 589       592.0  21/11/2025 14-58-40    Lauda Europe       LW12
# 598       602.0  21/11/2025 14-58-40  easyJet Europe     EC7656
# 608       612.0  21/11/2025 14-58-40  easyJet Europe     EC7131
# 610       614.0  21/11/2025 14-58-40  easyJet Europe     EC4212
# 614       618.0  21/11/2025 14-58-40            BUZZ     RR8384
# 619       623.0  21/11/2025 14-58-40         Ryanair     FR3121
# 621       625.0  21/11/2025 14-58-40  easyJet Europe     EC7141
# 644       648.0  21/11/2025 14-58-40  easyJet Europe     EC7153
# 645       649.0  21/11/2025 14-58-40    Lauda Europe     LW7351
# ...

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168 entries, 568 to 735
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       168 non-null    float64
#  1   fecha_scrapeo    168 non-null    object
#  2   Name_company     168 non-null    object
#  3   Num_flight       168 non-null    object
#  4   Name_Destiny     168 non-null    object
#  5   Time_flight      168 non-null    object
#  6   flight_state     168 non-null    object
#  7   flight_capacity  168 non-null    float64
#  8   Aircraft         168 non-null    object
#  9   Gate             168 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 14.4+ KB

# %%
df_por_fecha['21/11/2025 14-58-40'] = df_21.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_22 = df_por_fecha['22/Nov/2025'].copy()
df_22
# Out:
#      Unnamed: 0 fecha_scrapeo      Name_company Num_flight      Name_Destiny  \
# 736         NaN   22/Nov/2025           Ryanair      FR846       Milan (BGY)
# 737         NaN   22/Nov/2025    easyJet Europe     EC7105      Geneva (GVA)
# 738         NaN   22/Nov/2025           Ryanair     FR5718  Bratislava (BTS)
# 739         NaN   22/Nov/2025           Ryanair     FR4545       Porto (OPO)
# 740         NaN   22/Nov/2025           Ryanair     FR1342               NaN
# ..          ...           ...               ...        ...               ...
# 847         NaN   22/Nov/2025    Wizz Air Malta     W46020        Rome (FCO)
# 848         NaN   22/Nov/2025           Ryanair     FR3800  Birmingham (BHX)
# 849         NaN   22/Nov/2025           Ryanair     FR8574        Rome (FCO)
# 850         NaN   22/Nov/2025          Wizz Air     W64116    Belgrade (BEG)
# 851         NaN   22/Nov/2025  Air Arabia Maroc      3O642      Tanger (TNG)
#
# ...

# %%
df_22.isna().sum()
# Out:
# Unnamed: 0         116
# fecha_scrapeo        0
# Name_company         1
# Num_flight           0
# Name_Destiny         6
# Time_flight          0
# flight_state         0
# flight_capacity    116
# Aircraft           108
# Gate                 0
# dtype: int64

# %%
df_22[(df_22['flight_capacity'].isna())].head(10)
# Out:
#      Unnamed: 0 fecha_scrapeo      Name_company Num_flight      Name_Destiny  \
# 736         NaN   22/Nov/2025           Ryanair      FR846       Milan (BGY)
# 737         NaN   22/Nov/2025    easyJet Europe     EC7105      Geneva (GVA)
# 738         NaN   22/Nov/2025           Ryanair     FR5718  Bratislava (BTS)
# 739         NaN   22/Nov/2025           Ryanair     FR4545       Porto (OPO)
# 740         NaN   22/Nov/2025           Ryanair     FR1342               NaN
# 741         NaN   22/Nov/2025           Ryanair      FR777      Venice (VCE)
# 742         NaN   22/Nov/2025    easyJet Europe     EC7151       Milan (MXP)
# 743         NaN   22/Nov/2025           Ryanair     FR2918    Brussels (BRU)
# 744         NaN   22/Nov/2025           Ryanair     FR3180        Rome (FCO)
# 745         NaN   22/Nov/2025  Air Arabia Maroc      3O376   Al Aaroui (NDR)
#
#     Time_flight                flight_state  flight_capacity Aircraft Gate
# ...

# %%
df_22[(df_22['Name_Destiny'].isna())].head(10)
# Out:
#      Unnamed: 0 fecha_scrapeo Name_company Num_flight Name_Destiny  \
# 740         NaN   22/Nov/2025      Ryanair     FR1342          NaN
# 746         NaN   22/Nov/2025      Ryanair     FR1165          NaN
# 785         NaN   22/Nov/2025      Ryanair      FR483          NaN
# 800         NaN   22/Nov/2025      Ryanair     FR3070          NaN
# 834         NaN   22/Nov/2025      Ryanair     FR9581          NaN
# 836         NaN   22/Nov/2025      Ryanair     FR3182          NaN
#
#     Time_flight                flight_state  flight_capacity Aircraft Gate
# 740       06:20          En hora, Ha salido              NaN      NaN  S24
# 746       08:50          En hora, Ha salido              NaN      NaN  R12
# 785       13:05  Retrasado, Ha salido 13:24              NaN      NaN  S21
# 800       14:40  Retrasado, Ha salido 14:51              NaN      NaN  S24
# 834       20:25          En hora, Ha salido              NaN      NaN  R13
# ...

# %%
df_22.loc[df_22['Num_flight'] == 'FR3070', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'
df_22.loc[df_22['Num_flight'] == 'FR9581', 'Name_Destiny'] = 'Sevilla (SVQ)'

# %%
df_22.loc[df_22['Num_flight'] == 'RR3039', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'RR3039', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == '3O642', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W64116', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'FR8574', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR8574', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR3800', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3800', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W46020', 'flight_capacity'] = 239

# %%
df_22.loc[df_22['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR5220', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_22.loc[df_22['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_22.loc[df_22['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3174', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_22.loc[df_22['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_22.loc[df_22['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR3182', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3182', 'flight_capacity'] = 189
df_22.loc[df_22['Num_flight'] == 'FR3182', 'Name_Destiny'] = 'Malaga (AGP)'

# %%
df_22.loc[df_22['Num_flight'] == 'TW408', 'Aircraft'] = 'BOEING 777-300ER'
df_22.loc[df_22['Num_flight'] == 'TW408', 'flight_capacity'] = 294

df_22.loc[df_22['Num_flight'] == 'FR9581', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR9581', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR867', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'BT878', 'Aircraft'] = 'Airbus A220-300'
df_22.loc[df_22['Num_flight'] == 'BT878', 'flight_capacity'] = 148

df_22.loc[df_22['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR149', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR5270', 'flight_capacity'] = 189

# %%
df_22.loc[df_22['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W61176', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR3792', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR3035', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'HV5134', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR878', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'D81741', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'FR6353', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR6353', 'flight_capacity'] = 189

# %%
df_22.loc[df_22['Num_flight'] == 'FR2925', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR2925', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR6874', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR9015', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR3146', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3146', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR7543', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR7543', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR3807', 'flight_capacity'] = 197

# %%
df_22.loc[df_22['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR3070', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3070', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-900'
df_22.loc[df_22['Num_flight'] == 'KU136', 'flight_capacity'] = 278

df_22.loc[df_22['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'RR6920', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'RR6920', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_22.loc[df_22['Num_flight'] == 'BT684', 'flight_capacity'] = 148

# %%
df_22.loc[df_22['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'VF608', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'VF608', 'flight_capacity'] = 180
df_22.loc[df_22['Num_flight'] == 'VF608', 'Name_company'] = 'Ajet'

df_22.loc[df_22['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == '3O378', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR2098', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'RK6597', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'RK6597', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR7808', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321'
df_22.loc[df_22['Num_flight'] == 'W46330', 'flight_capacity'] = 230

df_22.loc[df_22['Num_flight'] == 'OB775', 'Aircraft'] = 'Airbus A330-200'
df_22.loc[df_22['Num_flight'] == 'OB775', 'flight_capacity'] = 246

# %%
df_22.loc[df_22['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR483', 'flight_capacity'] = 189
df_22.loc[df_22['Num_flight'] == 'FR483', 'Name_Destiny'] = 'Malaga (AGP)'

df_22.loc[df_22['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_22.loc[df_22['Num_flight'] == 'PC1092', 'flight_capacity'] = 230

df_22.loc[df_22['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3108', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'EI563', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'EC7193', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC7193', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'FR4597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR4597', 'flight_capacity'] = 197

# %%
df_22.loc[df_22['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'U22704', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'U5406', 'Aircraft'] = 'Boeing 737-700'
df_22.loc[df_22['Num_flight'] == 'U5406', 'flight_capacity'] = 149

df_22.loc[df_22['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320neo'
df_22.loc[df_22['Num_flight'] == 'J246', 'flight_capacity'] = 186

df_22.loc[df_22['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'FR9307', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR9307', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR3168', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3168', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'U22326', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'FR9171', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR9171', 'flight_capacity'] = 197

# %%
df_22.loc[df_22['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'HV5132', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'FR6559', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR6559', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'JU581', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'RR3049', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W61914', 'flight_capacity'] = 239

# %%
df_22.loc[df_22['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'TO4751', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'TO4751', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR2834', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_22.loc[df_22['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_22.loc[df_22['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == 'W43938', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR1165', 'flight_capacity'] = 189
df_22.loc[df_22['Num_flight'] == 'FR1165', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'

df_22.loc[df_22['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == '3O376', 'flight_capacity'] = 180

# %%
df_22.loc[df_22['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_22.loc[df_22['Num_flight'] == '3O376', 'flight_capacity'] = 180

df_22.loc[df_22['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR1342', 'flight_capacity'] = 189
df_22.loc[df_22['Num_flight'] == 'FR1342', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'

df_22.loc[df_22['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_22.loc[df_22['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_22.loc[df_22['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_22.loc[df_22['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_22.loc[df_22['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_22.loc[df_22['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_22.loc[df_22['Num_flight'] == 'FR846', 'flight_capacity'] = 189

# %%
df_22.isna().sum()
# Out:
# Unnamed: 0         116
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity      0
# Aircraft             0
# Gate                 0
# dtype: int64

# %%
df_22[(df_22.Name_Destiny == 'Valletta (MLA)')]
# Out:
#      Unnamed: 0 fecha_scrapeo Name_company Num_flight    Name_Destiny  \
# 812         NaN   22/Nov/2025      Ryanair     FR5752  Valletta (MLA)
#
#     Time_flight        flight_state  flight_capacity          Aircraft Gate
# 812       17:10  En hora, Ha salido            197.0  Boeing 737 MAX 8  W44

# %%
df_22.tail(60)
# Out:
#      Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 792         NaN   22/Nov/2025          Air Arabia Maroc      3O378
# 793         NaN   22/Nov/2025            easyJet Europe     EC7153
# 794         NaN   22/Nov/2025                      Ajet      VF608
# 795         NaN   22/Nov/2025                   Ryanair     FR1681
# 796         NaN   22/Nov/2025                Air Baltic      BT684
# 797         NaN   22/Nov/2025                      BUZZ     RR6920
# 798         NaN   22/Nov/2025                   Ryanair       FR58
# 799         NaN   22/Nov/2025            Kuwait Airways      KU136
# 800         NaN   22/Nov/2025                   Ryanair     FR3070
# 801         NaN   22/Nov/2025                   Ryanair      FR774
# 802         NaN   22/Nov/2025                   Ryanair     FR3121
# 803         NaN   22/Nov/2025                   Ryanair     FR6300
# 804         NaN   22/Nov/2025                   Ryanair     FR3189
# ...

# %%
# Rango a corregir
start, end = 805, 818

# Reemplazar los valores desplazando hacia arriba dentro del rango
df_22.loc[start:end, 'Gate'] = df_22.loc[start+1:end+1, 'Gate'].values

# %%
df_22.tail(60)
# Out:
#      Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 792         NaN   22/Nov/2025          Air Arabia Maroc      3O378
# 793         NaN   22/Nov/2025            easyJet Europe     EC7153
# 794         NaN   22/Nov/2025                      Ajet      VF608
# 795         NaN   22/Nov/2025                   Ryanair     FR1681
# 796         NaN   22/Nov/2025                Air Baltic      BT684
# 797         NaN   22/Nov/2025                      BUZZ     RR6920
# 798         NaN   22/Nov/2025                   Ryanair       FR58
# 799         NaN   22/Nov/2025            Kuwait Airways      KU136
# 800         NaN   22/Nov/2025                   Ryanair     FR3070
# 801         NaN   22/Nov/2025                   Ryanair      FR774
# 802         NaN   22/Nov/2025                   Ryanair     FR3121
# 803         NaN   22/Nov/2025                   Ryanair     FR6300
# 804         NaN   22/Nov/2025                   Ryanair     FR3189
# ...

# %%
# indice 805 tiene en la columna gate el valor w42 que es duplicada de la fila de arriba
# remplazar ese valor por el valor de abajo s21 y asi susesivamente a la siguientes filas hasta
# el indice 818 que reemplazamos su gate por u32 de abajo pero dejamos para la fila 819 el gate u32

# %%
# 819 es u31 en 818 u32 arrastrar arriba 803 elimina r2 y subir w42 y todo el resto

# %%
# dub -> y54 / tanger correcto

# %%
df_por_fecha['22/Nov/2025'] = df_22.copy()

# %%
df_por_fecha   #GURDAMOS EN DICC VISUALIZAMOS DICC
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
# CONCATENAMOS COLUMNAS DE PRIMERA SEMANA Y LO GUARDAMOS EN UNA VARIABLE 
df_semana1 = pd.concat([df_17, df_18, df_19, df_20, df_21, df_22], ignore_index=True)

# %%
df_semana1
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 0         118.0  17/11/2025 14-06-56           Ryanair     FR3180
# 1         119.0  17/11/2025 14-06-56           Ryanair      FR846
# 2         120.0  17/11/2025 14-06-56    easyJet Europe     EC7105
# 3         121.0  17/11/2025 14-06-56           Ryanair     FR2233
# 4         122.0  17/11/2025 14-06-56           Ryanair     FR8384
# ..          ...                  ...               ...        ...
# 731         NaN          22/Nov/2025    Wizz Air Malta     W46020
# 732         NaN          22/Nov/2025           Ryanair     FR3800
# 733         NaN          22/Nov/2025           Ryanair     FR8574
# 734         NaN          22/Nov/2025          Wizz Air     W64116
# 735         NaN          22/Nov/2025  Air Arabia Maroc      3O642
#
#          Name_Destiny Time_flight                flight_state  \
# 0          Rome (FCO)       06:00                   Ha salido
# ...

# %%
df_semana1.isna().sum()
# Out:
# Unnamed: 0         116
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity      2
# Aircraft             2
# Gate                16
# dtype: int64

# %%
df_semana1[(df_semana1['flight_capacity'].isna())].head(40) # QUE NULOS TENEMOS
# EL VUELO DE CARGO NOS LO CARGAMOS YA QUE NO INFLUYE EN AFLUENCIA DE PASAJEROS
# Out:
#      Unnamed: 0        fecha_scrapeo    Name_company Num_flight  \
# 125       243.0  17/11/2025 14-06-56       Eurowings     E69443
# 411        90.0  20/11/2025 14-38-34  easyJet Europe     EC7139
#
#                    Name_Destiny Time_flight          flight_state  \
# 125            Dusseldorf (DUS)       19:35  Retrasado, Ha salido
# 411  Rennes/Saint-Jacques (RNS)       18:15            Programado
#
#      flight_capacity Aircraft Gate
# 125              NaN      NaN  NaN
# 411              NaN      NaN    R

# %%
# AÑADIMOS INFO FALTANTE 
df_semana1.loc[df_semana1['Num_flight'] == 'EC7139', 'Aircraft'] = 'Airbus A320'
df_semana1.loc[df_semana1['Num_flight'] == 'EC7139', 'flight_capacity'] =  180

# %%
df_semana1[(df_semana1['Gate'].isna())].head(40)
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 3         121.0  17/11/2025 14-06-56           Ryanair     FR2233
# 22        140.0  17/11/2025 14-06-56  Air Arabia Maroc      3O398
# 37        155.0  17/11/2025 14-06-56         Transavia     TO4751
# 55        173.0  17/11/2025 14-06-56         Transavia     TO4755
# 91        209.0  17/11/2025 14-06-56  Air Arabia Maroc      3O376
# 93        211.0  17/11/2025 14-06-56           Ryanair     FR1681
# 125       243.0  17/11/2025 14-06-56         Eurowings     E69443
# 157       275.0  17/11/2025 14-06-56    Wizz Air Malta     W43178
# 240       358.0  19/11/2025 14-33-06           Ryanair     FR9406
# 253       371.0  19/11/2025 14-33-06  Air Arabia Maroc      3O376
# 283       401.0  19/11/2025 14-33-06           Ryanair      FR777
# 288       406.0  19/11/2025 14-33-06         Transavia     TO4755
# 295       413.0  19/11/2025 14-33-06    Wizz Air Malta     W43686
# ...

# %%
df_semana1.drop([241], inplace=True)   # ELIMINAR VUELO DE CARGO

# %%
df_semana1.reset_index(drop=True, inplace=True) # RESETEAR INDICE

# %%
df_semana1
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 0         118.0  17/11/2025 14-06-56           Ryanair     FR3180
# 1         119.0  17/11/2025 14-06-56           Ryanair      FR846
# 2         120.0  17/11/2025 14-06-56    easyJet Europe     EC7105
# 3         121.0  17/11/2025 14-06-56           Ryanair     FR2233
# 4         122.0  17/11/2025 14-06-56           Ryanair     FR8384
# ..          ...                  ...               ...        ...
# 730         NaN          22/Nov/2025    Wizz Air Malta     W46020
# 731         NaN          22/Nov/2025           Ryanair     FR3800
# 732         NaN          22/Nov/2025           Ryanair     FR8574
# 733         NaN          22/Nov/2025          Wizz Air     W64116
# 734         NaN          22/Nov/2025  Air Arabia Maroc      3O642
#
#          Name_Destiny Time_flight                flight_state  \
# 0          Rome (FCO)       06:00                   Ha salido
# ...

# %%
#df_semana1.to_csv("vuelos_bcn_s1.csv") # GUARDAR EN CSV

# %% [markdown]
# ## **SEMANA 2 :**

# %%
df_23 = df_por_fecha['23/11/2025 15-34-22'].copy()
df_23.head(88)
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 852         NaN  23/11/2025 15-34-22           Ryanair     FR3180
# 853         NaN  23/11/2025 15-34-22           Ryanair     FR2834
# 854         NaN  23/11/2025 15-34-22           Ryanair     FR2918
# 855         NaN  23/11/2025 15-34-22           Ryanair     FR4084
# 856         NaN  23/11/2025 15-34-22           Ryanair     FR2239
# ..          ...                  ...               ...        ...
# 935         NaN  23/11/2025 15-34-22    easyJet Europe     EC7694
# 936         NaN  23/11/2025 15-34-22           Ryanair     FR6973
# 937         NaN  23/11/2025 15-34-22  Air Arabia Maroc      3O378
# 938         NaN  23/11/2025 15-34-22    Wizz Air Malta     W46728
# 939         NaN  23/11/2025 15-34-22           Ryanair      FR133
#
#         Name_Destiny Time_flight                flight_state  flight_capacity  \
# 852       Rome (FCO)       06:00                   Ha salido              NaN
# ...

# %%
df_23.loc[929:983]
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 929         NaN  23/11/2025 15-34-22           Ryanair      FR269
# 930         NaN  23/11/2025 15-34-22        SmartWings     QS1059
# 931         NaN  23/11/2025 15-34-22           Ryanair     FR3320
# 932         NaN  23/11/2025 15-34-22           Ryanair      FR774
# 933         NaN  23/11/2025 15-34-22              BUZZ     RR3072
# 934         NaN  23/11/2025 15-34-22         Transavia     TO4755
# 935         NaN  23/11/2025 15-34-22    easyJet Europe     EC7694
# 936         NaN  23/11/2025 15-34-22           Ryanair     FR6973
# 937         NaN  23/11/2025 15-34-22  Air Arabia Maroc      3O378
# 938         NaN  23/11/2025 15-34-22    Wizz Air Malta     W46728
# 939         NaN  23/11/2025 15-34-22           Ryanair      FR133
# 940         NaN  23/11/2025 15-34-22           Ryanair     FR2922
# 941         NaN  23/11/2025 15-34-22    easyJet Europe     EC7173
# ...

# %%
# Rango a corregir
start, end = 932, 971

# Reemplazar los valores desplazando hacia arriba dentro del rango
df_23.loc[start:end, 'Gate'] = df_23.loc[start+1:end+1, 'Gate'].values

# %%
# 931 s20/  932 - u33  971 - u36 / 973 - w

# %%
df_23.loc[930:983]
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 930         NaN  23/11/2025 15-34-22        SmartWings     QS1059
# 931         NaN  23/11/2025 15-34-22           Ryanair     FR3320
# 932         NaN  23/11/2025 15-34-22           Ryanair      FR774
# 933         NaN  23/11/2025 15-34-22              BUZZ     RR3072
# 934         NaN  23/11/2025 15-34-22         Transavia     TO4755
# 935         NaN  23/11/2025 15-34-22    easyJet Europe     EC7694
# 936         NaN  23/11/2025 15-34-22           Ryanair     FR6973
# 937         NaN  23/11/2025 15-34-22  Air Arabia Maroc      3O378
# 938         NaN  23/11/2025 15-34-22    Wizz Air Malta     W46728
# 939         NaN  23/11/2025 15-34-22           Ryanair      FR133
# 940         NaN  23/11/2025 15-34-22           Ryanair     FR2922
# 941         NaN  23/11/2025 15-34-22    easyJet Europe     EC7173
# 942         NaN  23/11/2025 15-34-22           Ryanair     FR9814
# ...

# %%
df_23[(df_23['Num_flight'] == '3O378')]
# Out:
#      Unnamed: 0        fecha_scrapeo      Name_company Num_flight  \
# 937         NaN  23/11/2025 15-34-22  Air Arabia Maroc      3O378
#
#      Name_Destiny Time_flight        flight_state  flight_capacity Aircraft  \
# 937  Tanger (TNG)       15:35  En hora, Ha salido              NaN      NaN
#
#     Gate
# 937  Y55

# %%
df_23.loc[df_23['Num_flight'] == 'FR2233', 'Gate'] = 'W'

# %%
df_23[df_23['Name_Destiny'].isna()].head(10)
# Out:
#       Unnamed: 0        fecha_scrapeo  Name_company Num_flight Name_Destiny  \
# 862          NaN  23/11/2025 15-34-22       Ryanair     FR1165          NaN
# 868          NaN  23/11/2025 15-34-22       Volotea     V73735          NaN
# 883          NaN  23/11/2025 15-34-22       Ryanair     FR2495          NaN
# 902          NaN  23/11/2025 15-34-22  Lauda Europe     LW2889          NaN
# 906          NaN  23/11/2025 15-34-22       Ryanair     FR2402          NaN
# 918          NaN  23/11/2025 15-34-22       Ryanair      FR483          NaN
# 921          NaN  23/11/2025 15-34-22       Ryanair     FR1342          NaN
# 956          NaN  23/11/2025 15-34-22       Ryanair     FR2406          NaN
# 1000         NaN  23/11/2025 15-34-22       Ryanair     FR2896          NaN
#
#      Time_flight                flight_state  flight_capacity Aircraft Gate
# 862        07:50                   Ha salido              NaN      NaN  S24
# ...

# %%
df_23.loc[df_23['Num_flight'] == 'V73735', 'Name_Destiny'] = 'Murcia (RMU)'
df_23.loc[df_23['Num_flight'] == 'FR2495', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'
df_23.loc[df_23['Num_flight'] == 'LW2889', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'
df_23.loc[df_23['Num_flight'] == 'FR2402', 'Name_Destiny'] = 'Sevilla (SVQ)'
df_23.loc[df_23['Num_flight'] == 'FR1342', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'
df_23.loc[df_23['Num_flight'] == 'FR2896', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'

# %%
df_23.loc[df_23['Num_flight'] == 'BZ251', 'Gate'] = 'Y'
#df_23.loc[df_23['Num_flight'] == 'W62096', 'Gate'] = 'Y'

# %%
df_23.loc[df_23['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR9406', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W61706', 'flight_capacity'] = 239

# %%
#df_23.loc[df_23['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'
#df_23.loc[df_23['Num_flight'] == 'W45154', 'flight_capacity'] = 230
df_23.loc[df_23['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR5220', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321'
df_23.loc[df_23['Num_flight'] == 'W64116', 'flight_capacity'] = 230

df_23.loc[df_23['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'U22706', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'U22706', 'flight_capacity'] = 186

df_23.loc[df_23['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'U28060', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'U28060', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'W43406', 'flight_capacity'] = 180

# %%
df_23 = df_23.drop([873]) # AVION DE CARGO

# %%
df_23 = df_23.drop([985])  # AVION DE CARGO

# %%
df_23.loc[df_23['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_23.loc[df_23['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_23.loc[df_23['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR2896', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2896', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'EI565', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'RR8615', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'RR8615', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W64738', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W64738', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'U22326', 'flight_capacity'] = 186

# %%
df_23.loc[df_23['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'RR6944', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'HV5134', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR6275', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_23.loc[df_23['Num_flight'] == 'LG3596', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'LG3596', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR4587', 'flight_capacity'] = 189

# %%
df_23.loc[df_23['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'EW2521', 'flight_capacity'] = 186

df_23.loc[df_23['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'D83659', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'JU585', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR6985', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

# %%
df_23.loc[df_23['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W62096', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'FR8136', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR8136', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
df_23.loc[df_23['Num_flight'] == 'W64666', 'flight_capacity'] = 230

df_23.loc[df_23['Num_flight'] == 'LS1338', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'LS1338', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'U28058', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR9015', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR5710', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC3750', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'EC3750', 'flight_capacity'] = 180

# %%
df_23.loc[df_23['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EW9443', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'V72165', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR3160', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3160', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_23.loc[df_23['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_23.loc[df_23['Num_flight'] == 'EC7159', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7159', 'flight_capacity'] = 156

# %%
df_23.loc[df_23['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'W61176', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'U25716', 'flight_capacity'] = 186

df_23.loc[df_23['Num_flight'] == 'HV6066', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'HV6066', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR8631', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'W43686', 'flight_capacity'] = 180

# %%
df_23.loc[df_23['Num_flight'] == 'FR2406', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2406', 'flight_capacity'] = 189
df_23.loc[df_23['Num_flight'] == 'FR2406', 'Name_Destiny'] = 'Sevilla (SVQ)'

df_23.loc[df_23['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'EC7109', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7109', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR6305', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR777', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'RR5252', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'RR5252', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'V73573', 'flight_capacity'] = 156

# %%
df_23.loc[df_23['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR12', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'RR8394', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2250', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == '3O374', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == '3O374', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR8669', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR9814', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR9814', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

# %%
df_23.loc[df_23['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2922', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == '3O378', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR6973', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'EC7694', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'EC7694', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_23.loc[df_23['Num_flight'] == 'RR3072', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'RR3072', 'flight_capacity'] = 189

# %%
df_23.loc[df_23['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'QS1059', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'BZ251', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'BZ251', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'HV5132', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'HV5132', 'flight_capacity'] = 189

# %%
df_23.loc[df_23['Num_flight'] == 'XQ895', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'XQ895', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR6920', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_23.loc[df_23['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_23.loc[df_23['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR483', 'flight_capacity'] = 189
df_23.loc[df_23['Num_flight'] == 'FR483', 'Name_Destiny'] = 'Malaga (AGP)'

df_23.loc[df_23['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR9811', 'flight_capacity'] = 189

# %%
df_23.loc[df_23['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W46330', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'V71445', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'V71445', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'FR8598', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR8598', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR2511', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2511', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_23.loc[df_23['Num_flight'] == 'PC1092', 'flight_capacity'] = 230

# %%
df_23.loc[df_23['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'V72167', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'V72167', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2402', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR1527', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR3976', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'LW2889', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'LW2889', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FI597', 'flight_capacity'] = 197

# %%
df_23.loc[df_23['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320neo'
df_23.loc[df_23['Num_flight'] == 'EI563', 'flight_capacity'] = 186

df_23.loc[df_23['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'D81741', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'J246', 'flight_capacity'] = 122

df_23.loc[df_23['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR3143', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR1279', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR7543', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR7543', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR575', 'flight_capacity'] = 189

# %%
df_23.loc[df_23['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR6874', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'RR3049', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR2495', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2495', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'RR8384', 'flight_capacity'] = 197

# %%
df_23.loc[df_23['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'RR333', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_23.loc[df_23['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_23.loc[df_23['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W45088', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EW7521', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'RR3193', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'RR3193', 'flight_capacity'] = 189

# %%
df_23.loc[df_23['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_23.loc[df_23['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_23.loc[df_23['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR3028', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'RR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'RR1786', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'V73735', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR878', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC3754', 'Aircraft'] = 'Airbus A320'
df_23.loc[df_23['Num_flight'] == 'EC3754', 'flight_capacity'] = 180

df_23.loc[df_23['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'D85510', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR1165', 'flight_capacity'] = 189
df_23.loc[df_23['Num_flight'] == 'FR1165', 'Name_Destiny'] = 'Sevilla (SVQ)'

# %%
df_23.loc[df_23['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3108', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR6597', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'EC7191', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7191', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_23.loc[df_23['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_23.loc[df_23['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR4084', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR4084', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_23.loc[df_23['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
df_23.loc[df_23['Num_flight'] == 'FR2834', 'flight_capacity'] = 197

df_23.loc[df_23['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_23.loc[df_23['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

# %%
df_23.isna().sum()
# Out:
# Unnamed: 0         160
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity      2
# Aircraft             2
# Gate                 1
# dtype: int64

# %%
df_23['flight_capacity'].unique()
# Out:
# array([189., 197., 156., 180., 239., 230., 122., 186.,  nan, 148.])

# %%
df_23['Aircraft'].unique()
# Out:
# array(['Boeing 737-800', 'Boeing 737 MAX 8', 'Airbus A319', 'Airbus A320',
#        'Airbus A321neo', 'Airbus A321', 'Airbus A320neo', nan,
#        'Airbus A220-300'], dtype=object)

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A319') & 
(df_23['Name_company'] == 'Eurowings'),
'flight_capacity'
] = 150   # si es eurowings y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A320') & 
(df_23['Name_company'] == 'Eurowings'),
'flight_capacity'
] = 180   # si es eurowings y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A320') & 
(df_23['Name_company'] == 'Air Arabia Maroc'),
'flight_capacity'
] = 174   # si es eurowings y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A320') & 
(df_23['Name_company'] == 'Aer Lingus'),
'flight_capacity'
] = 174   # si es eurowings y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A319') & 
(df_23['Name_company'] == 'Air Serbia'),
'flight_capacity'
] = 144   # si es airserbia y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A321') & 
(df_23['Name_company'] == 'Pegasus Airlines'),
'flight_capacity'
] = 220   # si es airserbia y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23.loc[
(df_23['Aircraft'] == 'Airbus A321neo') & 
(df_23['Name_company'] == 'Jet2'),
'flight_capacity'
] = 232  # si es airserbia y tiene ese tipo de avion ponerle estas capacidades

# %%
df_23[(df_23['Aircraft'] == 'Airbus A220-300')]
# Out:
#      Unnamed: 0        fecha_scrapeo Name_company Num_flight Name_Destiny  \
# 919         NaN  23/11/2025 15-34-22   Air Baltic      BT684   Riga (RIX)
#
#     Time_flight flight_state  flight_capacity         Aircraft Gate
# 919       14:05    Ha salido            148.0  Airbus A220-300  S24

# %%
df_por_fecha['23/11/2025 15-34-22'] = df_23.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_semanac = pd.concat([df_semana1, df_23], ignore_index=True)

# %%
df_semanac.to_csv("vuelos_bcn_s1.csv") # GUARDAR EN CSV

# %%
df_24 = df_por_fecha['24/Nov/2025'].copy()
df_24.tail(40)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 1140         NaN   24/Nov/2025           Ryanair      FR133
# 1141         NaN   24/Nov/2025      Lauda Europe     LW7351
# 1142         NaN   24/Nov/2025           Easyjet     U28058
# 1143         NaN   24/Nov/2025           Volotea     V71415
# 1144         NaN   24/Nov/2025          Wizz Air     W64666
# 1145         NaN   24/Nov/2025           Ryanair     FR3080
# 1146         NaN   24/Nov/2025  Air Arabia Maroc      3O378
# 1147         NaN   24/Nov/2025           Ryanair     FR3807
# 1148         NaN   24/Nov/2025           Ryanair     FR6341
# 1149         NaN   24/Nov/2025           Ryanair     FR6597
# 1150         NaN   24/Nov/2025    easyJet Europe     EC1956
# 1151         NaN   24/Nov/2025    Wizz Air Malta     W42940
# 1152         NaN   24/Nov/2025    easyJet Europe     EC1010
# 1153         NaN   24/Nov/2025         T'Way Air      TW408
# 1154         NaN   24/Nov/2025           Volotea     V72135
# ...

# %%
df_24.isna().sum()
# Out:
# Unnamed: 0         166
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         8
# Time_flight          0
# flight_state         0
# flight_capacity    166
# Aircraft           147
# Gate                 3
# dtype: int64

# %%
df_24[(df_24['Name_Destiny'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo  Name_company Num_flight Name_Destiny  \
# 1026         NaN   24/Nov/2025  Lauda Europe     LW1342          NaN
# 1027         NaN   24/Nov/2025       Ryanair     FR1165          NaN
# 1046         NaN   24/Nov/2025       Ryanair     FR2495          NaN
# 1095         NaN   24/Nov/2025       Ryanair     FR2889          NaN
# 1111         NaN   24/Nov/2025       Volotea     V73735          NaN
# 1138         NaN   24/Nov/2025  Lauda Europe     LW2896          NaN
# 1145         NaN   24/Nov/2025       Ryanair     FR3080          NaN
# 1169         NaN   24/Nov/2025       Ryanair     FR2402          NaN
#
#      Time_flight                flight_state  flight_capacity Aircraft Gate
# 1026       07:40          En hora, Ha salido              NaN      NaN  R14
# 1027       07:55          En hora, Ha salido              NaN      NaN  S20
# 1046       09:45          En hora, Ha salido              NaN      NaN  R14
# ...

# %%
df_24.loc[df_24['Num_flight'] == 'LW1342', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'
df_24.loc[df_24['Num_flight'] == 'FR1165', 'Name_Destiny'] =  'Sevilla (SVQ)'
df_24.loc[df_24['Num_flight'] == 'FR2889', 'Name_Destiny'] =  'Palma de Mallorca (PMI)'
df_24.loc[df_24['Num_flight'] == 'LW2896', 'Name_Destiny'] = 'Palma de Mallorca (PMI)'

# %%
df_24[(df_24['flight_capacity'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
# 1014         NaN   24/Nov/2025         Ryanair     FR3180        Rome (FCO)
# 1015         NaN   24/Nov/2025         Ryanair      FR846       Milan (BGY)
# 1016         NaN   24/Nov/2025  easyJet Europe     EC7105      Geneva (GVA)
# 1017         NaN   24/Nov/2025         Ryanair     FR2233   Al Aaroui (NDR)
# 1018         NaN   24/Nov/2025         Ryanair     FR8384    Budapest (BUD)
# 1019         NaN   24/Nov/2025         Ryanair     FR3078      Lisbon (LIS)
# 1020         NaN   24/Nov/2025  easyJet Europe     EC8062      London (LGW)
# 1021         NaN   24/Nov/2025         Ryanair     FR3035      Krakow (KRK)
# 1022         NaN   24/Nov/2025         Ryanair     FR8215      London (STN)
# 1023         NaN   24/Nov/2025  easyJet Europe     EC7141  Strasbourg (SXB)
#
#      Time_flight                flight_state  flight_capacity Aircraft Gate
# ...

# %%
df_24.loc[df_24['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W45154', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'FR8574', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR8574', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'W64116', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'U22706', 'Aircraft'] = 'Airbus A320neo'
df_24.loc[df_24['Num_flight'] == 'U22706', 'flight_capacity'] =  186

# %%
df_24.loc[df_24['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2250', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR1527', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR4587', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'FR3168', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3168', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W46020', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'RR4084', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2402', 'flight_capacity'] =  189
df_24.loc[df_24['Num_flight'] == 'FR2402', 'Name_Destiny'] =  'Sevilla (SVQ)'

df_24.loc[df_24['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320neo'
df_24.loc[df_24['Num_flight'] == 'W43406', 'flight_capacity'] =  186

df_24.loc[df_24['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W43178', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EC1380', 'flight_capacity'] =  180

# %%
df_24.loc[df_24['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR6920', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR6275', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EI565', 'flight_capacity'] =  174

df_24.loc[df_24['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR878', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'V72165', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3928', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2098', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W62378', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_24.loc[df_24['Num_flight'] == 'TO4759', 'flight_capacity'] =  186

df_24.loc[df_24['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'RR8394', 'flight_capacity'] =  197

# %%
df_24.loc[df_24['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR5710', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'V72135', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'V72135', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'TW408', 'Aircraft'] = 'Airbus A330-200'
df_24.loc[df_24['Num_flight'] == 'TW408', 'flight_capacity'] =  246

df_24.loc[df_24['Num_flight'] == 'EC1010', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC1010', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W42940', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EC1956', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR6597', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR6341', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR3807', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'FR3080', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3080', 'flight_capacity'] =  189
df_24.loc[df_24['Num_flight'] == 'FR3080', 'Name_Destiny'] =  'Malaga (AGP)'

# %%
df_24.loc[df_24['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'W64666', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'V71415', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'U28058', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'LW7351', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR133', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'W61706', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'LW2896', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'LW2896', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'EW7521', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR8231', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR9307', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR9307', 'flight_capacity'] =  189

# %%
df_24.loc[df_24['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3185', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W61478', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3174', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'W43686', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR3320', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'EC7205', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7205', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR269', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'RR333', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'HV5134', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'EC7199', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7199', 'flight_capacity'] =  156

# %%
df_24.loc[df_24['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EC3737', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2922', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR1786', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W67920', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'V73700', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7173', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'RR6300', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR5270', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'U23372', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'U23372', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'RR6874', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'RR6874', 'flight_capacity'] =  189

# %%
df_24.loc[df_24['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR6305', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR5718', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR2507', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'V73735', 'flight_capacity'] =  180
df_24.loc[df_24['Num_flight'] == 'V73735', 'Name_Destiny'] =  'Murcia (RMU)'

df_24.loc[df_24['Num_flight'] == 'W43564', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'W43564', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR9811', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR867', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'PC1094', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W46728', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR1681', 'flight_capacity'] =  189

# %%
df_24.loc[df_24['Num_flight'] == 'FR3146', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3146', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'QS1059', 'flight_capacity'] =  189
df_24.loc[df_24['Num_flight'] == 'QS1059', 'Gate'] =  'U'

df_24.loc[df_24['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EC4212', 'flight_capacity'] =  180
df_24.loc[df_24['Num_flight'] == 'EC4212', 'Gate'] =  'R'

df_24.loc[df_24['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'W64406', 'flight_capacity'] =  180
df_24.loc[df_24['Num_flight'] == 'W64406', 'Gate'] =  'U'

df_24.loc[df_24['Num_flight'] == 'V71443', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'V71443', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7107', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'BZ251', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'D85502', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR2889', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2889', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_24.loc[df_24['Num_flight'] == 'BT684', 'flight_capacity'] =  148

# %%
df_24.loc[df_24['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3792', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'LS804', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3189', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'TK608', 'flight_capacity'] =  165

df_24.loc[df_24['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR4585', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7153', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'
df_24.loc[df_24['Num_flight'] == 'LG3592', 'flight_capacity'] =  76

df_24.loc[df_24['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'PC1528', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EW521', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'D81741', 'flight_capacity'] =  189

# %%
df_24.loc[df_24['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'H4264', 'flight_capacity'] =  186

df_24.loc[df_24['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR8631', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W46330', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR3108', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W67022', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'EC7137', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7137', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'D83657', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'PC1092', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR774', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR6973', 'flight_capacity'] =  197

# %%
df_24.loc[df_24['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3129', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'LS232', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'LS232', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR8217', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR777', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'EC7197', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7197', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR1279', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'TO4755', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'TO4755', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR7539', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EI563', 'flight_capacity'] =  174

df_24.loc[df_24['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'U22002', 'flight_capacity'] =  180

# %%
df_24.loc[df_24['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR9045', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3039', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3976', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3121', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2239', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'U28056', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7131', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR7808', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'U22324', 'Aircraft'] = 'Airbus A320neo'
df_24.loc[df_24['Num_flight'] == 'U22324', 'flight_capacity'] =  186

df_24.loc[df_24['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3143', 'flight_capacity'] =  189

# %%
df_24.loc[df_24['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W61476', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'FR6559', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR6559', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W46018', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'HV5132', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'HV5132', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'EC7656', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'JU581', 'flight_capacity'] =  144

df_24.loc[df_24['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR4545', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR2495', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2495', 'flight_capacity'] =  189
df_24.loc[df_24['Num_flight'] == 'FR2495', 'Name_Destiny'] =  'Palma de Mallorca (PMI)'

df_24.loc[df_24['Num_flight'] == 'EW9441', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EW9441', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'HV6062', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'HV6062', 'flight_capacity'] =  189

# %%
df_24.loc[df_24['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2834', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EC1030', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'EC1030', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'V73573', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W62376', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W45088', 'flight_capacity'] =  239

df_24.loc[df_24['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_24.loc[df_24['Num_flight'] == 'W43176', 'flight_capacity'] =  230

df_24.loc[df_24['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EW2521', 'flight_capacity'] =  156

df_24.loc[df_24['Name_company'] == 'Air Arabia Maroc', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] =  174

df_24.loc[df_24['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'V72327', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_24.loc[df_24['Num_flight'] == 'W62048', 'flight_capacity'] =  239

# %%
df_24.loc[df_24['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR1165', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR6078', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR6078', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'LW12', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC1376', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR575', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR58', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'D85510', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'LW1342', 'Aircraft'] = 'Airbus A320'
df_24.loc[df_24['Num_flight'] == 'LW1342', 'flight_capacity'] =  180

df_24.loc[df_24['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3028', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7151', 'flight_capacity'] =  156

# %%
df_24.loc[df_24['Num_flight'] == 'EC7141', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7141', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR8215', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR8215', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3035', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC8062', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3078', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_24.loc[df_24['Num_flight'] == 'FR8384', 'flight_capacity'] =  197

df_24.loc[df_24['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR2233', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_24.loc[df_24['Num_flight'] == 'EC7105', 'flight_capacity'] =  156

df_24.loc[df_24['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR846', 'flight_capacity'] =  189

df_24.loc[df_24['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_24.loc[df_24['Num_flight'] == 'FR3180', 'flight_capacity'] =  189

# %%
df_por_fecha['24/Nov/2025'] = df_24.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_25 = df_por_fecha['25/Nov/2025'].copy()
df_25.tail(40)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 1206         NaN   25/Nov/2025                Aer Lingus      EI563
# 1207         NaN   25/Nov/2025                   Ryanair       FR58
# 1208         NaN   25/Nov/2025                Icelandair      FI597
# 1209         NaN   25/Nov/2025                   Ryanair     FR3108
# 1210         NaN   25/Nov/2025            easyJet Europe     EC7151
# 1211         NaN   25/Nov/2025  Norwegian Air Sweden AOC     D83657
# 1212         NaN   25/Nov/2025                   Ryanair     FR8384
# 1213         NaN   25/Nov/2025          Pegasus Airlines     PC1092
# 1214         NaN   25/Nov/2025                   Ryanair     FR6267
# 1215         NaN   25/Nov/2025  Norwegian Air Sweden AOC     D81741
# 1216         NaN   25/Nov/2025                    FlyOne     5F5512
# 1217         NaN   25/Nov/2025                   Ryanair     FR2239
# 1218         NaN   25/Nov/2025                   Ryanair     FR3076
# ...

# %%
df_25[(df_25['flight_capacity'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight  \
# 1180         NaN   25/Nov/2025  easyJet Europe     EC7105
# 1181         NaN   25/Nov/2025         Ryanair     FR3189
# 1182         NaN   25/Nov/2025         Ryanair     FR2507
# 1183         NaN   25/Nov/2025         Ryanair     FR4545
# 1184         NaN   25/Nov/2025  easyJet Europe     EC7101
# 1185         NaN   25/Nov/2025  easyJet Europe     EC8062
# 1186         NaN   25/Nov/2025         Ryanair     FR3166
# 1187         NaN   25/Nov/2025         Ryanair     FR5718
# 1188         NaN   25/Nov/2025         Ryanair     FR3193
# 1189         NaN   25/Nov/2025  easyJet Europe     EC3737
#
#                            Name_Destiny Time_flight        flight_state  \
# 1180                       Geneva (GVA)       06:00  En hora, Ha salido
# 1181                          Fes (FEZ)       06:15  En hora, Ha salido
# 1182                 Cologne-Bonn (CGN)       06:20  En hora, Ha salido
# ...

# %%
df_25.loc[df_25['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR4585', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W46020', 'flight_capacity'] =  239

df_25.loc[df_25['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR6394', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'EC1380', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_25.loc[df_25['Num_flight'] == 'TO4759', 'flight_capacity'] =  186

df_25.loc[df_25['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'RR4084', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'EC1956', 'flight_capacity'] =  180

# %%
df_25.loc[df_25['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == '3O642', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'HV6790', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'HV6790', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'U28058', 'flight_capacity'] =  156

df_25.loc[df_25['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W64406', 'flight_capacity'] =  239

df_25.loc[df_25['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'EW9443', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR9015', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W61478', 'flight_capacity'] =  239

df_25.loc[df_25['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321'
df_25.loc[df_25['Num_flight'] == 'W61176', 'flight_capacity'] =  230

df_25.loc[df_25['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR2834', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR777', 'flight_capacity'] =  189

# %%
df_25.loc[df_25['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'RR6300', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'RR6300', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'EC7103', 'flight_capacity'] =  156

df_25.loc[df_25['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3180', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'HV5134', 'flight_capacity'] =  239

df_25.loc[df_25['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR575', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR1165', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR846', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR3792', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'BZ251', 'Gate'] = 'Y'
df_25.loc[df_25['Num_flight'] == 'BZ251', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'BZ251', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-900'
df_25.loc[df_25['Num_flight'] == 'KU136', 'flight_capacity'] =  278

# %%
df_25.loc[df_25['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3076', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR2239', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == '5F5512', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == '5F5512', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'D81741', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR6267', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_25.loc[df_25['Num_flight'] == 'PC1092', 'flight_capacity'] =  230

df_25.loc[df_25['Num_flight'] == 'FR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR8384', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'D83657', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'EC7151', 'flight_capacity'] =  156

df_25.loc[df_25['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3108', 'flight_capacity'] =  189

# %%
df_25.loc[df_25['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FI597', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR58', 'flight_capacity'] =  189

df_25.loc[df_25['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'EI563', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320neo'
df_25.loc[df_25['Num_flight'] == 'J246', 'flight_capacity'] =  186

df_25.loc[df_25['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR5270', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR1279', 'flight_capacity'] =  197

df_25.loc[df_25['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W61476', 'flight_capacity'] =  239

df_25.loc[df_25['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'LW12', 'flight_capacity'] =  180

df_25.loc[df_25['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'JU581', 'flight_capacity'] =  156

df_25.loc[df_25['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W62376', 'flight_capacity'] =  239

# %%
df_25.loc[df_25['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == '3O378', 'flight_capacity'] = 180

df_25.loc[df_25['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_25.loc[df_25['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_25.loc[df_25['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_25.loc[df_25['Num_flight'] == 'W61914', 'flight_capacity'] = 239

df_25.loc[df_25['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737 MAX 8'
df_25.loc[df_25['Num_flight'] == 'FR3807', 'flight_capacity'] = 197

df_25.loc[df_25['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3035', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321'
df_25.loc[df_25['Num_flight'] == 'W62048', 'flight_capacity'] = 230

df_25.loc[df_25['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'W43938', 'flight_capacity'] = 180

df_25.loc[df_25['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR133', 'flight_capacity'] = 189

# %%
df_25.loc[df_25['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_25.loc[df_25['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_25.loc[df_25['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_25.loc[df_25['Num_flight'] == 'EC8062', 'flight_capacity'] = 156

df_25.loc[df_25['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'FR3193', 'Aircraft'] = 'Boeing 737-800'
df_25.loc[df_25['Num_flight'] == 'FR3193', 'flight_capacity'] = 189

df_25.loc[df_25['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_25.loc[df_25['Num_flight'] == 'EC3737', 'flight_capacity'] = 180

# %%
df_25.isna().sum()
# Out:
# Unnamed: 0         66
# fecha_scrapeo       0
# Name_company        0
# Num_flight          0
# Name_Destiny        0
# Time_flight         0
# flight_state        0
# flight_capacity     0
# Aircraft            0
# Gate                0
# dtype: int64

# %%
df_25['Aircraft'].unique()
# Out:
# array(['Airbus A319', 'Boeing 737-800', 'Airbus A320', 'Airbus A321',
#        'Boeing 737 MAX 8', 'Airbus A321neo', 'Airbus A320neo',
#        'Airbus A330-900'], dtype=object)

# %%
df_25[(df_25['Aircraft'] == 'Airbus A320neo')]
# Out:
#       Unnamed: 0 fecha_scrapeo         Name_company Num_flight Name_Destiny  \
# 1205         NaN   25/Nov/2025  Azerbaijan Airlines       J246   Baku (GYD)
# 1241         NaN   25/Nov/2025            Transavia     TO4759  Paris (ORY)
#
#      Time_flight        flight_state  flight_capacity        Aircraft Gate
# 1205       10:45  En hora, Ha salido            186.0  Airbus A320neo  W45
# 1241       20:45  En hora, Ha salido            186.0  Airbus A320neo  U32

# %%
df_por_fecha['25/Nov/2025'] = df_25.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_26 = df_por_fecha['26/Nov/2025'].copy()
df_26
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight       Name_Destiny  \
# 1246         NaN   26/Nov/2025         Ryanair     FR2918     Brussels (BRU)
# 1247         NaN   26/Nov/2025         Ryanair     FR3185        Rabat (RBA)
# 1248         NaN   26/Nov/2025         Ryanair     FR9406          Fes (FEZ)
# 1249         NaN   26/Nov/2025  easyJet Europe     EC7105       Geneva (GVA)
# 1250         NaN   26/Nov/2025         Ryanair      FR483       Malaga (AGP)
# ...          ...           ...             ...        ...                ...
# 1325         NaN   26/Nov/2025         Easyjet     U22326       London (LTN)
# 1326         NaN   26/Nov/2025  easyJet Europe     EC1380       Geneva (GVA)
# 1327         NaN   26/Nov/2025  Wizz Air Malta     W43406  Cluj-Napoca (CLJ)
# 1328         NaN   26/Nov/2025  Wizz Air Malta     W46020         Rome (FCO)
# 1329         NaN   26/Nov/2025         Ryanair     FR6394       Dublin (DUB)
#
# ...

# %%
df_26.isna().sum()
# Out:
# Unnamed: 0         84
# fecha_scrapeo       0
# Name_company        0
# Num_flight          0
# Name_Destiny        0
# Time_flight         0
# flight_state        0
# flight_capacity    84
# Aircraft           75
# Gate                2
# dtype: int64

# %%
df_26[(df_26['Gate'].isna())]
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight     Name_Destiny  \
# 1264         NaN   26/Nov/2025           Ryanair     FR2834  Charleroi (CRL)
# 1287         NaN   26/Nov/2025  Bluebird Airways      BZ251   Tel Aviv (TLV)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# 1264       09:45              Cancelado 09:45              NaN      NaN  NaN
# 1287       14:45  Retrasado, Programado 14:56              NaN      NaN  NaN

# %%
df_26.loc[df_26['Num_flight'] == 'BZ251', 'Gate'] = 'W'
df_26.loc[df_26['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

# %%
df_26 = df_26.drop(1264)  # cancelado vuelo

# %%
df_26.reset_index(drop=True, inplace=True)

# %%
df_26[(df_26['flight_capacity'].isna())].head(10)
# Out:
#    Unnamed: 0 fecha_scrapeo    Name_company Num_flight  \
# 0         NaN   26/Nov/2025         Ryanair     FR2918
# 1         NaN   26/Nov/2025         Ryanair     FR3185
# 2         NaN   26/Nov/2025         Ryanair     FR9406
# 3         NaN   26/Nov/2025  easyJet Europe     EC7105
# 4         NaN   26/Nov/2025         Ryanair      FR483
# 5         NaN   26/Nov/2025  easyJet Europe     EC7193
# 6         NaN   26/Nov/2025         Ryanair     FR2239
# 7         NaN   26/Nov/2025         Ryanair     FR3028
# 8         NaN   26/Nov/2025         Ryanair     FR3108
# 9         NaN   26/Nov/2025  easyJet Europe     EC7101
#
#                         Name_Destiny Time_flight                flight_state  \
# 0                     Brussels (BRU)       06:05          En hora, Ha salido
# 1                        Rabat (RBA)       06:05          En hora, Ha salido
# 2                          Fes (FEZ)       06:05          En hora, Ha salido
# ...

# %%
df_26.loc[df_26['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR6394', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W46020', 'flight_capacity'] = 239

# %%
df_26.loc[df_26['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_26.loc[df_26['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_26.loc[df_26['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_26.loc[df_26['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_26.loc[df_26['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'JU585', 'flight_capacity'] = 144

df_26.loc[df_26['Num_flight'] == 'TW408', 'Aircraft'] = 'BOEING 777-300ER'
df_26.loc[df_26['Num_flight'] == 'TW408', 'flight_capacity'] = 294

df_26.loc[df_26['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == '3O378', 'flight_capacity'] = 174

df_26.loc[df_26['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'RR5246', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'RR5246', 'flight_capacity'] = 197

# %%
df_26.loc[df_26['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3143', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W61706', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'U28058', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'HV6064', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'HV6064', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR133', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'EW9443', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR9334', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR9334', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR1165', 'flight_capacity'] = 189

# %%
df_26.loc[df_26['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'E9803', 'Aircraft'] = 'Airbus A350-900'
df_26.loc[df_26['Num_flight'] == 'E9803', 'flight_capacity'] = 432

df_26.loc[df_26['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W67920', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

# %%
df_26.loc[df_26['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_26.loc[df_26['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_26.loc[df_26['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR3035', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321'
df_26.loc[df_26['Num_flight'] == 'PC1094', 'flight_capacity'] = 230

df_26.loc[df_26['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR12', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR777', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EW2521', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'D83659', 'flight_capacity'] = 197

# %%
df_26.loc[df_26['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'TK608', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'
df_26.loc[df_26['Num_flight'] == 'LG3592', 'flight_capacity'] = 76

df_26.loc[df_26['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'EW521', 'flight_capacity'] = 180

df_26.loc[df_26['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'D81741', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR6597', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'PC1092', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'FR9925', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR9925', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'EI563', 'flight_capacity'] = 174

# %%
df_26.loc[df_26['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR2507', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320neo'
df_26.loc[df_26['Num_flight'] == 'U22704', 'flight_capacity'] = 186

df_26.loc[df_26['Num_flight'] == 'U5406', 'Aircraft'] = 'Boeing 737-700'
df_26.loc[df_26['Num_flight'] == 'U5406', 'flight_capacity'] = 149

df_26.loc[df_26['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR6267', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'BT878', 'Aircraft'] = 'Airbus A220-300'
df_26.loc[df_26['Num_flight'] == 'BT878', 'flight_capacity'] = 148

df_26.loc[df_26['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3039', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'HV5132', 'flight_capacity'] = 239

# %%
df_26.loc[df_26['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == '3O642', 'flight_capacity'] = 174

df_26.loc[df_26['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'RR3049', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W42940', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == '3O376', 'flight_capacity'] = 174

df_26.loc[df_26['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_26.loc[df_26['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_26.loc[df_26['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_26.loc[df_26['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_26.loc[df_26['Num_flight'] == 'EC7161', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC7161', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_26.loc[df_26['Num_flight'] == 'EC3737', 'flight_capacity'] = 180

# %%
df_26.loc[df_26['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC8062', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737 MAX 8'
df_26.loc[df_26['Num_flight'] == 'FR3108', 'flight_capacity'] = 197

df_26.loc[df_26['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'EC7193', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC7193', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR483', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_26.loc[df_26['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_26.loc[df_26['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR9406', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR3185', 'flight_capacity'] = 189

df_26.loc[df_26['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_26.loc[df_26['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

# %%
df_16['Aircraft'].unique()
# Out:
# array(['Boeing 737-800', 'Airbus A320', 'Airbus A319', 'Boeing 737 MAX 8',
#        'Airbus A321', 'Airbus A220-300', 'Airbus A321neo',
#        'Airbus A320neo'], dtype=object)

# %%
df_por_fecha['26/Nov/2025'] = df_26.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_27 = df_por_fecha['27/Nov/2025'].copy()
df_27
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight    Name_Destiny  \
# 1330         NaN   27/Nov/2025         Ryanair     FR8215    London (STN)
# 1331         NaN   27/Nov/2025         Ryanair     FR2918  Brussels (BRU)
# 1332         NaN   27/Nov/2025  easyJet Europe     EC7105    Geneva (GVA)
# 1333         NaN   27/Nov/2025         Ryanair     FR3976    Dublin (DUB)
# 1334         NaN   27/Nov/2025  easyJet Europe     EC7191   Glasgow (GLA)
# ...          ...           ...             ...        ...             ...
# 1451         NaN   27/Nov/2025            BUZZ     RR3035    Krakow (KRK)
# 1452         NaN   27/Nov/2025            BUZZ     RR4084    Warsaw (WMI)
# 1453         NaN   27/Nov/2025  Wizz Air Malta     W46020      Rome (FCO)
# 1454         NaN   27/Nov/2025        Wizz Air     W64116  Belgrade (BEG)
# 1455         NaN   27/Nov/2025  Wizz Air Malta     W45154    Tirana (TIA)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# ...

# %%
df_27.isna().sum()
# Out:
# Unnamed: 0         126
# fecha_scrapeo        0
# Name_company         1
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    126
# Aircraft           109
# Gate                 2
# dtype: int64

# %%
df_27[(df_27['Gate'].isna())]
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight    Name_Destiny  \
# 1396         NaN   27/Nov/2025  Bluebird Airways      BZ251  Tel Aviv (TLV)
# 1397         NaN   27/Nov/2025        SmartWings     QS1059    Prague (PRG)
#
#      Time_flight         flight_state  flight_capacity Aircraft Gate
# 1396       14:45  En hora, Programado              NaN      NaN  NaN
# 1397       14:55  En hora, Programado              NaN      NaN  NaN

# %%
df_27.loc[df_27['Num_flight'] == 'BZ251', 'Gate'] = 'W'
df_27.loc[df_27['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'QS1059', 'Gate'] = 'U'
df_27.loc[df_27['Num_flight'] == 'QS1059', 'Aircraft'] = 'Airbus A220-300'
df_27.loc[df_27['Num_flight'] == 'QS1059', 'flight_capacity'] = 149

# %%
df_27[(df_27['flight_capacity'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight  \
# 1330         NaN   27/Nov/2025         Ryanair     FR8215
# 1331         NaN   27/Nov/2025         Ryanair     FR2918
# 1332         NaN   27/Nov/2025  easyJet Europe     EC7105
# 1333         NaN   27/Nov/2025         Ryanair     FR3976
# 1334         NaN   27/Nov/2025  easyJet Europe     EC7191
# 1335         NaN   27/Nov/2025         Ryanair     FR3049
# 1336         NaN   27/Nov/2025         Ryanair     FR3028
# 1337         NaN   27/Nov/2025    Lauda Europe     LW2495
# 1338         NaN   27/Nov/2025         Ryanair      FR133
# 1339         NaN   27/Nov/2025  easyJet Europe     EC7101
#
#                            Name_Destiny Time_flight        flight_state  \
# 1330                       London (STN)       06:00  En hora, Ha salido
# 1331                     Brussels (BRU)       06:05  En hora, Ha salido
# 1332                       Geneva (GVA)       06:10  En hora, Ha salido
# ...

# %%
df_27.loc[df_27['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'
df_27.loc[df_27['Num_flight'] == 'W45154', 'flight_capacity'] = 230

df_27.loc[df_27['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W64116', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321'
df_27.loc[df_27['Num_flight'] == 'W46020', 'flight_capacity'] = 230

df_27.loc[df_27['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'RR4084', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'RR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'RR3035', 'flight_capacity'] = 197

# %%
df_27.loc[df_27['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_27.loc[df_27['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_27.loc[df_27['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR8217', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'W61176', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'TO4755', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'TO4755', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'TO4755', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'TO4755', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR846', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR3039', 'flight_capacity'] = 197

# %%
df_27.loc[df_27['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'V71445', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'V71445', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'U28056', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321'
df_27.loc[df_27['Num_flight'] == 'W42938', 'flight_capacity'] = 230

df_27.loc[df_27['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W61914', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'D85510', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

# %%
df_27.loc[df_27['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR1527', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'EI565', 'flight_capacity'] = 174

df_27.loc[df_27['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'RR333', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W64738', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W64738', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'U22324', 'Aircraft'] = 'Airbus A320neo'
df_27.loc[df_27['Num_flight'] == 'U22324', 'flight_capacity'] = 186

df_27.loc[df_27['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_27.loc[df_27['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_27.loc[df_27['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR4587', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR3143', 'flight_capacity'] = 197

# %%
df_27.loc[df_27['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == '3O376', 'flight_capacity'] = 174

df_27.loc[df_27['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'V72167', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'V72167', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR8631', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'U28058', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR8598', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR8598', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'EW2521', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == '3O378', 'flight_capacity'] = 174

# %%
df_27= df_27.drop(1427)

# %%
df_27.loc[df_27['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'RR3193', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'RR3193', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_27.loc[df_27['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_27.loc[df_27['Num_flight'] == 'FR3800', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3800', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC7139', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'EC7139', 'flight_capacity'] = 180

# %%
df_27.loc[df_27['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'RR6300', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'HV5136', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'HV5136', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'V72327', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'RR8394', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR2098', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC1378', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'EC1378', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

# %%
df_27.loc[df_27['Num_flight'] == 'FR9913', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR9913', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR9045', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'V73573', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR2922', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR149', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-900'
df_27.loc[df_27['Num_flight'] == 'KU136', 'flight_capacity'] = 278

# %%
df_27.loc[df_27['Num_flight'] == 'XQ895', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'XQ895', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_27.loc[df_27['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_27.loc[df_27['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR6267', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'
df_27.loc[df_27['Num_flight'] == 'LG3592', 'flight_capacity'] = 76

df_27.loc[df_27['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'PC1092', 'flight_capacity'] = 239

# %%
df_27.loc[df_27['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'U22704', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3076', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR483', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR3160', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3160', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'EI563', 'flight_capacity'] = 174

df_27.loc[df_27['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR6597', 'flight_capacity'] = 189

# %%
df_27.loc[df_27['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320neo'
df_27.loc[df_27['Num_flight'] == 'J246', 'flight_capacity'] = 186

df_27.loc[df_27['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
df_27.loc[df_27['Num_flight'] == 'U25716', 'flight_capacity'] = 186

df_27.loc[df_27['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR1165', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'HV5132', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR1279', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_27.loc[df_27['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_27.loc[df_27['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'JU581', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

# %%
df_27.loc[df_27['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_27.loc[df_27['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_27.loc[df_27['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR5710', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'W43938', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR6973', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR575', 'flight_capacity'] = 189

# %%
df_27.loc[df_27['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR2507', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'LW2495', 'Aircraft'] = 'Airbus A320'
df_27.loc[df_27['Num_flight'] == 'LW2495', 'flight_capacity'] = 180

df_27.loc[df_27['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_27.loc[df_27['Num_flight'] == 'FR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR3049', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'EC7191', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7191', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737 MAX 8'
df_27.loc[df_27['Num_flight'] == 'FR3976', 'flight_capacity'] = 197

df_27.loc[df_27['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_27.loc[df_27['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_27.loc[df_27['Num_flight'] == 'FR8215', 'Aircraft'] = 'Boeing 737-800'
df_27.loc[df_27['Num_flight'] == 'FR8215', 'flight_capacity'] = 189

# %%
df_por_fecha['27/Nov/2025'] = df_27.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_28 = df_por_fecha['28/Nov/2025'].copy()
df_28
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight    Name_Destiny  \
# 1456         NaN   28/Nov/2025  easyJet Europe     EC7105    Geneva (GVA)
# 1457         NaN   28/Nov/2025         Ryanair     FR8183   Bologna (BLQ)
# 1458         NaN   28/Nov/2025         Ryanair     FR8231    London (STN)
# 1459         NaN   28/Nov/2025         Ryanair      FR777    Venice (VCE)
# 1460         NaN   28/Nov/2025         Ryanair      FR846     Milan (BGY)
# ...          ...           ...             ...        ...             ...
# 1619         NaN   28/Nov/2025        Wizz Air     W64116  Belgrade (BEG)
# 1620         NaN   28/Nov/2025         Ryanair     FR3080    Malaga (AGP)
# 1621         NaN   28/Nov/2025  Wizz Air Malta     W45154    Tirana (TIA)
# 1622         NaN   28/Nov/2025        Wizz Air     W61706    Gdansk (GDN)
# 1623         NaN   28/Nov/2025         Ryanair     FR9814    London (STN)
#
#      Time_flight                flight_state  flight_capacity  \
# ...

# %%
df_28.isna().sum()
# Out:
# Unnamed: 0         168
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    168
# Aircraft           142
# Gate                 3
# dtype: int64

# %%
df_28[(df_28['Gate'].isna())]
# Out:
#       Unnamed: 0 fecha_scrapeo Name_company Num_flight      Name_Destiny  \
# 1504         NaN   28/Nov/2025      Ryanair      FR269       Milan (MXP)
# 1521         NaN   28/Nov/2025     Wizz Air     W67022  Bratislava (BTS)
# 1537         NaN   28/Nov/2025     Wizz Air     W64406       Sofia (SOF)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# 1504       11:20              Cancelado 11:20              NaN      NaN  NaN
# 1521       12:55  Retrasado, Programado 15:25              NaN      NaN  NaN
# 1537       14:50  Retrasado, Programado 15:20              NaN      NaN  NaN

# %%
df_28= df_28.drop(1504)

# %%
df_28.loc[df_28['Num_flight'] == 'W67022', 'Gate'] = 'S'

# %%
df_28.loc[df_28['Num_flight'] == 'W64406', 'Gate'] = 'R'

# %%
df_28[(df_28['flight_capacity'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight  \
# 1456         NaN   28/Nov/2025  easyJet Europe     EC7105
# 1457         NaN   28/Nov/2025         Ryanair     FR8183
# 1458         NaN   28/Nov/2025         Ryanair     FR8231
# 1459         NaN   28/Nov/2025         Ryanair      FR777
# 1460         NaN   28/Nov/2025         Ryanair      FR846
# 1461         NaN   28/Nov/2025         Ryanair      FR133
# 1462         NaN   28/Nov/2025         Ryanair     FR4545
# 1463         NaN   28/Nov/2025  easyJet Europe     EC7101
# 1464         NaN   28/Nov/2025  easyJet Europe     EC7199
# 1465         NaN   28/Nov/2025    Lauda Europe     LW2889
#
#                            Name_Destiny Time_flight  \
# 1456                       Geneva (GVA)       06:10
# 1457                      Bologna (BLQ)       06:10
# 1458                       London (STN)       06:10
# 1459                       Venice (VCE)       06:20
# 1460                        Milan (BGY)       06:25
# ...

# %%
df_28.loc[df_28['Num_flight'] == 'FR9814', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR9814', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W61706', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W45154', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR3080', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR3080', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W64116', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2250', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6597', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'RR6944', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR2495', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2495', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC7682', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'EC7682', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR9811', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR8669', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR7808', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3174', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'U23374', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'U23374', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EI565', 'flight_capacity'] = 174

df_28.loc[df_28['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'RR8394', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_28.loc[df_28['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_28.loc[df_28['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_28.loc[df_28['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_28.loc[df_28['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR5710', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'LG3592', 'Aircraft'] = 'Boeing 737-700'
df_28.loc[df_28['Num_flight'] == 'LG3592', 'flight_capacity'] = 142

df_28.loc[df_28['Num_flight'] == 'RR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'RR1786', 'flight_capacity'] = 197

# %%
df_28.loc[df_28['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'JU585', 'flight_capacity'] = 144

df_28.loc[df_28['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR8631', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR7539', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'V72135', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'V72135', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'TW408', 'Aircraft'] = 'Airbus A330-200'
df_28.loc[df_28['Num_flight'] == 'TW408', 'flight_capacity'] = 246

df_28.loc[df_28['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W42940', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W62096', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6305', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6275', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR2402', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR1527', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W64666', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'EW2521', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR6374', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6374', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'U28058', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'LW7362', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'LW7362', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'FR2330', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2330', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'EW9443', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'V72165', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'RR6330', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'RR6330', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR149', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W61478', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2098', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == '5F5512', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == '5F5512', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == '3O398', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == '3O398', 'flight_capacity'] = 174

df_28.loc[df_28['Num_flight'] == 'EC7205', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7205', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR6353', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR6353', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'HV5134', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'V73573', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR3076', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W67920', 'flight_capacity'] = 239

# %%
df_28.loc[df_28['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR4587', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR878', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W43564', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'W43564', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6985', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR2925', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2925', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'D85510', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'PC1094', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR483', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR483', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'V73735', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'QS1059', 'Aircraft'] = 'Airbus A220-300'
df_28.loc[df_28['Num_flight'] == 'QS1059', 'flight_capacity'] = 149

df_28.loc[df_28['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR867', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W64406', 'flight_capacity'] = 239

# %%
df_28.loc[df_28['Num_flight'] == 'V71443', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'V71443', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR8215', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR8215', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_28.loc[df_28['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_28.loc[df_28['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_28.loc[df_28['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_28.loc[df_28['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR6078', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6078', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'TK608', 'flight_capacity'] = 165

df_28.loc[df_28['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'PC1528', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'H4264', 'flight_capacity'] = 186

df_28.loc[df_28['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W46330', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W67022', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6874', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'PC1092', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR575', 'flight_capacity'] = 197

# %%
df_28.loc[df_28['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'D83657', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 757-200'
df_28.loc[df_28['Num_flight'] == 'FI597', 'flight_capacity'] = 184

df_28.loc[df_28['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'RR3049', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC7141', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7141', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'LW2896', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'LW2896', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR3121', 'flight_capacity'] = 197

# %%
df_28.loc[df_28['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EI563', 'flight_capacity'] = 174

df_28.loc[df_28['Num_flight'] == '3F232', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == '3F232', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR5270', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320neo'
df_28.loc[df_28['Num_flight'] == 'U22704', 'flight_capacity'] = 186

df_28.loc[df_28['Num_flight'] == 'HV6064', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'HV6064', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

# %%
df_28.loc[df_28['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320neo'
df_28.loc[df_28['Num_flight'] == 'U22002', 'flight_capacity'] = 186

df_28.loc[df_28['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EW7521', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'HV5132', 'flight_capacity'] = 232

df_28.loc[df_28['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR6920', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR9015', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'JU581', 'flight_capacity'] = 144

df_28.loc[df_28['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

# %%
df_28.loc[df_28['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == '3O378', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'U26654', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'U26654', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR3028', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W45088', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_28.loc[df_28['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_28.loc[df_28['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == '3O374', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == '3O374', 'flight_capacity'] = 180

# %%
df_28.loc[df_28['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR2834', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'EC3737', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_28.loc[df_28['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_28.loc[df_28['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR1165', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR6973', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR3185', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR3976', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'D85502', 'flight_capacity'] = 189

# %%
df_28.loc[df_28['Num_flight'] == 'LW2889', 'Aircraft'] = 'Airbus A320'
df_28.loc[df_28['Num_flight'] == 'LW2889', 'flight_capacity'] = 180

df_28.loc[df_28['Num_flight'] == 'EC7199', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7199', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_28.loc[df_28['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_28.loc[df_28['Num_flight'] == 'FR777', 'flight_capacity'] = 197

df_28.loc[df_28['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'FR8183', 'Aircraft'] = 'Boeing 737-800'
df_28.loc[df_28['Num_flight'] == 'FR8183', 'flight_capacity'] = 189

df_28.loc[df_28['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_28.loc[df_28['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

# %%
df_por_fecha['28/Nov/2025'] = df_28.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_29 = df_por_fecha['29/Nov/2025'].copy()
df_29
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 1624         NaN   29/Nov/2025           Ryanair      FR846
# 1625         NaN   29/Nov/2025    easyJet Europe     EC7105
# 1626         NaN   29/Nov/2025           Ryanair     FR5718
# 1627         NaN   29/Nov/2025           Ryanair     FR4545
# 1628         NaN   29/Nov/2025           Ryanair     FR1342
# ...          ...           ...               ...        ...
# 1737         NaN   29/Nov/2025    Wizz Air Malta     W46020
# 1738         NaN   29/Nov/2025           Ryanair     FR3800
# 1739         NaN   29/Nov/2025           Ryanair     FR8574
# 1740         NaN   29/Nov/2025          Wizz Air     W64116
# 1741         NaN   29/Nov/2025  Air Arabia Maroc      3O642
#
#                  Name_Destiny Time_flight                 flight_state  \
# 1624              Milan (BGY)       06:00           En hora, Ha salido
# 1625             Geneva (GVA)       06:10           En hora, Ha salido
# ...

# %%
df_29.isna().sum()
# Out:
# Unnamed: 0         118
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    112
# Aircraft            97
# Gate                 1
# dtype: int64

# %%
df_29[(df_29['Gate'].isna())]
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight       Name_Destiny  \
# 1686         NaN   29/Nov/2025  Kuwait Airways      KU136  Kuwait City (KWI)
#
#      Time_flight         flight_state  flight_capacity Aircraft Gate
# 1686       14:25  En hora, Programado              NaN      NaN  NaN

# %%
df_29.loc[df_29['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-800'
df_29.loc[df_29['Num_flight'] == 'KU136', 'Gate'] = 'W'
df_29.loc[df_29['Num_flight'] == 'KU136', 'flight_capacity'] = 235

# %%
df_29[(df_29['flight_capacity'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight      Name_Destiny  \
# 1624         NaN   29/Nov/2025           Ryanair      FR846       Milan (BGY)
# 1625         NaN   29/Nov/2025    easyJet Europe     EC7105      Geneva (GVA)
# 1626         NaN   29/Nov/2025           Ryanair     FR5718  Bratislava (BTS)
# 1627         NaN   29/Nov/2025           Ryanair     FR4545       Porto (OPO)
# 1629         NaN   29/Nov/2025           Ryanair      FR777      Venice (VCE)
# 1630         NaN   29/Nov/2025    easyJet Europe     EC7151       Milan (MXP)
# 1631         NaN   29/Nov/2025           Ryanair     FR2918    Brussels (BRU)
# 1632         NaN   29/Nov/2025           Ryanair     FR3180        Rome (FCO)
# 1633         NaN   29/Nov/2025  Air Arabia Maroc      3O376   Al Aaroui (NDR)
# 1635         NaN   29/Nov/2025           Ryanair      FR575     Bologna (BLQ)
#
#      Time_flight        flight_state  flight_capacity Aircraft Gate
# ...

# %%
df_29.loc[df_29['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == '3O642', 'flight_capacity'] = 174

df_29.loc[df_29['Num_flight'] == 'FR8574', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR8574', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR3800', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3800', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'RR3039', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'RR3039', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR5220', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'W43406', 'flight_capacity'] = 180

# %%
df_29.loc[df_29['Num_flight'] == 'TW408', 'Aircraft'] = 'BOEING 777-300ER'
df_29.loc[df_29['Num_flight'] == 'TW408', 'flight_capacity'] = 294

df_29.loc[df_29['Num_flight'] == 'FR9581', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR9581', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR3182', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3182', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_29.loc[df_29['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_29.loc[df_29['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_29.loc[df_29['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_29.loc[df_29['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3174', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_29.loc[df_29['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

# %%
df_29.loc[df_29['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR867', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_29.loc[df_29['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_29.loc[df_29['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR5270', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W61176', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR3792', 'flight_capacity'] = 197

# %%
df_29.loc[df_29['Num_flight'] == 'BT878', 'Aircraft'] = 'Airbus A220-300'
df_29.loc[df_29['Num_flight'] == 'BT878', 'flight_capacity'] = 148

df_29.loc[df_29['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321'
df_29.loc[df_29['Num_flight'] == 'W64406', 'flight_capacity'] = 230

df_29.loc[df_29['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR149', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'TO4757', 'Aircraft'] = 'Airbus A320neo'
df_29.loc[df_29['Num_flight'] == 'TO4757', 'flight_capacity'] = 186

df_29.loc[df_29['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'V72327', 'flight_capacity'] = 180

# %%
df_29.loc[df_29['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR3035', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'HV5134', 'flight_capacity'] = 232

df_29.loc[df_29['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR878', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'BZ251', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'BZ251', 'flight_capacity'] = 180

df_29.loc[df_29['Num_flight'] == 'FR6353', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR6353', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR2925', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR2925', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR6874', 'flight_capacity'] = 189

# %%
df_29.loc[df_29['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR9015', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR3146', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3146', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR7543', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR7543', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR3807', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

# %%
df_29.loc[df_29['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'RR6920', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'RR6920', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_29.loc[df_29['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_29.loc[df_29['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == '3O378', 'flight_capacity'] = 174

df_29.loc[df_29['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR2098', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'RK6597', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'RK6597', 'flight_capacity'] = 189

# %%
df_29.loc[df_29['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR7808', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W46330', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'OB775', 'Aircraft'] = 'Airbus A330-200'
df_29.loc[df_29['Num_flight'] == 'OB775', 'flight_capacity'] = 246

df_29.loc[df_29['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_29.loc[df_29['Num_flight'] == 'PC1092', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3108', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

# %%
df_29.loc[df_29['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'EI563', 'flight_capacity'] = 174

df_29.loc[df_29['Num_flight'] == 'EC7193', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC7193', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'FR4597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR4597', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320neo'
df_29.loc[df_29['Num_flight'] == 'U22704', 'flight_capacity'] = 186

df_29.loc[df_29['Num_flight'] == 'U5406', 'Aircraft'] = 'Boeing 737-700'
df_29.loc[df_29['Num_flight'] == 'U5406', 'flight_capacity'] = 149

df_29.loc[df_29['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'J246', 'flight_capacity'] = 122

df_29.loc[df_29['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_29.loc[df_29['Num_flight'] == 'FR9307', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR9307', 'flight_capacity'] = 197

# %%
df_29.loc[df_29['Num_flight'] == 'FR3168', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3168', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'U22326', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'FR9171', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR9171', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'HV5132', 'flight_capacity'] = 232

df_29.loc[df_29['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'FR6559', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR6559', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'JU581', 'flight_capacity'] = 144

df_29.loc[df_29['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'RR3049', 'flight_capacity'] = 189

# %%
df_29.loc[df_29['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W61914', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR2834', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_29.loc[df_29['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_29.loc[df_29['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == 'W43938', 'flight_capacity'] = 180

df_29.loc[df_29['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

# %%
df_29.loc[df_29['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_29.loc[df_29['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_29.loc[df_29['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_29.loc[df_29['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

df_29.loc[df_29['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_29.loc[df_29['Num_flight'] == '3O376', 'flight_capacity'] = 189

df_29.loc[df_29['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_29.loc[df_29['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

# %%
df_por_fecha['29/Nov/2025'] = df_29.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_30 = df_por_fecha['30/Nov/2025'].copy()
df_30
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight     Name_Destiny  \
# 1742         NaN   30/Nov/2025         Ryanair     FR3180       Rome (FCO)
# 1743         NaN   30/Nov/2025         Ryanair     FR2834  Charleroi (CRL)
# 1744         NaN   30/Nov/2025         Ryanair     FR2918   Brussels (BRU)
# 1745         NaN   30/Nov/2025         Ryanair     FR4084     Warsaw (WMI)
# 1746         NaN   30/Nov/2025         Ryanair     FR2239  Marrakech (RAK)
# ...          ...           ...             ...        ...              ...
# 1897         NaN   30/Nov/2025        Wizz Air     W64116   Belgrade (BEG)
# 1898         NaN   30/Nov/2025  Wizz Air Malta     W45154     Tirana (TIA)
# 1899         NaN   30/Nov/2025         Ryanair     FR5220    Bologna (BLQ)
# 1900         NaN   30/Nov/2025        Wizz Air     W61706     Gdansk (GDN)
# 1901         NaN   30/Nov/2025         Ryanair     FR9406        Fes (FEZ)
#
# ...

# %%
df_30.isna().sum()
# Out:
# Unnamed: 0         160
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    150
# Aircraft           144
# Gate                 3
# dtype: int64

# %%
df_30[(df_30['flight_capacity'].isna())].head(10)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight  \
# 1742         NaN   30/Nov/2025         Ryanair     FR3180
# 1743         NaN   30/Nov/2025         Ryanair     FR2834
# 1744         NaN   30/Nov/2025         Ryanair     FR2918
# 1745         NaN   30/Nov/2025         Ryanair     FR4084
# 1746         NaN   30/Nov/2025         Ryanair     FR2239
# 1747         NaN   30/Nov/2025         Ryanair     FR2507
# 1748         NaN   30/Nov/2025  easyJet Europe     EC7101
# 1749         NaN   30/Nov/2025  easyJet Europe     EC7191
# 1750         NaN   30/Nov/2025         Ryanair     FR6597
# 1751         NaN   30/Nov/2025         Ryanair     FR3108
#
#                            Name_Destiny Time_flight        flight_state  \
# 1742                         Rome (FCO)       06:00  En hora, Ha salido
# 1743                    Charleroi (CRL)       06:10  En hora, Ha salido
# 1744                     Brussels (BRU)       06:25  En hora, Ha salido
# ...

# %%
df_30.loc[df_30['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR9406', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W61706', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR5220', 'flight_capacity'] = 197

# %%
df_30.loc[df_30['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W45154', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W64116', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'U22706', 'Aircraft'] = 'Airbus A320neo'
df_30.loc[df_30['Num_flight'] == 'U22706', 'flight_capacity'] = 186

df_30.loc[df_30['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'U28060', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'U28060', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'HV5134', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EI565', 'flight_capacity'] = 174

df_30.loc[df_30['Num_flight'] == 'RR8615', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'RR8615', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W64738', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W64738', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_30.loc[df_30['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_30.loc[df_30['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'RR6944', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR6275', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'TO4759', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'TO4759', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'LG3596', 'Aircraft'] = 'Boeing 737-700'
df_30.loc[df_30['Num_flight'] == 'LG3596', 'flight_capacity'] = 142

# %%
df_30.loc[df_30['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR4587', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EW2521', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'D83659', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'JU585', 'flight_capacity'] = 144

df_30.loc[df_30['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EW521', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR6985', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W62096', 'flight_capacity'] = 239

# %%
df_30.loc[df_30['Num_flight'] == 'FR8136', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR8136', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W64666', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'U28058', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR9015', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR5710', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC3750', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC3750', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'V72165', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FR3160', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3160', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'EC7159', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7159', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'W61176', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
df_30.loc[df_30['Num_flight'] == 'U25716', 'flight_capacity'] = 186

df_30.loc[df_30['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
df_30.loc[df_30['Num_flight'] == 'U25716', 'flight_capacity'] = 186

df_30.loc[df_30['Num_flight'] == 'HV6066', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'HV6066', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR8631', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'LS804', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'EC7109', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7109', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR6305', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR777', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'RR5252', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'RR5252', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'V73573', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR12', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'RR8394', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2250', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == '3O374', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == '3O374', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR8669', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR9814', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR9814', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC7173', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC7173', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2922', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == '3O378', 'flight_capacity'] = 174

# %%
df_30.loc[df_30['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR8669', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'QS1059', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR6973', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'EC7694', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC7694', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_30.loc[df_30['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_30.loc[df_30['Num_flight'] == 'RR3072', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'RR3072', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'HV5132', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'HV5132', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'XQ895', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'XQ895', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR6920', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_30.loc[df_30['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_30.loc[df_30['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'PC1092', 'flight_capacity'] = 220

df_30.loc[df_30['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR9811', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W46330', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'V71445', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'V71445', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR8598', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR8598', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR2511', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2511', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'EC7139', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC7139', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320neo'
df_30.loc[df_30['Num_flight'] == 'EI563', 'flight_capacity'] = 186

df_30.loc[df_30['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'J246', 'flight_capacity'] = 174

df_30.loc[df_30['Num_flight'] == 'V72167', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'V72167', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR1527', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR3976', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'V72327', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FI597', 'flight_capacity'] = 160

# %%
df_30.loc[df_30['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR3143', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR1279', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR7543', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR7543', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR6874', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'RR3049', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'RR8384', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'RR333', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W45088', 'flight_capacity'] = 230

df_30.loc[df_30['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_30.loc[df_30['Num_flight'] == 'W43176', 'flight_capacity'] = 230

# %%
df_30.loc[df_30['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EW7521', 'flight_capacity'] = 150

df_30.loc[df_30['Num_flight'] == 'RR3193', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'RR3193', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_30.loc[df_30['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_30.loc[df_30['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR3028', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'RR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'RR1786', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR878', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC3754', 'Aircraft'] = 'Airbus A320'
df_30.loc[df_30['Num_flight'] == 'EC3754', 'flight_capacity'] = 180

df_30.loc[df_30['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'D85510', 'flight_capacity'] = 189

# %%
df_30.loc[df_30['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3108', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR6597', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'EC7191', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7191', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_30.loc[df_30['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_30.loc[df_30['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR4084', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR4084', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_30.loc[df_30['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
df_30.loc[df_30['Num_flight'] == 'FR2834', 'flight_capacity'] = 197

df_30.loc[df_30['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_30.loc[df_30['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

# %%
df_30[(df_30['Aircraft'] == 'Airbus A320')].tail(30)
# Out:
#       Unnamed: 0 fecha_scrapeo         Name_company Num_flight  \
# 1755         NaN   30/Nov/2025       easyJet Europe     EC3754
# 1758         NaN   30/Nov/2025              Volotea     V73735
# 1778         NaN   30/Nov/2025         Lauda Europe     LW7351
# 1785         NaN   30/Nov/2025  Azerbaijan Airlines       J246
# 1789         NaN   30/Nov/2025       easyJet Europe     EC7139
# 1791         NaN   30/Nov/2025         Lauda Europe     LW2889
# 1797         NaN   30/Nov/2025              Volotea     V72167
# 1802         NaN   30/Nov/2025              Volotea     V71445
# 1806         NaN   30/Nov/2025       easyJet Europe     EC1380
# 1825         NaN   30/Nov/2025       easyJet Europe     EC7694
# 1827         NaN   30/Nov/2025     Air Arabia Maroc      3O378
# 1831         NaN   30/Nov/2025       easyJet Europe     EC7173
# 1834         NaN   30/Nov/2025     Air Arabia Maroc      3O374
# 1845         NaN   30/Nov/2025              Volotea     V73700
# ...

# %%
df_30[(df_30['Name_company'] == 'Air Arabia Maroc')]
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight      Name_Destiny  \
# 1827         NaN   30/Nov/2025  Air Arabia Maroc      3O378      Tanger (TNG)
# 1834         NaN   30/Nov/2025  Air Arabia Maroc      3O374  Casablanca (CMN)
#
#      Time_flight                flight_state  flight_capacity     Aircraft  \
# 1827       15:35  Retrasado, Ha salido 15:54            174.0  Airbus A320
# 1834       17:00          En hora, Ha salido            180.0  Airbus A320
#
#      Gate
# 1827  S24
# 1834  W42

# %%
df_30.loc[1820:1880].head(50)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 1820         NaN   30/Nov/2025        SmartWings     QS1059
# 1821         NaN   30/Nov/2025           Ryanair     FR3320
# 1822         NaN   30/Nov/2025           Ryanair      FR774
# 1823         NaN   30/Nov/2025              BUZZ     RR3072
# 1824         NaN   30/Nov/2025         Transavia     TO4755
# 1825         NaN   30/Nov/2025    easyJet Europe     EC7694
# 1826         NaN   30/Nov/2025           Ryanair     FR6973
# 1827         NaN   30/Nov/2025  Air Arabia Maroc      3O378
# 1828         NaN   30/Nov/2025    Wizz Air Malta     W46728
# 1829         NaN   30/Nov/2025           Ryanair      FR133
# 1830         NaN   30/Nov/2025           Ryanair     FR2922
# 1831         NaN   30/Nov/2025    easyJet Europe     EC7173
# 1832         NaN   30/Nov/2025           Ryanair     FR9814
# 1833         NaN   30/Nov/2025           Ryanair     FR8669
# 1834         NaN   30/Nov/2025  Air Arabia Maroc      3O374
# ...

# %%
start, end = 1822, 1861

# Reemplazar los valores desplazando hacia arriba dentro del rango
df_30.loc[start:end, 'Gate'] = df_30.loc[start+1:end+1, 'Gate'].values

# %%
df_30.loc[df_30['Num_flight'] == 'FR2233', 'Gate'] = 'W'

# %%
# 1822 -> s20 /1860 cambiar a u31- 1861 dejar

# %%
df_30[(df_30['Gate'].isna())]
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight     Name_Destiny  \
# 1815         NaN   30/Nov/2025         Transavia     HV5132  Amsterdam (AMS)
# 1818         NaN   30/Nov/2025  Bluebird Airways      BZ251   Tel Aviv (TLV)
# 1820         NaN   30/Nov/2025        SmartWings     QS1059     Prague (PRG)
#
#      Time_flight         flight_state  flight_capacity        Aircraft Gate
# 1815       14:20  En hora, Programado            189.0  Boeing 737-800  NaN
# 1818       14:45  En hora, Programado            189.0  Boeing 737-800  NaN
# 1820       14:55  En hora, Programado            189.0  Boeing 737-800  NaN

# %%
df_30.loc[df_30['Num_flight'] == 'HV5132', 'Gate'] = 'U'
df_30.loc[df_30['Num_flight'] == 'BZ251', 'Gate'] = 'Y'
df_30.loc[df_30['Num_flight'] == 'QS1059', 'Gate'] = 'U'

# %%
df_por_fecha['30/Nov/2025'] = df_30.copy()

# %%
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_mes1 = pd.concat([df_semanac, df_24, df_25, df_26, df_27, df_28, df_29, df_30 ], ignore_index=True)

# %%
df_mes1.reset_index(drop=True, inplace=True)

# %%
df_mes1.to_csv("vuelos_bcn_m1.csv")

# %%
#df_final = pd.concat(df_por_fecha.values(), ignore_index=True)
