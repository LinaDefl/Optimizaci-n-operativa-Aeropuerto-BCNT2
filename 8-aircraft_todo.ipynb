# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("vuelos_bcn_sindup.csv") 
df.head(10)
# Out:
#    Unnamed: 0        fecha_scrapeo              Name_company Num_flight  \
# 0         0.0  16/11/2025 23-03-05                   Ryanair     FR3166
# 1         1.0  16/11/2025 23-03-05  Norwegian Air Sweden AOC     D81741
# 2         2.0  16/11/2025 23-03-05                Aer Lingus      EI563
# 3         3.0  16/11/2025 23-03-05            easyJet Europe     EC7139
# 4         4.0  16/11/2025 23-03-05                Icelandair      FI597
# 5         5.0  16/11/2025 23-03-05              Lauda Europe     LW2889
# 6         6.0  16/11/2025 23-03-05                   Ryanair     FR3129
# 7         7.0  16/11/2025 23-03-05                   Ryanair     FR3976
# 8         8.0  16/11/2025 23-03-05                   Ryanair     FR1527
# 9         9.0  16/11/2025 23-03-05                   Ryanair     FR2402
#
#                  Name_Destiny Time_flight          flight_state  \
# 0               Palermo (PMO)       11:00             Ha salido
# ...

# %%
# Dividir en diccionario por fecha
df_por_fecha = {fecha: df_fecha.copy() for fecha, df_fecha in df.groupby('fecha_scrapeo')}
df_por_fecha
# Out:
# {'01/Dic/2025':       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
#  1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
#  1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
#  1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
#  1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
#  1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
#  ...          ...           ...             ...        ...               ...
#  2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
#  2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
#  2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
#  2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
#  2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_01 = df_por_fecha['01/Dic/2025'].copy()
df_01
# Lunes
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
# 1902         NaN   01/Dic/2025         Ryanair     FR3180        Rome (FCO)
# 1903         NaN   01/Dic/2025         Ryanair      FR846       Milan (BGY)
# 1904         NaN   01/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
# 1905         NaN   01/Dic/2025         Ryanair     FR2233   Al Aaroui (NDR)
# 1906         NaN   01/Dic/2025         Ryanair     FR8384    Budapest (BUD)
# ...          ...           ...             ...        ...               ...
# 2066         NaN   01/Dic/2025  Wizz Air Malta     W46728      Venice (VCE)
# 2067         NaN   01/Dic/2025         Ryanair     FR8574        Rome (FCO)
# 2068         NaN   01/Dic/2025  easyJet Europe     EC7682      Lisbon (LIS)
# 2069         NaN   01/Dic/2025  Wizz Air Malta     W45154      Tirana (TIA)
# 2070         NaN   01/Dic/2025         Ryanair     FR3800  Birmingham (BHX)
#
# ...

# %%
df_01.isna().sum()
# Out:
# Unnamed: 0         169
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    162
# Aircraft           149
# Gate                 4
# dtype: int64

# %%
df_01.loc[1990:2015]
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 1990         NaN   01/Dic/2025        SmartWings     QS1059
# 1991         NaN   01/Dic/2025  Air Arabia Maroc      3O376
# 1992         NaN   01/Dic/2025           Ryanair     FR3146
# 1993         NaN   01/Dic/2025           Ryanair     FR2330
# 1994         NaN   01/Dic/2025           Ryanair     FR1681
# 1995         NaN   01/Dic/2025          Wizz Air     W61412
# 1996         NaN   01/Dic/2025  Pegasus Airlines     PC1094
# 1997         NaN   01/Dic/2025           Ryanair      FR867
# 1998         NaN   01/Dic/2025           Ryanair     FR9811
# 1999         NaN   01/Dic/2025    Wizz Air Malta     W43564
# 2000         NaN   01/Dic/2025           Volotea     V73735
# 2001         NaN   01/Dic/2025           Ryanair     FR2507
# 2002         NaN   01/Dic/2025           Ryanair     FR5718
# 2003         NaN   01/Dic/2025           Ryanair     FR6305
# 2004         NaN   01/Dic/2025           Ryanair     FR6874
# ...

# %%
# 2004 -> U23372 M / 2013 EC3737 R

# %%
# 1992 y-> w / 2013 mantener igual

# %%
# 2013 subir a 2012

# %%
# 2011 error no es w es u

# %%
# 17;10  y 10:35 milan u34 -> R

# %%
# Rango a corregir
start, end = 1992,2013

# Reemplazar los valores desplazando hacia arriba dentro del rango
df_01.loc[start:end, 'Gate'] = df_01.loc[start+1:end+1, 'Gate'].values

# %%
df_01.loc[1990:2015]
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 1990         NaN   01/Dic/2025        SmartWings     QS1059
# 1991         NaN   01/Dic/2025  Air Arabia Maroc      3O376
# 1992         NaN   01/Dic/2025           Ryanair     FR3146
# 1993         NaN   01/Dic/2025           Ryanair     FR2330
# 1994         NaN   01/Dic/2025           Ryanair     FR1681
# 1995         NaN   01/Dic/2025          Wizz Air     W61412
# 1996         NaN   01/Dic/2025  Pegasus Airlines     PC1094
# 1997         NaN   01/Dic/2025           Ryanair      FR867
# 1998         NaN   01/Dic/2025           Ryanair     FR9811
# 1999         NaN   01/Dic/2025    Wizz Air Malta     W43564
# 2000         NaN   01/Dic/2025           Volotea     V73735
# 2001         NaN   01/Dic/2025           Ryanair     FR2507
# 2002         NaN   01/Dic/2025           Ryanair     FR5718
# 2003         NaN   01/Dic/2025           Ryanair     FR6305
# 2004         NaN   01/Dic/2025           Ryanair     FR6874
# ...

# %%
df_01.loc[df_01['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR5270', 'flight_capacity'] = 189

# %%
df_01.loc[df_01['Num_flight'] == 'EC3737', 'Gate'] = 'R'
df_01.loc[df_01['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC3737', 'flight_capacity'] = 156

# %%
df_01[(df_01['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 1902         NaN   01/Dic/2025                   Ryanair     FR3180
# 1903         NaN   01/Dic/2025                   Ryanair      FR846
# 1904         NaN   01/Dic/2025            easyJet Europe     EC7105
# 1905         NaN   01/Dic/2025                   Ryanair     FR2233
# 1906         NaN   01/Dic/2025                   Ryanair     FR8384
# 1907         NaN   01/Dic/2025                   Ryanair     FR3078
# 1908         NaN   01/Dic/2025            easyJet Europe     EC8062
# 1909         NaN   01/Dic/2025                   Ryanair     FR3035
# 1910         NaN   01/Dic/2025                   Ryanair     FR8215
# 1911         NaN   01/Dic/2025            easyJet Europe     EC7141
# 1912         NaN   01/Dic/2025            easyJet Europe     EC7151
# 1913         NaN   01/Dic/2025                   Ryanair     FR3028
# 1916         NaN   01/Dic/2025  Norwegian Air Sweden AOC     D85510
# ...

# %%
df_01.loc[df_01['Aircraft'] == 'B738', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Aircraft'] == 'B38M', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Aircraft'] == 'A320', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Aircraft'] == 'A21N', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Aircraft'] == 'A20N', 'Aircraft'] = 'Airbus A320neo'
df_01.loc[df_01['Aircraft'] == 'A319', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Aircraft'] == 'A321', 'Aircraft'] = 'Airbus A321'

# %%
df_01.loc[df_01['Aircraft'] == 'Boeing 737-800', 'flight_capacity'] = 189
df_01.loc[df_01['Aircraft'] == 'Boeing 737 MAX 8', 'flight_capacity'] = 197
df_01.loc[df_01['Aircraft'] == 'Airbus A320', 'flight_capacity'] = 180
df_01.loc[df_01['Aircraft'] == 'Airbus A321neo', 'flight_capacity'] = 239
df_01.loc[df_01['Aircraft'] == 'Airbus A320neo', 'flight_capacity'] = 186
df_01.loc[df_01['Aircraft'] == 'Airbus A319', 'flight_capacity'] = 156
df_01.loc[df_01['Aircraft'] == 'Airbus A321', 'flight_capacity'] = 230
#df_04.loc[df_04['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] = 174

# %%
df_01[(df_01['Gate'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight    Name_Destiny  \
# 1984         NaN   01/Dic/2025  Bluebird Airways      BZ251  Tel Aviv (TLV)
# 1987         NaN   01/Dic/2025           Volotea     V71443    Ancona (AOI)
# 1989         NaN   01/Dic/2025    easyJet Europe     EC4212    Napoli (NAP)
# 1990         NaN   01/Dic/2025        SmartWings     QS1059    Prague (PRG)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# 1984       14:45  Retrasado, Programado 14:56              NaN      NaN  NaN
# 1987       14:45          En hora, Programado              NaN      NaN  NaN
# 1989       14:55  Retrasado, Programado 15:23              NaN      NaN  NaN
# 1990       14:55          En hora, Programado              NaN      NaN  NaN

# %%
df_01.loc[df_01['Num_flight'] == 'V71443', 'Gate'] = 'R'
df_01.loc[df_01['Num_flight'] == 'EC4212', 'Gate'] = 'R'
df_01.loc[df_01['Num_flight'] == 'QS1059', 'Gate'] = 'S'
df_01.loc[df_01['Num_flight'] == 'BZ251', 'Gate'] = 'Y'

# %%
df_01[(df_01['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 1902         NaN   01/Dic/2025                   Ryanair     FR3180
# 1903         NaN   01/Dic/2025                   Ryanair      FR846
# 1904         NaN   01/Dic/2025            easyJet Europe     EC7105
# 1905         NaN   01/Dic/2025                   Ryanair     FR2233
# 1906         NaN   01/Dic/2025                   Ryanair     FR8384
# 1907         NaN   01/Dic/2025                   Ryanair     FR3078
# 1908         NaN   01/Dic/2025            easyJet Europe     EC8062
# 1911         NaN   01/Dic/2025            easyJet Europe     EC7141
# 1912         NaN   01/Dic/2025            easyJet Europe     EC7151
# 1913         NaN   01/Dic/2025                   Ryanair     FR3028
# 1916         NaN   01/Dic/2025  Norwegian Air Sweden AOC     D85510
# 1917         NaN   01/Dic/2025                   Ryanair       FR58
# 1918         NaN   01/Dic/2025                   Ryanair      FR575
# ...

# %%
df_01.loc[df_01['Name_company'] == 'Air Arabia Maroc', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] = 174

# %%
df_01.loc[df_01['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR5710', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'RR8394', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_01.loc[df_01['Num_flight'] == 'TO4759', 'flight_capacity'] =186

df_01.loc[df_01['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W62378', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2098', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3928', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'V72165', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR878', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EI565', 'flight_capacity'] =174

df_01.loc[df_01['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR6275', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6920', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EC1380', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W43178', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'W43406', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR2402', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2402', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'RR4084', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W46020', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'FR3168', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3168', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3800', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR3800', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W45154', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'EC7682', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'EC7682', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'FR8574', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR8574', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W46728', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W64116', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2250', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR1527', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR4587', 'flight_capacity'] =197

# %%
df_01.loc[df_01['Num_flight'] == 'V72135', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'V72135', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'TW408', 'Aircraft'] = 'Airbus A330-200'
df_01.loc[df_01['Num_flight'] == 'TW408', 'flight_capacity'] =246

df_01.loc[df_01['Num_flight'] == 'EC1010', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC1010', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W42940', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EC1956', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6597', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6341', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3807', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3080', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3080', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W64666', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'V71415', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'LW7351', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR133', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W61706', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'LW2896', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'LW2896', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EW7521', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3185', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W61478', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3174', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'W43686', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3320', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'EC7205', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7205', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR269', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'HV5134', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'EC7199', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7199', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2922', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR1786', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR1786', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W67920', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'V73700', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7173', 'flight_capacity'] =156

# %%
df_01.loc[df_01['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'RR6300', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'U23372', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'U23372', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6874', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6305', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR2507', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'V73735', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'V73735', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'W43564', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'W43564', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR9811', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR867', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'PC1094', 'flight_capacity'] =220

df_01.loc[df_01['Num_flight'] == 'W61412', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W61412', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR1681', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR2330', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2330', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3146', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3146', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'QS1059', 'Aircraft'] = 'Airbus A220-300'
df_01.loc[df_01['Num_flight'] == 'QS1059', 'flight_capacity'] =149

df_01.loc[df_01['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EC4212', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W64406', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'V71443', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'V71443', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'TK608', 'flight_capacity'] =162

df_01.loc[df_01['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7107', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'BZ251', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'D85502', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_01.loc[df_01['Num_flight'] == 'BT684', 'flight_capacity'] =149

df_01.loc[df_01['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3792', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'LS804', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3189', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR4585', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7153', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'
df_01.loc[df_01['Num_flight'] == 'LG3592', 'flight_capacity'] =76

df_01.loc[df_01['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7131', 'flight_capacity'] =156

# %%
df_01.loc[df_01['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'PC1528', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EW521', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'D81741', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'D81741', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'H4264', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR8631', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W46330', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR3108', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W67022', 'flight_capacity'] =239

df_01.loc[df_01['Num_flight'] == 'EC7137', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7137', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'D83657', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'PC1092', 'flight_capacity'] =230

df_01.loc[df_01['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR774', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR6973', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR8217', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR777', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'EC7197', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7197', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR1279', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'TO4755', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'TO4755', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR7539', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR7539', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EI563', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'U22002', 'flight_capacity'] =180

df_01.loc[df_01['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3976', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3121', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'U28056', 'flight_capacity'] =156

df_01.loc[df_01['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR7808', 'flight_capacity'] =197

df_01.loc[df_01['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3143', 'flight_capacity'] =189

df_01.loc[df_01['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W61476', 'flight_capacity'] = 230

df_01.loc[df_01['Num_flight'] == 'FR6559', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6559', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'FR9175', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR9175', 'flight_capacity'] = 189

# %%
df_01.loc[df_01['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_01.loc[df_01['Num_flight'] == 'HV5132', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'HV5132', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_01.loc[df_01['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'JU581', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'HV6062', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'HV6062', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2834', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'EC1030', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'EC1030', 'flight_capacity'] = 180

df_01.loc[df_01['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'V73573', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_01.loc[df_01['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W45088', 'flight_capacity'] = 230

df_01.loc[df_01['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_01.loc[df_01['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_01.loc[df_01['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EW2521', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_01.loc[df_01['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_01.loc[df_01['Num_flight'] == 'FR6078', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR6078', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_01.loc[df_01['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_01.loc[df_01['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR58', 'flight_capacity'] = 197

df_01.loc[df_01['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'D85510', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'EC7141', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7141', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC8062', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'FR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_01.loc[df_01['Num_flight'] == 'FR8384', 'flight_capacity'] = 197

df_01.loc[df_01['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_01.loc[df_01['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_01.loc[df_01['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_01.loc[df_01['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_01.loc[df_01['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

# %%
df_02 = df_por_fecha['02/Dic/2025'].copy()
df_02
# Martes
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight        Name_Destiny  \
# 2071         NaN   02/Dic/2025  easyJet Europe     EC7105        Geneva (GVA)
# 2072         NaN   02/Dic/2025         Ryanair     FR2918      Brussels (BRU)
# 2073         NaN   02/Dic/2025         Ryanair     FR3189           Fes (FEZ)
# 2074         NaN   02/Dic/2025         Ryanair     FR2507  Cologne-Bonn (CGN)
# 2075         NaN   02/Dic/2025         Ryanair     FR4545         Porto (OPO)
# ...          ...           ...             ...        ...                 ...
# 2138         NaN   02/Dic/2025       Transavia     TO4759         Paris (ORY)
# 2139         NaN   02/Dic/2025  easyJet Europe     EC1380        Geneva (GVA)
# 2140         NaN   02/Dic/2025         Ryanair     FR6394        Dublin (DUB)
# 2141         NaN   02/Dic/2025  Wizz Air Malta     W46020          Rome (FCO)
# 2142         NaN   02/Dic/2025         Ryanair     FR4585         Porto (OPO)
#
# ...

# %%
df_02.isna().sum()
# Out:
# Unnamed: 0         72
# fecha_scrapeo       0
# Name_company        1
# Num_flight          0
# Name_Destiny        0
# Time_flight         0
# flight_state        0
# flight_capacity    70
# Aircraft           62
# Gate                1
# dtype: int64

# %%
df_02 = df_02.drop([2131])

# %%
df_02[(df_02['Gate'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight    Name_Destiny  \
# 2115         NaN   02/Dic/2025  Bluebird Airways      BZ251  Tel Aviv (TLV)
#
#      Time_flight         flight_state  flight_capacity Aircraft Gate
# 2115       14:45  En hora, Programado              NaN      NaN  NaN

# %%
df_02.loc[df_02['Num_flight'] == 'BZ251', 'Gate'] = 'Y'

# %%
df_02[(df_02['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo         Name_company Num_flight  \
# 2071         NaN   02/Dic/2025       easyJet Europe     EC7105
# 2072         NaN   02/Dic/2025              Ryanair     FR2918
# 2073         NaN   02/Dic/2025              Ryanair     FR3189
# 2074         NaN   02/Dic/2025              Ryanair     FR2507
# 2075         NaN   02/Dic/2025              Ryanair     FR4545
# 2076         NaN   02/Dic/2025       easyJet Europe     EC7101
# 2077         NaN   02/Dic/2025       easyJet Europe     EC8062
# 2078         NaN   02/Dic/2025              Ryanair     FR3166
# 2079         NaN   02/Dic/2025              Ryanair     FR5718
# 2080         NaN   02/Dic/2025              Ryanair     FR3193
# 2081         NaN   02/Dic/2025       easyJet Europe     EC3737
# 2082         NaN   02/Dic/2025              Ryanair     FR6973
# 2083         NaN   02/Dic/2025              Ryanair      FR133
# 2084         NaN   02/Dic/2025       Wizz Air Malta     W43938
# ...

# %%
df_02.loc[df_02['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR6267', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_02.loc[df_02['Num_flight'] == 'PC1092', 'flight_capacity'] = 220

df_02.loc[df_02['Num_flight'] == 'FR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR8384', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'D83657', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR3108', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FI597', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'EI563', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR3035', 'flight_capacity'] = 189

# %%
df_02[(df_02['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo         Name_company Num_flight  \
# 2071         NaN   02/Dic/2025       easyJet Europe     EC7105
# 2072         NaN   02/Dic/2025              Ryanair     FR2918
# 2073         NaN   02/Dic/2025              Ryanair     FR3189
# 2074         NaN   02/Dic/2025              Ryanair     FR2507
# 2075         NaN   02/Dic/2025              Ryanair     FR4545
# 2076         NaN   02/Dic/2025       easyJet Europe     EC7101
# 2077         NaN   02/Dic/2025       easyJet Europe     EC8062
# 2078         NaN   02/Dic/2025              Ryanair     FR3166
# 2079         NaN   02/Dic/2025              Ryanair     FR5718
# 2080         NaN   02/Dic/2025              Ryanair     FR3193
# 2081         NaN   02/Dic/2025       easyJet Europe     EC3737
# 2082         NaN   02/Dic/2025              Ryanair     FR6973
# 2083         NaN   02/Dic/2025              Ryanair      FR133
# 2084         NaN   02/Dic/2025       Wizz Air Malta     W43938
# ...

# %%
df_02.loc[df_02['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W46020', 'flight_capacity'] = 239

# %%
df_02.loc[df_02['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_02.loc[df_02['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_02.loc[df_02['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'RR4084', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == '3O642', 'flight_capacity'] = 174

df_02.loc[df_02['Num_flight'] == 'HV6790', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'HV6790', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'U28058', 'flight_capacity'] = 156

df_02.loc[df_02['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR9015', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_02.loc[df_02['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_02.loc[df_02['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W61176', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'RR6300', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_02.loc[df_02['Num_flight'] == 'HV5134', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'HV5134', 'flight_capacity'] = 232

df_02.loc[df_02['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'V72327', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR575', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR8217', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'EC7682', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'EC7682', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-900'
df_02.loc[df_02['Num_flight'] == 'KU136', 'flight_capacity'] = 278

df_02.loc[df_02['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR3076', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == '5F5512', 'Aircraft'] = 'Airbus A321'
df_02.loc[df_02['Num_flight'] == '5F5512', 'flight_capacity'] = 194

df_02.loc[df_02['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_02.loc[df_02['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

# %%
df_02.loc[df_02['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320neo'
df_02.loc[df_02['Num_flight'] == 'J246', 'flight_capacity'] = 186

df_02.loc[df_02['Num_flight'] == 'U22324', 'Aircraft'] = 'Airbus A320neo'
df_02.loc[df_02['Num_flight'] == 'U22324', 'flight_capacity'] = 186

df_02.loc[df_02['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR5270', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR1279', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'EC7656', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'JU581', 'flight_capacity'] = 144

df_02.loc[df_02['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == '3O378', 'flight_capacity'] = 174

df_02.loc[df_02['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321'
df_02.loc[df_02['Num_flight'] == 'W62376', 'flight_capacity'] = 230

df_02.loc[df_02['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_02.loc[df_02['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_02.loc[df_02['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W61914', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR3807', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_02.loc[df_02['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_02.loc[df_02['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
df_02.loc[df_02['Num_flight'] == 'W43938', 'flight_capacity'] = 180

df_02.loc[df_02['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR6973', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC3737', 'flight_capacity'] = 156

df_02.loc[df_02['Num_flight'] == 'FR3193', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR3193', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC8062', 'flight_capacity'] = 156

df_02.loc[df_02['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_02.loc[df_02['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_02.loc[df_02['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_02.loc[df_02['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_02.loc[df_02['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_02.loc[df_02['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_02.loc[df_02['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

# %%
df_02['Aircraft'].unique()
# Out:
# array(['Airbus A319', 'Boeing 737-800', 'Boeing 737 MAX 8', 'Airbus A320',
#        'Airbus A321neo', 'Airbus A321', 'Airbus A320neo',
#        'Airbus A330-900'], dtype=object)

# %%
df_02['flight_capacity'].unique()
# Out:
# array([156., 189., 197., 180., 239., 230., 174., 144., 186., 220., 194.,
#        278., 232.])

# %%
df_02['Gate'].unique()
# Out:
# array(['R10', 'S21', 'Y59', 'S23', 'U37', 'R13', 'M6', 'S20', 'S22',
#        'R14', 'R9', 'U31', 'U35', 'Y58', 'U36', 'S24', 'U32', 'U34',
#        'U33', 'S25', 'Y57', 'W44', 'W45', 'Y54', 'U41', 'W46', 'W42',
#        'W43', 'Y', 'U', 'R11', 'M8'], dtype=object)

# %%
df_03 = df_por_fecha['03/Dic/2025'].copy()
df_03
# Miercoles
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight       Name_Destiny  \
# 2143         NaN   03/Dic/2025         Ryanair     FR2918     Brussels (BRU)
# 2144         NaN   03/Dic/2025         Ryanair     FR3185        Rabat (RBA)
# 2145         NaN   03/Dic/2025         Ryanair     FR9406          Fes (FEZ)
# 2146         NaN   03/Dic/2025  easyJet Europe     EC7105       Geneva (GVA)
# 2147         NaN   03/Dic/2025         Ryanair      FR483       Malaga (AGP)
# ...          ...           ...             ...        ...                ...
# 2228         NaN   03/Dic/2025         Easyjet     U22326       London (LTN)
# 2229         NaN   03/Dic/2025  easyJet Europe     EC1380       Geneva (GVA)
# 2230         NaN   03/Dic/2025  Wizz Air Malta     W43406  Cluj-Napoca (CLJ)
# 2231         NaN   03/Dic/2025  Wizz Air Malta     W46020         Rome (FCO)
# 2232         NaN   03/Dic/2025         Ryanair     FR6394       Dublin (DUB)
#
# ...

# %%
df_03.isna().sum()
# Out:
# Unnamed: 0         90
# fecha_scrapeo       0
# Name_company        0
# Num_flight          0
# Name_Destiny        0
# Time_flight         0
# flight_state        0
# flight_capacity    86
# Aircraft           82
# Gate                1
# dtype: int64

# %%
df_03[(df_03['Gate'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  Name_Destiny  \
# 2166         NaN   03/Dic/2025  Air Arabia Maroc      3O642  Tanger (TNG)
#
#      Time_flight        flight_state  flight_capacity Aircraft Gate
# 2166       10:05  En hora, Ha salido              NaN      NaN  NaN

# %%
df_03.loc[df_03['Num_flight'] == '3O642', 'Gate'] = 'Y'

# %%
df_03[(df_03['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2143         NaN   03/Dic/2025                   Ryanair     FR2918
# 2144         NaN   03/Dic/2025                   Ryanair     FR3185
# 2145         NaN   03/Dic/2025                   Ryanair     FR9406
# 2146         NaN   03/Dic/2025            easyJet Europe     EC7105
# 2148         NaN   03/Dic/2025            easyJet Europe     EC7193
# 2149         NaN   03/Dic/2025                   Ryanair     FR2239
# 2150         NaN   03/Dic/2025                   Ryanair     FR3028
# 2151         NaN   03/Dic/2025                   Ryanair     FR3108
# 2152         NaN   03/Dic/2025            easyJet Europe     EC7101
# 2153         NaN   03/Dic/2025            easyJet Europe     EC8062
# 2155         NaN   03/Dic/2025                   Ryanair      FR846
# 2156         NaN   03/Dic/2025            easyJet Europe     EC3737
# 2157         NaN   03/Dic/2025            easyJet Europe     EC7161
# ...

# %%
df_03.loc[df_03['Num_flight'] == 'HV6064', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'HV6064', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR9334', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR9334', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'PC1094', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'U22704', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'D85544', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'D85544', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR3108', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR3108', 'flight_capacity'] = 197

# %%
df_03[(df_03['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 2143         NaN   03/Dic/2025           Ryanair     FR2918
# 2144         NaN   03/Dic/2025           Ryanair     FR3185
# 2145         NaN   03/Dic/2025           Ryanair     FR9406
# 2146         NaN   03/Dic/2025    easyJet Europe     EC7105
# 2148         NaN   03/Dic/2025    easyJet Europe     EC7193
# 2149         NaN   03/Dic/2025           Ryanair     FR2239
# 2150         NaN   03/Dic/2025           Ryanair     FR3028
# 2152         NaN   03/Dic/2025    easyJet Europe     EC7101
# 2153         NaN   03/Dic/2025    easyJet Europe     EC8062
# 2155         NaN   03/Dic/2025           Ryanair      FR846
# 2156         NaN   03/Dic/2025    easyJet Europe     EC3737
# 2157         NaN   03/Dic/2025    easyJet Europe     EC7161
# 2158         NaN   03/Dic/2025    Wizz Air Malta     W43176
# 2159         NaN   03/Dic/2025          Wizz Air     W62376
# 2160         NaN   03/Dic/2025              BUZZ     RR8384
# ...

# %%
df_03.loc[df_03['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR6394', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320neo'
df_03.loc[df_03['Num_flight'] == 'W43406', 'flight_capacity'] = 186

df_03.loc[df_03['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_03.loc[df_03['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_03.loc[df_03['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_03.loc[df_03['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_03.loc[df_03['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'FB585', 'Aircraft'] = 'Embraer ERJ-190'
df_03.loc[df_03['Num_flight'] == 'FB585', 'flight_capacity'] = 108

df_03.loc[df_03['Num_flight'] == 'TW408', 'Aircraft'] = 'BOEING 777-300ER'
df_03.loc[df_03['Num_flight'] == 'TW408', 'flight_capacity'] = 294

df_03.loc[df_03['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == '3O378', 'flight_capacity'] = 174

df_03.loc[df_03['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'RR5246', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'RR5246', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3143', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'U28058', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR133', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'EW9443', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR1342', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'FR1165', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR1165', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

# %%
df_03.loc[df_03['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'RR8394', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EC8060', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC8060', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'E9803', 'Aircraft'] = 'Airbus A350-900'
df_03.loc[df_03['Num_flight'] == 'E9803', 'flight_capacity'] = 432

df_03.loc[df_03['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR4585', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321'
df_03.loc[df_03['Num_flight'] == 'W67920', 'flight_capacity'] = 230

df_03.loc[df_03['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_03.loc[df_03['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_03.loc[df_03['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR3035', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'W61412', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W61412', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'EC7682', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'EC7682', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR12', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EW2521', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'D83659', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'V72327', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'TK608', 'flight_capacity'] = 162

df_03.loc[df_03['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'EW521', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'H4264', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR6597', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_03.loc[df_03['Num_flight'] == 'PC1092', 'flight_capacity'] = 230

df_03.loc[df_03['Num_flight'] == 'FR9925', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR9925', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'EI563', 'flight_capacity'] = 174

# %%
df_03.loc[df_03['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR2507', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'U5406', 'Aircraft'] = 'Boeing 737-700'
df_03.loc[df_03['Num_flight'] == 'U5406', 'flight_capacity'] = 141

df_03.loc[df_03['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR6267', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'BT878', 'Aircraft'] = 'Airbus A220-300'
df_03.loc[df_03['Num_flight'] == 'BT878', 'flight_capacity'] = 148

df_03.loc[df_03['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == 'U22002', 'flight_capacity'] = 180

df_03.loc[df_03['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3039', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'HV5132', 'flight_capacity'] = 232

df_03.loc[df_03['Num_flight'] == '3O642', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == '3O642', 'flight_capacity'] = 174

df_03.loc[df_03['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'RR3049', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_03.loc[df_03['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_03.loc[df_03['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR2834', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W42940', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == '3O376', 'Aircraft'] = 'Airbus A320'
df_03.loc[df_03['Num_flight'] == '3O376', 'flight_capacity'] = 174

df_03.loc[df_03['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_03.loc[df_03['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_03.loc[df_03['Num_flight'] == 'EC7161', 'Aircraft'] = 'Airbus A320neo'
df_03.loc[df_03['Num_flight'] == 'EC7161', 'flight_capacity'] = 186

df_03.loc[df_03['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC3737', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EC8062', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC8062', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'EC7193', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC7193', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_03.loc[df_03['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_03.loc[df_03['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR9406', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR3185', 'flight_capacity'] = 189

df_03.loc[df_03['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_03.loc[df_03['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

# %%
df_04 = df_por_fecha['04/Dic/2025'].copy()
df_04
# Jueves
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight    Name_Destiny  \
# 2233         NaN   04/Dic/2025         Ryanair     FR8215    London (STN)
# 2234         NaN   04/Dic/2025  easyJet Europe     EC7105    Geneva (GVA)
# 2235         NaN   04/Dic/2025         Ryanair     FR3976    Dublin (DUB)
# 2236         NaN   04/Dic/2025  easyJet Europe     EC7191   Glasgow (GLA)
# 2237         NaN   04/Dic/2025         Ryanair     FR3049    Krakow (KRK)
# ...          ...           ...             ...        ...             ...
# 2350         NaN   04/Dic/2025            BUZZ     RR3035    Krakow (KRK)
# 2351         NaN   04/Dic/2025            BUZZ     RR4084    Warsaw (WMI)
# 2352         NaN   04/Dic/2025  Wizz Air Malta     W46020      Rome (FCO)
# 2353         NaN   04/Dic/2025        Wizz Air     W64116  Belgrade (BEG)
# 2354         NaN   04/Dic/2025  Wizz Air Malta     W45154    Tirana (TIA)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# ...

# %%
df_04.isna().sum()
# Out:
# Unnamed: 0         122
# fecha_scrapeo        0
# Name_company         1
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    117
# Aircraft            96
# Gate                 1
# dtype: int64

# %%
df_04 = df_04.drop([2324])

# %%
df_04[(df_04['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2233         NaN   04/Dic/2025                   Ryanair     FR8215
# 2234         NaN   04/Dic/2025            easyJet Europe     EC7105
# 2235         NaN   04/Dic/2025                   Ryanair     FR3976
# 2236         NaN   04/Dic/2025            easyJet Europe     EC7191
# 2237         NaN   04/Dic/2025                   Ryanair     FR3049
# 2238         NaN   04/Dic/2025                   Ryanair     FR3028
# 2240         NaN   04/Dic/2025                   Ryanair      FR133
# 2241         NaN   04/Dic/2025            easyJet Europe     EC7101
# 2242         NaN   04/Dic/2025            easyJet Europe     EC7151
# 2243         NaN   04/Dic/2025                   Ryanair     FR2507
# 2244         NaN   04/Dic/2025  Norwegian Air Sweden AOC     D85510
# 2245         NaN   04/Dic/2025                   Ryanair      FR575
# 2246         NaN   04/Dic/2025                   Ryanair      FR774
# ...

# %%
df_04.loc[df_04['Aircraft'] == 'B738', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Aircraft'] == 'B38M', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Aircraft'] == 'A320', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Aircraft'] == 'A21N', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Aircraft'] == 'A20N', 'Aircraft'] = 'Airbus A320neo'

# %%
df_04.loc[df_04['Aircraft'] == 'Boeing 737-800', 'flight_capacity'] = 189
df_04.loc[df_04['Aircraft'] == 'Boeing 737 MAX 8', 'flight_capacity'] = 197
df_04.loc[df_04['Aircraft'] == 'Airbus A320', 'flight_capacity'] = 180
df_04.loc[df_04['Aircraft'] == 'Airbus A321neo', 'flight_capacity'] = 239
df_04.loc[df_04['Aircraft'] == 'Airbus A320neo', 'flight_capacity'] = 186
df_04.loc[df_04['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] = 174

# %%
df_04[(df_04['Gate'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo Name_company Num_flight  Name_Destiny  \
# 2300         NaN   04/Dic/2025   SmartWings     QS1059  Prague (PRG)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# 2300       14:55  Retrasado, Programado 15:06              NaN      NaN  NaN

# %%
df_04.loc[df_04['Num_flight'] == 'QS1059', 'Gate'] = 'U'

# %%
df_04[(df_04['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2234         NaN   04/Dic/2025            easyJet Europe     EC7105
# 2236         NaN   04/Dic/2025            easyJet Europe     EC7191
# 2237         NaN   04/Dic/2025                   Ryanair     FR3049
# 2238         NaN   04/Dic/2025                   Ryanair     FR3028
# 2241         NaN   04/Dic/2025            easyJet Europe     EC7101
# 2242         NaN   04/Dic/2025            easyJet Europe     EC7151
# 2243         NaN   04/Dic/2025                   Ryanair     FR2507
# 2244         NaN   04/Dic/2025  Norwegian Air Sweden AOC     D85510
# 2245         NaN   04/Dic/2025                   Ryanair      FR575
# 2246         NaN   04/Dic/2025                   Ryanair      FR774
# 2247         NaN   04/Dic/2025                   Ryanair     FR6973
# 2249         NaN   04/Dic/2025                   Ryanair     FR5710
# 2250         NaN   04/Dic/2025                  Wizz Air     W62048
# ...

# %%
df_04.loc[df_04['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W45154', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W64116', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'RR4084', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'RR4084', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'RR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'RR3035', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321'
df_04.loc[df_04['Num_flight'] == 'W46728', 'flight_capacity'] = 230

df_04.loc[df_04['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_04.loc[df_04['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_04.loc[df_04['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W64406', 'flight_capacity'] = 239

# %%
df_04.loc[df_04['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'RR333', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'W64738', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W64738', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3143', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A320neo'
df_04.loc[df_04['Num_flight'] == 'U28058', 'flight_capacity'] = 186

df_04.loc[df_04['Num_flight'] == 'FR8598', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR8598', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == '3O378', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == '3O378', 'flight_capacity'] = 174

df_04.loc[df_04['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR8217', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR1342', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR1342', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'RR3193', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'RR3193', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W61176', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_04.loc[df_04['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_04.loc[df_04['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_04.loc[df_04['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_04.loc[df_04['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC7139', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7139', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'RR6300', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'RR6300', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'V72327', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'RR8394', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'EC1378', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'EC1378', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'FR9913', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR9913', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'V73573', 'flight_capacity'] = 156

# %%
df_04.loc[df_04['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR2922', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'QS1059', 'Aircraft'] = 'Airbus A220-300'
df_04.loc[df_04['Num_flight'] == 'QS1059', 'flight_capacity'] = 149

df_04.loc[df_04['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR9015', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-800'
df_04.loc[df_04['Num_flight'] == 'KU136', 'flight_capacity'] = 235

df_04.loc[df_04['Num_flight'] == 'XQ895', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'XQ895', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_04.loc[df_04['Num_flight'] == 'BT684', 'flight_capacity'] = 149

df_04.loc[df_04['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR846', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR6267', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'LG3592', 'Aircraft'] = 'de Havilland Dash 8-400'
df_04.loc[df_04['Num_flight'] == 'LG3592', 'flight_capacity'] = 76

df_04.loc[df_04['Num_flight'] == 'FR3039', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR3039', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'V71445', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'V71445', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321'
df_04.loc[df_04['Num_flight'] == 'PC1092', 'flight_capacity'] = 220

df_04.loc[df_04['Num_flight'] == 'FR3160', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3160', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'EC7131', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320neo'
df_04.loc[df_04['Num_flight'] == 'U22704', 'flight_capacity'] = 186

df_04.loc[df_04['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR4545', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

# %%
df_04.loc[df_04['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'J246', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
df_04.loc[df_04['Num_flight'] == 'U25716', 'flight_capacity'] = 186

df_04.loc[df_04['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A320neo'
df_04.loc[df_04['Num_flight'] == 'U28056', 'flight_capacity'] = 186

df_04.loc[df_04['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_04.loc[df_04['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_04.loc[df_04['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR1279', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'EC7656', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'JU581', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'TO4751', 'Aircraft'] = 'Airbus A320neo'
df_04.loc[df_04['Num_flight'] == 'TO4751', 'flight_capacity'] = 186

df_04.loc[df_04['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W61914', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_04.loc[df_04['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_04.loc[df_04['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_04.loc[df_04['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_04.loc[df_04['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR5710', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR6973', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'D85510', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR2507', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_04.loc[df_04['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_04.loc[df_04['Num_flight'] == 'FR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_04.loc[df_04['Num_flight'] == 'FR3049', 'flight_capacity'] = 197

df_04.loc[df_04['Num_flight'] == 'EC7191', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7191', 'flight_capacity'] = 156

df_04.loc[df_04['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_04.loc[df_04['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

# %%
df_05 = df_por_fecha['05/Dic/2025'].copy()
df_05
# Viernes
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight   Name_Destiny  \
# 2355         NaN   05/Dic/2025  easyJet Europe     EC7105   Geneva (GVA)
# 2356         NaN   05/Dic/2025         Ryanair     FR8183  Bologna (BLQ)
# 2357         NaN   05/Dic/2025         Ryanair     FR8231   London (STN)
# 2358         NaN   05/Dic/2025         Ryanair      FR777   Venice (VCE)
# 2359         NaN   05/Dic/2025         Ryanair      FR846    Milan (BGY)
# ...          ...           ...             ...        ...            ...
# 2527         NaN   05/Dic/2025         Easyjet     U28060   London (LGW)
# 2528         NaN   05/Dic/2025         Ryanair     FR3080   Malaga (AGP)
# 2529         NaN   05/Dic/2025  Wizz Air Malta     W45154   Tirana (TIA)
# 2530         NaN   05/Dic/2025        Wizz Air     W61706   Gdansk (GDN)
# 2531         NaN   05/Dic/2025         Ryanair     FR9814   London (STN)
#
#      Time_flight                 flight_state  flight_capacity  \
# ...

# %%
df_05.isna().sum()
# Out:
# Unnamed: 0         177
# fecha_scrapeo        0
# Name_company         1
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    166
# Aircraft           157
# Gate                 2
# dtype: int64

# %%
df_05 = df_05.drop([2448])

# %%
df_05[(df_05['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2355         NaN   05/Dic/2025            easyJet Europe     EC7105
# 2356         NaN   05/Dic/2025                   Ryanair     FR8183
# 2357         NaN   05/Dic/2025                   Ryanair     FR8231
# 2358         NaN   05/Dic/2025                   Ryanair      FR777
# 2359         NaN   05/Dic/2025                   Ryanair      FR846
# 2360         NaN   05/Dic/2025                   Ryanair      FR133
# 2361         NaN   05/Dic/2025                   Ryanair     FR4545
# 2362         NaN   05/Dic/2025            easyJet Europe     EC7101
# 2363         NaN   05/Dic/2025            easyJet Europe     EC7199
# 2365         NaN   05/Dic/2025  Norwegian Air Sweden AOC     D85502
# 2366         NaN   05/Dic/2025                   Ryanair     FR3976
# 2367         NaN   05/Dic/2025                   Ryanair     FR3185
# 2368         NaN   05/Dic/2025                   Ryanair     FR6973
# ...

# %%
df_05.loc[df_05['Aircraft'] == 'B738', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Aircraft'] == 'B38M', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Aircraft'] == 'A320', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Aircraft'] == 'A21N', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Aircraft'] == 'A20N', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Aircraft'] == 'A319', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Aircraft'] == 'A321', 'Aircraft'] = 'Airbus A321'

# %%
df_05.loc[df_05['Aircraft'] == 'Boeing 737-800', 'flight_capacity'] = 189
df_05.loc[df_05['Aircraft'] == 'Boeing 737 MAX 8', 'flight_capacity'] = 197
df_05.loc[df_05['Aircraft'] == 'Airbus A320', 'flight_capacity'] = 180
df_05.loc[df_05['Aircraft'] == 'Airbus A321neo', 'flight_capacity'] = 239
df_05.loc[df_05['Aircraft'] == 'Airbus A320neo', 'flight_capacity'] = 186
df_05.loc[(df_05['Name_company'] == 'Aer Lingus') &
(df_05['Aircraft'] == 'Airbus A320'), 'flight_capacity'] = 174

# %%
df_05[(df_05['Gate'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight    Name_Destiny  \
# 2426         NaN   05/Dic/2025          FlyOne     5F5512  Chisinau (KIV)
# 2435         NaN   05/Dic/2025  easyJet Europe     EC7153     Milan (MXP)
#
#      Time_flight                 flight_state  flight_capacity Aircraft Gate
# 2426       13:30  Retrasado, Programado 15:00              NaN      NaN  NaN
# 2435       14:20  Retrasado, Programado 14:31              NaN      NaN  NaN

# %%
df_05.loc[df_05['Num_flight'] == '5F5512', 'Gate'] = 'W'
df_05.loc[df_05['Num_flight'] == 'EC7153', 'Gate'] = 'R'

# %%
df_05[(df_05['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2355         NaN   05/Dic/2025            easyJet Europe     EC7105
# 2356         NaN   05/Dic/2025                   Ryanair     FR8183
# 2357         NaN   05/Dic/2025                   Ryanair     FR8231
# 2358         NaN   05/Dic/2025                   Ryanair      FR777
# 2359         NaN   05/Dic/2025                   Ryanair      FR846
# 2360         NaN   05/Dic/2025                   Ryanair      FR133
# 2362         NaN   05/Dic/2025            easyJet Europe     EC7101
# 2363         NaN   05/Dic/2025            easyJet Europe     EC7199
# 2365         NaN   05/Dic/2025  Norwegian Air Sweden AOC     D85502
# 2366         NaN   05/Dic/2025                   Ryanair     FR3976
# 2367         NaN   05/Dic/2025                   Ryanair     FR3185
# 2368         NaN   05/Dic/2025                   Ryanair     FR6973
# 2369         NaN   05/Dic/2025            easyJet Europe     EC1376
# ...

# %%
df_05.loc[df_05['Name_company'] == 'Air Arabia Maroc', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] = 174

# %%
df_05.loc[df_05['Num_flight'] == 'FR9814', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR9814', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W61706', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W45154', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'U28060', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'U28060', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W46728', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W64116', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2250', 'flight_capacity'] = 189

# %%
df_05.loc[df_05['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR6597', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EC7682', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == 'EC7682', 'flight_capacity'] = 230

df_05.loc[df_05['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR9811', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR8669', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR7808', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR7808', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'RR6944', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_05.loc[df_05['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'FR3174', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3174', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'U23374', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'U23374', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'EI565', 'flight_capacity'] = 174

df_05.loc[df_05['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'RR8394', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'U22326', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR5710', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'LG3592', 'Aircraft'] = 'Boeing 737-700'
df_05.loc[df_05['Num_flight'] == 'LG3592', 'flight_capacity'] = 141

df_05.loc[df_05['Num_flight'] == 'RR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'RR1786', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'JU585', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR8631', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR7539', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR7539', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'V72135', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'V72135', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'TW408', 'Aircraft'] = 'Airbus A330-200'
df_05.loc[df_05['Num_flight'] == 'TW408', 'flight_capacity'] = 246

df_05.loc[df_05['Num_flight'] == 'W42940', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W42940', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'EC1956', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'EC1956', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W62096', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR6305', 'flight_capacity'] = 197

# %%
df_05.loc[df_05['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR6275', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR1527', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W64666', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == 'W64666', 'flight_capacity'] = 230

df_05.loc[df_05['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'EW2521', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR6374', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR6374', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'U28058', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'LW7362', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'LW7362', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'FR2330', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2330', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EW9443', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'EW9443', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'V72165', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR9111', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR9111', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'RR6330', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'RR6330', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR149', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'EC7155', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7155', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR3189', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3189', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR2098', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2098', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'EC7205', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7205', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR6353', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR6353', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'HV5134', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'V73573', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR3076', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR3076', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'W67920', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W67920', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR4587', 'flight_capacity'] = 197

# %%
df_05.loc[df_05['Num_flight'] == 'FR878', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'FR878', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W43564', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'W43564', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR6985', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR2925', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2925', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'D85510', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'D85510', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'PC1094', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'PC1094', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'W61412', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W61412', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'EC7694', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'EC7694', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'QS1059', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'QS1059', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR867', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'V71443', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'V71443', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR8215', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR8215', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'TK608', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'S4507', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'S4507', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_05.loc[df_05['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_05.loc[df_05['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR6078', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR6078', 'flight_capacity'] = 189

# %%
df_05.loc[df_05['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2922', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'PC1528', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == '5F5512', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == '5F5512', 'flight_capacity'] = 194

df_05.loc[df_05['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'H4264', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'H4264', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR6874', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'PC1092', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'D83657', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'D83657', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FI597', 'flight_capacity'] = 160

df_05.loc[df_05['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'U28056', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'EC7141', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7141', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == '3F232', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == '3F232', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'HV6064', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'HV6064', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'U22324', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'U22324', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'U22002', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'HV5132', 'flight_capacity'] = 232

df_05.loc[df_05['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR6920', 'flight_capacity'] = 197

# %%
df_05.loc[df_05['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR9015', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'JU581', 'flight_capacity'] = 174

df_05.loc[df_05['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_05.loc[df_05['Num_flight'] == 'U26654', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'U26654', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_05.loc[df_05['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_05.loc[df_05['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == 'W45088', 'flight_capacity'] = 230

df_05.loc[df_05['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_05.loc[df_05['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_05.loc[df_05['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'EC3737', 'Aircraft'] = 'Airbus A320'
df_05.loc[df_05['Num_flight'] == 'EC3737', 'flight_capacity'] = 180

df_05.loc[df_05['Num_flight'] == 'TO4751', 'Aircraft'] = 'Airbus A320neo'
df_05.loc[df_05['Num_flight'] == 'TO4751', 'flight_capacity'] = 186

df_05.loc[df_05['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_05.loc[df_05['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_05.loc[df_05['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR6973', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR3185', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3185', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR3976', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EC7199', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7199', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_05.loc[df_05['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR846', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'FR8183', 'Aircraft'] = 'Boeing 737-800'
df_05.loc[df_05['Num_flight'] == 'FR8183', 'flight_capacity'] = 189

df_05.loc[df_05['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_05.loc[df_05['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

# %%
df_06 = df_por_fecha['06/Dic/2025'].copy()
df_06
# Sabado
# Out:
#       Unnamed: 0 fecha_scrapeo      Name_company Num_flight  \
# 2532         NaN   06/Dic/2025           Ryanair      FR846
# 2533         NaN   06/Dic/2025    easyJet Europe     EC7105
# 2534         NaN   06/Dic/2025           Ryanair     FR5718
# 2535         NaN   06/Dic/2025           Ryanair     FR4545
# 2536         NaN   06/Dic/2025           Ryanair     FR1342
# ...          ...           ...               ...        ...
# 2656         NaN   06/Dic/2025    Wizz Air Malta     W46020
# 2657         NaN   06/Dic/2025           Ryanair     FR3800
# 2658         NaN   06/Dic/2025           Ryanair     FR8574
# 2659         NaN   06/Dic/2025          Wizz Air     W64116
# 2660         NaN   06/Dic/2025  Air Arabia Maroc      3O642
#
#                  Name_Destiny Time_flight                flight_state  \
# 2532              Milan (BGY)       06:00          En hora, Ha salido
# 2533             Geneva (GVA)       06:10          En hora, Ha salido
# ...

# %%
df_06.isna().sum()
# Out:
# Unnamed: 0         129
# fecha_scrapeo        0
# Name_company         0
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    120
# Aircraft           102
# Gate                 0
# dtype: int64

# %%
df_06.loc[df_06['Name_company'] == 'Air Arabia Maroc', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] = 174

# %%
df_06[(df_06['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
# 2532         NaN   06/Dic/2025         Ryanair      FR846       Milan (BGY)
# 2533         NaN   06/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
# 2534         NaN   06/Dic/2025         Ryanair     FR5718  Bratislava (BTS)
# 2535         NaN   06/Dic/2025         Ryanair     FR4545       Porto (OPO)
# 2537         NaN   06/Dic/2025         Ryanair      FR777      Venice (VCE)
# 2538         NaN   06/Dic/2025         Ryanair     FR8217      London (STN)
# 2539         NaN   06/Dic/2025  easyJet Europe     EC7151       Milan (MXP)
# 2540         NaN   06/Dic/2025         Ryanair     FR2918    Brussels (BRU)
# 2541         NaN   06/Dic/2025         Ryanair     FR3180        Rome (FCO)
# 2544         NaN   06/Dic/2025         Ryanair      FR575     Bologna (BLQ)
# 2545         NaN   06/Dic/2025         Ryanair     FR3166     Palermo (PMO)
# ...

# %%
df_06.loc[df_06['Aircraft'] == 'B738', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Aircraft'] == 'B38M', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Aircraft'] == 'A320', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Aircraft'] == 'A21N', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Aircraft'] == 'A20N', 'Aircraft'] = 'Airbus A320neo'
df_06.loc[df_06['Aircraft'] == 'A319', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Aircraft'] == 'A321', 'Aircraft'] = 'Airbus A321'

# %%
df_06.loc[df_06['Aircraft'] == 'Boeing 737-800', 'flight_capacity'] = 189
df_06.loc[df_06['Aircraft'] == 'Boeing 737 MAX 8', 'flight_capacity'] = 197
df_06.loc[df_06['Aircraft'] == 'Airbus A320', 'flight_capacity'] = 180
df_06.loc[df_06['Aircraft'] == 'Airbus A321neo', 'flight_capacity'] = 239
df_06.loc[df_06['Aircraft'] == 'Airbus A320neo', 'flight_capacity'] = 186
#df_05.loc[(df_05['Name_company'] == 'Aer Lingus') &
#(df_05['Aircraft'] == 'Airbus A320'), 'flight_capacity'] = 174

# %%
df_06[(df_06['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight      Name_Destiny  \
# 2532         NaN   06/Dic/2025         Ryanair      FR846       Milan (BGY)
# 2533         NaN   06/Dic/2025  easyJet Europe     EC7105      Geneva (GVA)
# 2534         NaN   06/Dic/2025         Ryanair     FR5718  Bratislava (BTS)
# 2537         NaN   06/Dic/2025         Ryanair      FR777      Venice (VCE)
# 2538         NaN   06/Dic/2025         Ryanair     FR8217      London (STN)
# 2539         NaN   06/Dic/2025  easyJet Europe     EC7151       Milan (MXP)
# 2541         NaN   06/Dic/2025         Ryanair     FR3180        Rome (FCO)
# 2544         NaN   06/Dic/2025         Ryanair      FR575     Bologna (BLQ)
# 2545         NaN   06/Dic/2025         Ryanair     FR3166     Palermo (PMO)
# 2546         NaN   06/Dic/2025  Wizz Air Malta     W43938    Chisinau (KIV)
# 2547         NaN   06/Dic/2025        Wizz Air     W62048      Krakow (KRK)
# ...

# %%
df_06.loc[df_06['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321'
df_06.loc[df_06['Num_flight'] == 'W64116', 'flight_capacity'] = 230

df_06.loc[df_06['Num_flight'] == 'FR8574', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR8574', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR3800', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3800', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'RR3039', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'RR3039', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR5220', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_06.loc[df_06['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_06.loc[df_06['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'TO4759', 'Aircraft'] = 'Airbus A320neo'
df_06.loc[df_06['Num_flight'] == 'TO4759', 'flight_capacity'] = 186

# %%
df_06.loc[df_06['Num_flight'] == 'FR3928', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3928', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR3182', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3182', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'TW408', 'Aircraft'] = 'BOEING 777-300ER'
df_06.loc[df_06['Num_flight'] == 'TW408', 'flight_capacity'] = 294

df_06.loc[df_06['Num_flight'] == 'FR9581', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR9581', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR867', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR867', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'FR3078', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3078', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'BT878', 'Aircraft'] = 'Airbus A220-300'
df_06.loc[df_06['Num_flight'] == 'BT878', 'flight_capacity'] = 148

df_06.loc[df_06['Num_flight'] == 'FR149', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR149', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'V72327', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'FR5270', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR5270', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR9045', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR9045', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'W61478', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W61478', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W61176', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR3792', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'FR3035', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR3035', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'HV5134', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR878', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR878', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'EC8066', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC8066', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'FR2925', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR2925', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'W43180', 'Aircraft'] = 'Airbus A321'
df_06.loc[df_06['Num_flight'] == 'W43180', 'flight_capacity'] = 230

df_06.loc[df_06['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR6874', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR9015', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'FR2406', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR2406', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR269', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

# %%
df_06.loc[df_06['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321'
df_06.loc[df_06['Num_flight'] == 'W46728', 'flight_capacity'] = 230

df_06.loc[df_06['Num_flight'] == 'FR3146', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3146', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR7543', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR7543', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'RR8384', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR3807', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR3807', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'TK608', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'TK608', 'flight_capacity'] = 151

df_06.loc[df_06['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'KU136', 'Aircraft'] = 'Airbus A330-800'
df_06.loc[df_06['Num_flight'] == 'KU136', 'flight_capacity'] = 235

df_06.loc[df_06['Num_flight'] == 'FR58', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR58', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_06.loc[df_06['Num_flight'] == 'BT684', 'flight_capacity'] = 148

df_06.loc[df_06['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'OB775', 'Aircraft'] = 'Airbus A330-200'
df_06.loc[df_06['Num_flight'] == 'OB775', 'flight_capacity'] = 246

df_06.loc[df_06['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR3320', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'FR2507', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'FR2507', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'EI563', 'flight_capacity'] = 174

df_06.loc[df_06['Num_flight'] == 'EC7193', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC7193', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'FR6394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR6394', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'U22704', 'Aircraft'] = 'Airbus A320neo'
df_06.loc[df_06['Num_flight'] == 'U22704', 'flight_capacity'] = 186

df_06.loc[df_06['Num_flight'] == 'U5406', 'Aircraft'] = 'Boeing 737-700'
df_06.loc[df_06['Num_flight'] == 'U5406', 'flight_capacity'] = 141

df_06.loc[df_06['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A320neo'
df_06.loc[df_06['Num_flight'] == 'J246', 'flight_capacity'] = 186

df_06.loc[df_06['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'U28056', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'LW12', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'LW12', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'FR9307', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR9307', 'flight_capacity'] = 197

# %%
df_06.loc[df_06['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_06.loc[df_06['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_06.loc[df_06['Num_flight'] == 'FR9171', 'Aircraft'] = 'Boeing 737 MAX 8'
df_06.loc[df_06['Num_flight'] == 'FR9171', 'flight_capacity'] = 197

df_06.loc[df_06['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_06.loc[df_06['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_06.loc[df_06['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'W61812', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W61812', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'HV5132', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'HV5132', 'flight_capacity'] = 232

df_06.loc[df_06['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'FR6559', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR6559', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3143', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'JU581', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'JU581', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321'
df_06.loc[df_06['Num_flight'] == 'W42938', 'flight_capacity'] = 230

df_06.loc[df_06['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'RR3049', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W43176', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'W61914', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W61914', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3028', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR2834', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_06.loc[df_06['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_06.loc[df_06['Num_flight'] == 'W43938', 'Aircraft'] = 'Airbus A320'
df_06.loc[df_06['Num_flight'] == 'W43938', 'flight_capacity'] = 180

df_06.loc[df_06['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'EC7151', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC7151', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR8217', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR777', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_06.loc[df_06['Num_flight'] == 'EC7105', 'Aircraft'] = 'Airbus A319'
df_06.loc[df_06['Num_flight'] == 'EC7105', 'flight_capacity'] = 156

df_06.loc[df_06['Num_flight'] == 'FR846', 'Aircraft'] = 'Boeing 737-800'
df_06.loc[df_06['Num_flight'] == 'FR846', 'flight_capacity'] = 189

# %%
df_07 = df_por_fecha['07/Dic/2025'].copy()
df_07
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight     Name_Destiny  \
# 2661         NaN   07/Dic/2025         Ryanair     FR3180       Rome (FCO)
# 2662         NaN   07/Dic/2025         Ryanair     FR2834  Charleroi (CRL)
# 2663         NaN   07/Dic/2025         Ryanair     FR2918   Brussels (BRU)
# 2664         NaN   07/Dic/2025         Ryanair     FR4084     Warsaw (WMI)
# 2665         NaN   07/Dic/2025         Ryanair     FR2239  Marrakech (RAK)
# ...          ...           ...             ...        ...              ...
# 2825         NaN   07/Dic/2025        Wizz Air     W64116   Belgrade (BEG)
# 2826         NaN   07/Dic/2025  Wizz Air Malta     W45154     Tirana (TIA)
# 2827         NaN   07/Dic/2025         Ryanair     FR5220    Bologna (BLQ)
# 2828         NaN   07/Dic/2025        Wizz Air     W61706     Gdansk (GDN)
# 2829         NaN   07/Dic/2025         Ryanair     FR9406        Fes (FEZ)
#
# ...

# %%
df_07.isna().sum()
# Out:
# Unnamed: 0         169
# fecha_scrapeo        0
# Name_company         1
# Num_flight           0
# Name_Destiny         0
# Time_flight          0
# flight_state         0
# flight_capacity    160
# Aircraft           150
# Gate                 3
# dtype: int64

# %%
df_07[(df_07['flight_capacity'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2661         NaN   07/Dic/2025                   Ryanair     FR3180
# 2662         NaN   07/Dic/2025                   Ryanair     FR2834
# 2663         NaN   07/Dic/2025                   Ryanair     FR2918
# 2664         NaN   07/Dic/2025                   Ryanair     FR4084
# 2665         NaN   07/Dic/2025                   Ryanair     FR2239
# 2666         NaN   07/Dic/2025                   Ryanair     FR2507
# 2667         NaN   07/Dic/2025            easyJet Europe     EC7101
# 2668         NaN   07/Dic/2025            easyJet Europe     EC7191
# 2669         NaN   07/Dic/2025            easyJet Europe     EC8064
# 2670         NaN   07/Dic/2025                   Ryanair     FR6597
# 2671         NaN   07/Dic/2025                   Ryanair     FR3108
# 2673         NaN   07/Dic/2025  Norwegian Air Sweden AOC     D85510
# 2674         NaN   07/Dic/2025            easyJet Europe     EC7131
# ...

# %%
df_07.loc[df_07['Aircraft'] == 'B738', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Aircraft'] == 'B38M', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Aircraft'] == 'A320', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Aircraft'] == 'A21N', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Aircraft'] == 'A20N', 'Aircraft'] = 'Airbus A320neo'
df_07.loc[df_07['Aircraft'] == 'A319', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Aircraft'] == 'A321', 'Aircraft'] = 'Airbus A321'

# %%
df_07.loc[df_07['Aircraft'] == 'Boeing 737-800', 'flight_capacity'] = 189
df_07.loc[df_07['Aircraft'] == 'Boeing 737 MAX 8', 'flight_capacity'] = 197
df_07.loc[df_07['Aircraft'] == 'Airbus A320', 'flight_capacity'] = 180
df_07.loc[df_07['Aircraft'] == 'Airbus A319', 'flight_capacity'] = 156
df_07.loc[df_07['Aircraft'] == 'Airbus A321neo', 'flight_capacity'] = 239
df_07.loc[df_07['Aircraft'] == 'Airbus A321', 'flight_capacity'] = 230
df_07.loc[df_07['Aircraft'] == 'Airbus A320neo', 'flight_capacity'] = 186

# %%
df_07.loc[df_07['Aircraft'] == 'BBoeing 737-800', 'Aircraft'] = 'Boeing 737-800'

# %%
df_07 = df_07.drop([2786])

# %%
df_07.loc[df_07['Name_company'] == 'Air Arabia Maroc', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Name_company'] == 'Air Arabia Maroc', 'flight_capacity'] = 174

# %%
df_07[(df_07['Gate'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo              Name_company Num_flight  \
# 2744         NaN   07/Dic/2025  Norwegian Air Sweden AOC     D85502
# 2745         NaN   07/Dic/2025          Bluebird Airways      BZ251
# 2746         NaN   07/Dic/2025                SmartWings     QS1059
#
#          Name_Destiny Time_flight         flight_state  flight_capacity  \
# 2744  Stockholm (ARN)       14:40  En hora, Programado              NaN
# 2745   Tel Aviv (TLV)       14:45  En hora, Programado              NaN
# 2746     Prague (PRG)       14:55  En hora, Programado              NaN
#
#      Aircraft Gate
# 2744      NaN  NaN
# 2745      NaN  NaN
# 2746      NaN  NaN

# %%
df_07.loc[df_07['Num_flight'] == 'D85502', 'Gate'] = 'U'
df_07.loc[df_07['Num_flight'] == 'BZ251', 'Gate'] = 'Y'
df_07.loc[df_07['Num_flight'] == 'QS1059', 'Gate'] = 'U'

# %%
df_07[(df_07['Aircraft'].isna())].head(30)
# Out:
#       Unnamed: 0 fecha_scrapeo    Name_company Num_flight  \
# 2661         NaN   07/Dic/2025         Ryanair     FR3180
# 2662         NaN   07/Dic/2025         Ryanair     FR2834
# 2663         NaN   07/Dic/2025         Ryanair     FR2918
# 2665         NaN   07/Dic/2025         Ryanair     FR2239
# 2666         NaN   07/Dic/2025         Ryanair     FR2507
# 2667         NaN   07/Dic/2025  easyJet Europe     EC7101
# 2668         NaN   07/Dic/2025  easyJet Europe     EC7191
# 2669         NaN   07/Dic/2025  easyJet Europe     EC8064
# 2670         NaN   07/Dic/2025         Ryanair     FR6597
# 2674         NaN   07/Dic/2025  easyJet Europe     EC7131
# 2675         NaN   07/Dic/2025  easyJet Europe     EC3754
# 2677         NaN   07/Dic/2025  easyJet Europe     EC1376
# 2679         NaN   07/Dic/2025            BUZZ     RR1786
# 2680         NaN   07/Dic/2025         Ryanair     FR3028
# 2681         NaN   07/Dic/2025        Wizz Air     W62048
# ...

# %%
df_07.loc[df_07['Num_flight'] == 'FR9406', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR9406', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W61706', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W61706', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'FR5220', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR5220', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W45154', 'Aircraft'] = 'Airbus A321'
df_07.loc[df_07['Num_flight'] == 'W45154', 'flight_capacity'] = 230

df_07.loc[df_07['Num_flight'] == 'W64116', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W64116', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'V71415', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'V71415', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'U22706', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'U22706', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'W46728', 'Aircraft'] = 'Airbus A321'
df_07.loc[df_07['Num_flight'] == 'W46728', 'flight_capacity'] = 230

df_07.loc[df_07['Num_flight'] == 'FR5752', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR5752', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'W46020', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W46020', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'U28060', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'U28060', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'W43406', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'W43406', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'EI565', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EI565', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'W43178', 'Aircraft'] = 'Airbus A321'
df_07.loc[df_07['Num_flight'] == 'W43178', 'flight_capacity'] = 230

df_07.loc[df_07['Num_flight'] == 'FR3792', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR3792', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'HV5134', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'HV5134', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR2896', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2896', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'RR8615', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'RR8615', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W64738', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W64738', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'U22326', 'Aircraft'] = 'Airbus A320neo'
df_07.loc[df_07['Num_flight'] == 'U22326', 'flight_capacity'] = 186

df_07.loc[df_07['Num_flight'] == 'RR6944', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'RR6944', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR6275', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6275', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W62378', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W62378', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'TO4759', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'TO4759', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'LG3596', 'Aircraft'] = 'Boeing 737-700'
df_07.loc[df_07['Num_flight'] == 'LG3596', 'flight_capacity'] = 141

df_07.loc[df_07['Num_flight'] == 'FR4587', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR4587', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EW2521', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'EW2521', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'D83659', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'D83659', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'JU585', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'JU585', 'flight_capacity'] = 174

# %%
df_07.loc[df_07['Num_flight'] == 'EW521', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EW521', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR6985', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR6985', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'W67022', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W67022', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'HV6788', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'HV6788', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC4212', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EC4212', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'W62096', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W62096', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'FR8136', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR8136', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'U28058', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'U28058', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR9015', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR9015', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR5710', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR5710', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC3750', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EC3750', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR2233', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2233', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W64406', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W64406', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'V72165', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'V72165', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'EC7159', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7159', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'W61176', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'W61176', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'U25716', 'Aircraft'] = 'Airbus A320neo'
df_07.loc[df_07['Num_flight'] == 'U25716', 'flight_capacity'] = 186

df_07.loc[df_07['Num_flight'] == 'HV6066', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'HV6066', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR8631', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR8631', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC7103', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7103', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'LS804', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'LS804', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W43686', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'W43686', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR2406', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2406', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'V73700', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'V73700', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'EC7109', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7109', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR6305', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6305', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR777', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR777', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR1681', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR1681', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'RR5252', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'RR5252', 'flight_capacity'] = 189

# %%
df_07.loc[df_07['Num_flight'] == 'V73573', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'V73573', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR12', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR12', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR5718', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR5718', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'RR8394', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'RR8394', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR2250', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2250', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR8669', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR8669', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC7173', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7173', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR2922', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2922', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR133', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR133', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR269', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR269', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'W61412', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W61412', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'EC7694', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EC7694', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'TO4755', 'Aircraft'] = 'Airbus A320neo'
df_07.loc[df_07['Num_flight'] == 'TO4755', 'flight_capacity'] = 186

df_07.loc[df_07['Num_flight'] == 'RR3072', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'RR3072', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR774', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR774', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR3320', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR3320', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'QS1059', 'Aircraft'] = 'Airbus A220-300'
df_07.loc[df_07['Num_flight'] == 'QS1059', 'flight_capacity'] = 149

df_07.loc[df_07['Num_flight'] == 'BZ251', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'BZ251', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'D85502', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'D85502', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR6973', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6973', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC7107', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7107', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'HV5132', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'HV5132', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'XQ895', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'XQ895', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR4585', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR4585', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR6920', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR6920', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'EC7153', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7153', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'BT684', 'Aircraft'] = 'Airbus A220-300'
df_07.loc[df_07['Num_flight'] == 'BT684', 'flight_capacity'] = 149

df_07.loc[df_07['Num_flight'] == 'FR9811', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR9811', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'PC1528', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'PC1528', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'EC1380', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EC1380', 'flight_capacity'] = 180

# %%
df_07.loc[df_07['Num_flight'] == 'U28056', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'U28056', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR3121', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR3121', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W46330', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W46330', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'V71445', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'V71445', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR8598', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR8598', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR2511', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2511', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'PC1092', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'PC1092', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'FR6300', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6300', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'V72167', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'V72167', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR1527', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR1527', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR3976', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR3976', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR3129', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR3129', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR8217', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR8217', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'V72327', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'V72327', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FI597', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FI597', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'EC7139', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7139', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'EI563', 'Aircraft'] = 'Airbus A320neo'
df_07.loc[df_07['Num_flight'] == 'EI563', 'flight_capacity'] = 186

df_07.loc[df_07['Num_flight'] == 'DY1741', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'DY1741', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'U22002', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'U22002', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR3166', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR3166', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'J246', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'J246', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR3143', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR3143', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR1279', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR1279', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR7543', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR7543', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR6267', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6267', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR575', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR575', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W61476', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W61476', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'W61812', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W61812', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'LW7351', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'LW7351', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'FR6874', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR6874', 'flight_capacity'] = 197

# %%
df_07.loc[df_07['Num_flight'] == 'W46018', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W46018', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'FR8231', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR8231', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'RR3049', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'RR3049', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR6341', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6341', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR9593', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR9593', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'RR8384', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'RR8384', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'RR333', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'RR333', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC7656', 'Aircraft'] = 'Airbus A321'
df_07.loc[df_07['Num_flight'] == 'EC7656', 'flight_capacity'] = 230

df_07.loc[df_07['Num_flight'] == 'W42938', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W42938', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'FR4545', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR4545', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W62376', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W62376', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'W45088', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W45088', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'W43176', 'Aircraft'] = 'Airbus A321'
df_07.loc[df_07['Num_flight'] == 'W43176', 'flight_capacity'] = 230

df_07.loc[df_07['Num_flight'] == 'EW7521', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EW7521', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'RR3193', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'RR3193', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'W62048', 'Aircraft'] = 'Airbus A321neo'
df_07.loc[df_07['Num_flight'] == 'W62048', 'flight_capacity'] = 239

df_07.loc[df_07['Num_flight'] == 'FR3028', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR3028', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'RR1786', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'RR1786', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'EC1376', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC1376', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'EC3754', 'Aircraft'] = 'Airbus A320'
df_07.loc[df_07['Num_flight'] == 'EC3754', 'flight_capacity'] = 180

df_07.loc[df_07['Num_flight'] == 'EC7131', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7131', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR6597', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR6597', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC8064', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC8064', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'EC7101', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7101', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR2507', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2507', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR2239', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2239', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'FR2918', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR2918', 'flight_capacity'] = 189

df_07.loc[df_07['Num_flight'] == 'EC7191', 'Aircraft'] = 'Airbus A319'
df_07.loc[df_07['Num_flight'] == 'EC7191', 'flight_capacity'] = 156

df_07.loc[df_07['Num_flight'] == 'FR2834', 'Aircraft'] = 'Boeing 737 MAX 8'
df_07.loc[df_07['Num_flight'] == 'FR2834', 'flight_capacity'] = 197

df_07.loc[df_07['Num_flight'] == 'FR3180', 'Aircraft'] = 'Boeing 737-800'
df_07.loc[df_07['Num_flight'] == 'FR3180', 'flight_capacity'] = 189

# %%
df_dic = pd.concat([ df_01, df_02, df_03, df_04, df_05, df_06, df_07 ], ignore_index=True)

# %%
df_dic
# Out:
#      Unnamed: 0 fecha_scrapeo    Name_company Num_flight     Name_Destiny  \
# 0           NaN   01/Dic/2025         Ryanair     FR3180       Rome (FCO)
# 1           NaN   01/Dic/2025         Ryanair      FR846      Milan (BGY)
# 2           NaN   01/Dic/2025  easyJet Europe     EC7105     Geneva (GVA)
# 3           NaN   01/Dic/2025         Ryanair     FR2233  Al Aaroui (NDR)
# 4           NaN   01/Dic/2025         Ryanair     FR8384   Budapest (BUD)
# ..          ...           ...             ...        ...              ...
# 919         NaN   07/Dic/2025        Wizz Air     W64116   Belgrade (BEG)
# 920         NaN   07/Dic/2025  Wizz Air Malta     W45154     Tirana (TIA)
# 921         NaN   07/Dic/2025         Ryanair     FR5220    Bologna (BLQ)
# 922         NaN   07/Dic/2025        Wizz Air     W61706     Gdansk (GDN)
# 923         NaN   07/Dic/2025         Ryanair     FR9406        Fes (FEZ)
#
#     Time_flight         flight_state  flight_capacity          Aircraft Gate
# ...

# %%
df_dic = df_dic.drop(columns=['Unnamed: 0'])

# %%
#df_enero = pd.concat([df_01, df_04, df_05, df_06, df_07], ignore_index=True)

# %%
df_dic.reset_index(drop=True, inplace=True)

# %%
df_dic
# Out:
#     fecha_scrapeo    Name_company Num_flight     Name_Destiny Time_flight  \
# 0     01/Dic/2025         Ryanair     FR3180       Rome (FCO)       06:00
# 1     01/Dic/2025         Ryanair      FR846      Milan (BGY)       06:10
# 2     01/Dic/2025  easyJet Europe     EC7105     Geneva (GVA)       06:15
# 3     01/Dic/2025         Ryanair     FR2233  Al Aaroui (NDR)       06:20
# 4     01/Dic/2025         Ryanair     FR8384   Budapest (BUD)       06:25
# ..            ...             ...        ...              ...         ...
# 919   07/Dic/2025        Wizz Air     W64116   Belgrade (BEG)       21:55
# 920   07/Dic/2025  Wizz Air Malta     W45154     Tirana (TIA)       22:45
# 921   07/Dic/2025         Ryanair     FR5220    Bologna (BLQ)       22:50
# 922   07/Dic/2025        Wizz Air     W61706     Gdansk (GDN)       22:50
# 923   07/Dic/2025         Ryanair     FR9406        Fes (FEZ)       23:15
#
#             flight_state  flight_capacity          Aircraft Gate
# ...

# %%
#df_dic.to_csv("vuelos_Enero_rellenados.csv")

# %%
df_dic.isna().sum()
# Out:
# fecha_scrapeo      0
# Name_company       0
# Num_flight         0
# Name_Destiny       0
# Time_flight        0
# flight_state       0
# flight_capacity    0
# Aircraft           0
# Gate               0
# dtype: int64

# %%
df_dic[df_dic['flight_capacity'].isna()]
# Out:
# Empty DataFrame
# Columns: [fecha_scrapeo, Name_company, Num_flight, Name_Destiny, Time_flight, flight_state, flight_capacity, Aircraft, Gate]
# Index: []

# %%
df_dic['Aircraft'].unique()
# Out:
# array(['Boeing 737-800', 'Airbus A319', 'Boeing 737 MAX 8', 'Airbus A320',
#        'Airbus A321neo', 'Airbus A321', 'Airbus A320neo',
#        'de Havilland Dash 8-400', 'Airbus A220-300', 'Airbus A330-200',
#        'Airbus A330-900', 'Boeing 737-700', 'Airbus A350-900',
#        'BOEING 777-300ER', 'Embraer ERJ-190', 'Airbus A330-800'],
#       dtype=object)

# %%
df_dic['flight_capacity'].unique()
# Out:
# array([189., 156., 197., 180., 239., 174., 230., 186.,  76., 149., 162.,
#        220., 246., 144., 194., 278., 232., 148., 141., 432., 294., 108.,
#        235., 160., 151.])

# %%
import pandas as pd

# Diccionario de traducción de meses en español a números
meses_es = {
    'Ene': '01', 'Feb': '02', 'Mar': '03', 'Abr': '04', 'May': '05', 'Jun': '06',
    'Jul': '07', 'Ago': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dic': '12'
}

# Reemplazamos los nombres meses por números usando regex

for mes_nom, mes_num in meses_es.items():
    df_dic['fecha_scrapeo'] = df_dic['fecha_scrapeo'].str.replace(mes_nom, mes_num, regex=False)

# %%
df_dic
# Out:
#     fecha_scrapeo    Name_company Num_flight     Name_Destiny Time_flight  \
# 0      01/12/2025         Ryanair     FR3180       Rome (FCO)       06:00
# 1      01/12/2025         Ryanair      FR846      Milan (BGY)       06:10
# 2      01/12/2025  easyJet Europe     EC7105     Geneva (GVA)       06:15
# 3      01/12/2025         Ryanair     FR2233  Al Aaroui (NDR)       06:20
# 4      01/12/2025         Ryanair     FR8384   Budapest (BUD)       06:25
# ..            ...             ...        ...              ...         ...
# 919    07/12/2025        Wizz Air     W64116   Belgrade (BEG)       21:55
# 920    07/12/2025  Wizz Air Malta     W45154     Tirana (TIA)       22:45
# 921    07/12/2025         Ryanair     FR5220    Bologna (BLQ)       22:50
# 922    07/12/2025        Wizz Air     W61706     Gdansk (GDN)       22:50
# 923    07/12/2025         Ryanair     FR9406        Fes (FEZ)       23:15
#
#             flight_state  flight_capacity          Aircraft Gate
# ...

# %%
df_nov = pd.read_csv('vuelos_TODO_LIMPIO.csv')
df_nov
# Out:
#       Unnamed: 0 fecha_scrapeo   Name_company Num_flight     Name_Destiny  \
# 0              0    2025-11-17  Grupo Ryanair     FR3180       Rome (FCO)
# 1              1    2025-11-17  Grupo Ryanair      FR846      Milan (BGY)
# 2              2    2025-11-17     Grupo easy     EC7105     Geneva (GVA)
# 3              3    2025-11-17  Grupo Ryanair     FR2233  Al Aaroui (NDR)
# 4              4    2025-11-17  Grupo Ryanair     FR8384   Budapest (BUD)
# ...          ...           ...            ...        ...              ...
# 1774        1774    2025-11-30     Grupo wizz     W64116   Belgrade (BEG)
# 1775        1775    2025-11-30     Grupo wizz     W45154     Tirana (TIA)
# 1776        1776    2025-11-30  Grupo Ryanair     FR5220    Bologna (BLQ)
# 1777        1777    2025-11-30     Grupo wizz     W61706     Gdansk (GDN)
# 1778        1778    2025-11-30  Grupo Ryanair     FR9406        Fes (FEZ)
#
#      Time_flight flight_state  flight_capacity          Aircraft Gate Type_f  \
# ...

# %%
df_nov = df_nov.drop(columns=['Unnamed: 0'])

# %%
df_nov.isna().sum()
# Out:
# fecha_scrapeo      0
# Name_company       0
# Num_flight         0
# Name_Destiny       0
# Time_flight        0
# flight_state       0
# flight_capacity    0
# Aircraft           0
# Gate               0
# Type_f             0
# week_day           0
# day_time           0
# dtype: int64

# %%
df_nov
# Out:
#      fecha_scrapeo   Name_company Num_flight     Name_Destiny Time_flight  \
# 0       2025-11-17  Grupo Ryanair     FR3180       Rome (FCO)    06:00:00
# 1       2025-11-17  Grupo Ryanair      FR846      Milan (BGY)    06:10:00
# 2       2025-11-17     Grupo easy     EC7105     Geneva (GVA)    06:15:00
# 3       2025-11-17  Grupo Ryanair     FR2233  Al Aaroui (NDR)    06:20:00
# 4       2025-11-17  Grupo Ryanair     FR8384   Budapest (BUD)    06:25:00
# ...            ...            ...        ...              ...         ...
# 1774    2025-11-30     Grupo wizz     W64116   Belgrade (BEG)    21:55:00
# 1775    2025-11-30     Grupo wizz     W45154     Tirana (TIA)    22:45:00
# 1776    2025-11-30  Grupo Ryanair     FR5220    Bologna (BLQ)    22:50:00
# 1777    2025-11-30     Grupo wizz     W61706     Gdansk (GDN)    22:50:00
# 1778    2025-11-30  Grupo Ryanair     FR9406        Fes (FEZ)    23:15:00
#
#      flight_state  flight_capacity          Aircraft Gate Type_f week_day  \
# ...

# %%
df_todo = pd.concat([df_nov, df_dic], ignore_index=True)
df_todo
# Out:
#      fecha_scrapeo    Name_company Num_flight     Name_Destiny Time_flight  \
# 0       2025-11-17   Grupo Ryanair     FR3180       Rome (FCO)    06:00:00
# 1       2025-11-17   Grupo Ryanair      FR846      Milan (BGY)    06:10:00
# 2       2025-11-17      Grupo easy     EC7105     Geneva (GVA)    06:15:00
# 3       2025-11-17   Grupo Ryanair     FR2233  Al Aaroui (NDR)    06:20:00
# 4       2025-11-17   Grupo Ryanair     FR8384   Budapest (BUD)    06:25:00
# ...            ...             ...        ...              ...         ...
# 2698    07/12/2025        Wizz Air     W64116   Belgrade (BEG)       21:55
# 2699    07/12/2025  Wizz Air Malta     W45154     Tirana (TIA)       22:45
# 2700    07/12/2025         Ryanair     FR5220    Bologna (BLQ)       22:50
# 2701    07/12/2025        Wizz Air     W61706     Gdansk (GDN)       22:50
# 2702    07/12/2025         Ryanair     FR9406        Fes (FEZ)       23:15
#
# ...

# %%
df_dic
# Out:
#     fecha_scrapeo    Name_company Num_flight     Name_Destiny Time_flight  \
# 0      01/12/2025         Ryanair     FR3180       Rome (FCO)       06:00
# 1      01/12/2025         Ryanair      FR846      Milan (BGY)       06:10
# 2      01/12/2025  easyJet Europe     EC7105     Geneva (GVA)       06:15
# 3      01/12/2025         Ryanair     FR2233  Al Aaroui (NDR)       06:20
# 4      01/12/2025         Ryanair     FR8384   Budapest (BUD)       06:25
# ..            ...             ...        ...              ...         ...
# 919    07/12/2025        Wizz Air     W64116   Belgrade (BEG)       21:55
# 920    07/12/2025  Wizz Air Malta     W45154     Tirana (TIA)       22:45
# 921    07/12/2025         Ryanair     FR5220    Bologna (BLQ)       22:50
# 922    07/12/2025        Wizz Air     W61706     Gdansk (GDN)       22:50
# 923    07/12/2025         Ryanair     FR9406        Fes (FEZ)       23:15
#
#             flight_state  flight_capacity          Aircraft Gate
# ...

# %%
#df_dic.to_csv("vuelos_Enero_rellenados.csv")

# %%
#df_enero.to_csv("vuelos_enero.csv")
